# %%
import nltk
import requests
import re
from bs4 import BeautifulSoup
from datetime import datetime
from nltk.corpus import stopwords
#from gensim import corpora, models, similarities

# %% [markdown]
# Exploratory text analysis of the transcript of a single cnn broadcast.

# %%
url = "http://transcripts.cnn.com/TRANSCRIPTS/2016.08.15.html"
res = requests.get(url)
txt = res.text
soup = BeautifulSoup(txt,"lxml")

# %%
shows = [show.get_text() for show in soup.find_all('div',class_='cnnTransDate')]
sections = soup.find_all('div',class_='cnnSectBulletItems')
section_links = [section.find_all('a') for section in sections]

# %%
transcript_links = [link['href'] for section in section_links for link in section]
transcript_links = transcript_links[0:40] # unicode error on the last element

# %%
base_url = "http://transcripts.cnn.com"
transcript_urls = [base_url+link for link in transcript_links]

# %%
res = requests.get(transcript_urls[0])
text = res.text

# %%
soup = BeautifulSoup(text,'lxml')
transcript = soup.find_all('p',class_="cnnBodyText")[2].text.replace(",","")

# %%
# Split by commercial break
p = re.compile("((COMMERCIAL BREAK))")
segments = re.split(p,transcript)
segments = [s for s in segments if s !="COMMERCIAL BREAK"]

# %%
# Chunk by speaker
words = [nltk.word_tokenize(seg) for seg in segments]
pos = [nltk.pos_tag(word) for word in words]
grammar = grammar = "speaker: {<NNP>+<:>}" #""" NP: {<NNP>+:}"""
cp = nltk.RegexpParser(grammar)
speakers = [cp.parse(seg) for seg in pos]

# %%
speakers
# Out:
# [Tree('S', [(u'[', 'NN'), (u'20:00:21', 'CD'), (u']', 'CD'), Tree('speaker', [(u'ANDERSON', 'NNP'), (u'COOPER', 'NNP'), (u'CNN', 'NNP'), (u'ANCHOR', 'NNP'), (u':', ':')]), (u'Good', 'NNP'), (u'evening', 'NN'), (u'.', '.'), (u'Thanks', 'NNS'), (u'for', 'IN'), (u'joining', 'VBG'), (u'us', 'PRP'), (u'.', '.'), (u'Tonight', 'NNP'), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u'on', 'IN'), (u'prompter', 'NN'), (u'and', 'CC'), (u'on', 'IN'), (u'message', 'NN'), (u'for', 'IN'), (u'a', 'DT'), (u'second', 'JJ'), (u'straight', 'NN'), (u'Monday', 'NNP'), (u'this', 'DT'), (u'time', 'NN'), (u'laying', 'VBG'), (u'out', 'RP'), (u'his', 'PRP$'), (u'plan', 'NN'), (u'for', 'IN'), (u'defeating', 'NN'), (u'ISIS', 'NNP'), (u'.', '.'), (u'And', 'CC'), (u'for', 'IN'), (u'a', 'DT'), (u'second', 'JJ'), (u'straight', 'NN'), (u'Monday', 'NNP'), (u'Republicans', 'NNP'), (u'holding', 'VBG'), (u'their', 'PRP$'), (u'breath', 'NN'), (u'hoping', 'VBG'), (u'tomorrow', 'NN'), (u'wo', 'MD'), (u"n't", 'RB'), (u'be', 'VB'), (u'another', 'DT'), (u'Tuesday', 'NNP'), (u'like', 'IN'), (u'last', 'JJ'), (u'Tuesday', 'NNP'), (u'when', 'WRB'), (u'Trump', 'NNP'), (u'got', 'VBD'), (u'off', 'RP'), (u'message', 'NN'), (u'and', 'CC'), (u'to', 'TO'), (u'many', 'JJ'), (u'campaign', 'NN'), (u'watchers', 'NNS'), (u'stayed', 'VBD'), (u'that', 'IN'), (u'way', 'NN'), (u'all', 'DT'), (u'week', 'NN'), (u'.', '.'), (u'So', 'RB'), (u'this', 'DT'), (u'afternoon', 'NN'), (u'under', 'IN'), (u'pressure', 'NN'), (u'from', 'IN'), (u'the', 'DT'), (u'party', 'NN'), (u'and', 'CC'), (u'trailing', 'VBG'), (u'in', 'IN'), (u'a', 'DT'), (u'new', 'JJ'), (u'batch', 'NN'), (u'of', 'IN'), (u'polling', 'VBG'), (u'in', 'IN'), (u'key', 'JJ'), (u'battleground', 'NN'), (u'states', 'NNS'), (u'Trump', 'NNP'), (u'stepped', 'VBD'), (u'to', 'TO'), (u'the', 'DT'), (u'microphone', 'NN'), (u'looked', 'VBD'), (u'into', 'IN'), (u'the', 'DT'), (u'teleprompter', 'NN'), (u'and', 'CC'), (u'started', 'VBD'), (u'reading', 'NN'), (u'.', '.'), (u'CNN', 'NNP'), (u"'s", 'POS'), (u'Sara', 'NNP'), (u'Murray', 'NNP'), (u'reports', 'VBZ'), (u'.', '.'), (u'(', ':'), Tree('speaker', [(u'BEGIN', 'NNP'), (u'VIDEOTAPE', 'NNP'), (u')', 'NNP'), (u'SARA', 'NNP'), (u'MURRAY', 'NNP'), (u'CNN', 'NNP'), (u'POLITICS', 'NNP'), (u'REPORTER', 'NNP'), (u'(', 'NNP'), (u'voice-over', 'NNP'), (u')', 'NNP'), (u':', ':')]), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u'battling', 'NN'), (u'to', 'TO'), (u'take', 'VB'), (u'control', 'NN'), (u'of', 'IN'), (u'his', 'PRP$'), (u'campaign', 'NN'), (u'message', 'NN'), (u'by', 'IN'), (u'laying', 'NN'), (u'out', 'IN'), (u'his', 'PRP$'), (u'vision', 'NN'), (u'to', 'TO'), (u'defeat', 'VB'), (u'ISIS', 'NNP'), (u'.', '.'), Tree('speaker', [(u'DONALD', 'NNP'), (u'TRUMP', 'NNP'), (u'(', 'NNP'), (u'R', 'NNP'), (u')', 'NNP'), (u'PRESIDENTIAL', 'NNP'), (u'NOMINEE', 'NNP'), (u':', ':')]), (u'We', 'PRP'), (u'can', 'MD'), (u'not', 'RB'), (u'let', 'VB'), (u'this', 'DT'), (u'evil', 'JJ'), (u'continue', 'NN'), (u'.', '.'), Tree('speaker', [(u'MURRAY', 'NNP'), (u':', ':')]), (u'Trump', 'NNP'), (u'looking', 'NN'), (u'to', 'TO'), (u'rebound', 'VB'), (u'from', 'IN'), (u'a', 'DT'), (u'rocky', 'JJ'), (u'stretch', 'NN'), (u'and', 'CC'), (u'ginning', 'VBG'), (u'up', 'RP'), (u'doubts', 'NNS'), (u'about', 'IN'), (u'Hillary', 'NNP'), (u'Clinton', 'NNP'), (u"'s", 'POS'), (u'foreign', 'JJ'), (u'policy', 'NN'), (u'chops', 'NNS'), (u'.', '.'), Tree('speaker', [(u'TRUMP', 'NNP'), (u':', ':')]), (u'With', 'IN'), (u'one', 'CD'), (u'episode', 'NN'), (u'of', 'IN'), (u'bad', 'JJ'), (u'judgment', 'NN'), (u'after', 'IN'), (u'another', 'DT'), (u'Hillary', 'NNP'), (u'Clinton', 'NNP'), (u"'s", 'POS'), (u'policies', 'NNS'), (u'launched', 'VBD'), (u'ISIS', 'NNP'), (u'on', 'IN'), (u'to', 'TO'), (u'the', 'DT'), (u'world', 'NN'), (u'stage', 'NN'), (u'.', '.'), (u'Things', 'NNS'), (u'turned', 'VBD'), (u'out', 'RP'), (u'really', 'RB'), (u'to', 'TO'), (u'be', 'VB'), (u'not', 'RB'), (u'so', 'RB'), (u'hot', 'JJ'), (u'for', 'IN'), (u'our', 'PRP$'), (u'world', 'NN'), (u'and' ...
#  Tree('S', [(u')', 'NN'), (u'[', '``'), (u'20:16:13', 'CD'), (u']', 'CD'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'We', 'PRP'), (u'are', 'VBP'), (u'talking', 'VBG'), (u'about', 'IN'), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u"'s", 'POS'), (u'second', 'JJ'), (u'campaign', 'NN'), (u'the', 'DT'), (u'last', 'JJ'), (u'two', 'CD'), (u'weeks', 'NNS'), (u'and', 'CC'), (u'the', 'DT'), (u'pressure', 'NN'), (u'that', 'IN'), (u'he', 'PRP'), (u'is', 'VBZ'), (u'under', 'IN'), (u'to', 'TO'), (u'stay', 'VB'), (u'focus', 'NN'), (u'today', 'NN'), (u'in', 'IN'), (u'Ohio', 'NNP'), (u'.', '.'), (u'He', 'PRP'), (u'stuck', 'VBD'), (u'to', 'TO'), (u'a', 'DT'), (u'script', 'NN'), (u'and', 'CC'), (u'took', 'VBD'), (u'the', 'DT'), (u'advice', 'NN'), (u'to', 'TO'), (u'those', 'DT'), (u'who', 'WP'), (u'wanted', 'VBN'), (u'him', 'PRP'), (u'to', 'TO'), (u'appear', 'VB'), (u'more', 'JJR'), (u'presidential', 'JJ'), (u'advice', 'NN'), (u'he', 'PRP'), (u"'s", 'VBZ'), (u'belittled', 'VBN'), (u'on', 'IN'), (u'occasion', 'NN'), (u'.', '.'), (u'Last', 'JJ'), (u'April', 'NNP'), (u'he', 'PRP'), (u'told', 'VBD'), (u'a', 'DT'), (u'crowd', 'NN'), (u'in', 'IN'), (u'Harrisburg', 'NNP'), (u'Pennsylvania', 'NNP'), (u'that', 'IN'), (u'one', 'CD'), (u'day', 'NN'), (u'he', 'PRP'), (u'will', 'MD'), (u'be', 'VB'), (u'so', 'RB'), (u'presidential', 'JJ'), (u'that', 'IN'), (u'he', 'PRP'), (u'will', 'MD'), (u'bore', 'VB'), (u'people', 'NNS'), (u'and', 'CC'), (u'they', 'PRP'), (u'will', 'MD'), (u'stop', 'VB'), (u'coming', 'VBG'), (u'to', 'TO'), (u'his', 'PRP$'), (u'rallies', 'NNS'), (u'.', '.'), (u'The', 'DT'), (u'question', 'NN'), (u'tonight', 'NN'), (u'what', 'WP'), (u'did', 'VBD'), (u'the', 'DT'), (u'crowd', 'NN'), (u'in', 'IN'), (u'Youngstown', 'NNP'), (u'Ohio', 'NNP'), (u'make', 'VBP'), (u'of', 'IN'), (u'what', 'WP'), (u'they', 'PRP'), (u'heard', 'VBP'), (u'today', 'NN'), (u'?', '.'), (u'More', 'NNP'), (u'in', 'IN'), (u'that', 'DT'), (u'from', 'IN'), (u'our', 'PRP$'), (u'Gary', 'NNP'), (u'Tuchman', 'NNP'), (u'.', '.'), (u'(', ':'), Tree('speaker', [(u'BEGIN', 'NNP'), (u'VIDEOTAPE', 'NNP'), (u')', 'NNP'), (u'GARY', 'NNP'), (u'TUCHMAN', 'NNP'), (u'CNN', 'NNP'), (u'CORRESPONDENT', 'NNP'), (u'(', 'NNP'), (u'voice-over', 'NNP'), (u')', 'NNP'), (u':', ':')]), (u'An', 'DT'), (u'invitation', 'NN'), (u'only', 'RB'), (u'crowd', 'JJ'), (u'of', 'IN'), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u'supporters', 'NNS'), (u'waiting', 'VBG'), (u'out', 'RP'), (u'in', 'IN'), (u'the', 'DT'), (u'Ohio', 'NNP'), (u'rain', 'NN'), (u'waiting', 'VBG'), (u'to', 'TO'), (u'find', 'VB'), (u'out', 'RP'), (u'how', 'WRB'), (u'he', 'PRP'), (u'plans', 'VBZ'), (u'to', 'TO'), (u'keep', 'VB'), (u'them', 'PRP'), (u'safe', 'VB'), (u'.', '.'), Tree('speaker', [(u'ROBIN', 'NNP'), (u'MCCORMACK', 'NNP'), (u'TRUMP', 'NNP'), (u'SUPPORTER', 'NNP'), (u':', ':')]), (u'This', 'DT'), (u'has', 'VBZ'), (u'to', 'TO'), (u'stop', 'VB'), (u'.', '.'), (u'We', 'PRP'), (u"'ve", 'VBP'), (u'got', 'VBN'), (u'to', 'TO'), (u'stop', 'VB'), (u'being', 'VBG'), (u'victims', 'NNS'), (u'.', '.'), (u'We', 'PRP'), (u"'ve", 'VBP'), (u'got', 'VBN'), (u'to', 'TO'), (u'stop', 'VB'), (u'being', 'VBG'), (u'gentle', 'NN'), (u'.', '.'), (u'TUCHMAN', 'NN'), (u':', ':'), (u'This', 'DT'), (u'woman', 'NN'), (u'says', 'VBZ'), (u'America', 'NNP'), (u'has', 'VBZ'), (u'to', 'TO'), (u'do', 'VB'), (u'what', 'WP'), (u'America', 'NNP'), (u'has', 'VBZ'), (u'to', 'TO'), (u'do', 'VB'), (u'.', '.'), (u'So', 'RB'), (u'does', 'VBZ'), (u'that', 'IN'), (u'include', 'NN'), (u'waterboarding', 'VBG'), (u'at', 'IN'), (u'your', 'PRP$'), (u'estimation', 'NN'), (u'and', 'CC'), (u'hence', 'NN'), (u'interrogation', 'NN'), (u'techniques', 'NNS'), (u'?', '.'), Tree('speaker', [(u'MCCORMACK', 'NNP'), (u':', ':')]), (u'I', 'PRP'), (u"'m", 'VBP'), (u'not', 'RB'), (u'opposed', 'VBN'), (u'to', 'TO'), (u'it', 'PRP'), (u'.', '.'), Tree('speaker', [(u'TUCHMAN', 'NNP'), (u':', ':')]), (u'And', 'CC'), (u'then', 'RB'), (u'there', 'RB'), (u'was', 'VBD'), (u'this', 'DT'), (u'quote', 'NN'),  ...
#  Tree('S', [(u')', 'NN'), (u'[', '``'), (u'20:33:18', 'CD'), (u']', 'CD'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'Welcome', 'NNP'), (u'back', 'RB'), (u'.', '.'), (u'Hillary', 'NNP'), (u'Clinton', 'NNP'), (u'had', 'VBD'), (u'some', 'DT'), (u'company', 'NN'), (u'on', 'IN'), (u'the', 'DT'), (u'campaign', 'NN'), (u'trail', 'NN'), (u'in', 'IN'), (u'Pennsylvania', 'NNP'), (u'today', 'NN'), (u'some', 'DT'), (u'help', 'NN'), (u'slamming', 'VBG'), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u'for', 'IN'), (u'the', 'DT'), (u'first', 'JJ'), (u'time', 'NN'), (u'vice', 'NN'), (u'president', 'NN'), (u'Joe', 'NNP'), (u'Biden', 'NNP'), (u'hit', 'VBD'), (u'the', 'DT'), (u'trail', 'NN'), (u'with', 'IN'), (u'Hillary', 'NNP'), (u'Clinton', 'NNP'), (u'.', '.'), (u'They', 'PRP'), (u'spoke', 'VBP'), (u'at', 'IN'), (u'a', 'DT'), (u'rally', 'RB'), (u'in', 'IN'), (u'Scranton', 'NNP'), (u'Pennsylvania', 'NNP'), (u'.', '.'), (u'Biden', 'NNP'), (u'said', 'VBD'), (u'Trump', 'NNP'), (u'ca', 'MD'), (u"n't", 'RB'), (u'be', 'VB'), (u'trusted', 'VBN'), (u'and', 'CC'), (u'is', 'VBZ'), (u'quote', 'JJ'), (u'``', '``'), (u'Totally', 'RB'), (u'unqualified', 'VBN'), (u'to', 'TO'), (u'be', 'VB'), (u'president', 'NN'), (u"''", "''"), (u'.', '.'), (u'Clinton', 'NNP'), (u'who', 'WP'), (u"'s", 'POS'), (u'already', 'RB'), (u'down', 'IN'), (u'what', 'WP'), (u'she', 'PRP'), (u'calls', 'VBZ'), (u'the', 'DT'), (u'Trump', 'NNP'), (u'loophole', 'NN'), (u'in', 'IN'), (u'his', 'PRP$'), (u'tax', 'NN'), (u'plan', 'NN'), (u'and', 'CC'), (u'when', 'WRB'), (u'she', 'PRP'), (u'said', 'VBD'), (u'would', 'MD'), (u'only', 'RB'), (u'benefit', 'VB'), (u'people', 'NNS'), (u'like', 'IN'), (u'him', 'PRP'), (u'.', '.'), (u'(', ':'), Tree('speaker', [(u'BEGIN', 'NNP'), (u'VIDEO', 'NNP'), (u'CLIP', 'NNP'), (u')', 'NNP'), (u'HILLARY', 'NNP'), (u'CLINTON', 'NNP'), (u'(', 'NNP'), (u'D', 'NNP'), (u')', 'NNP'), (u'PRESIDENTIAL', 'NNP'), (u'NOMINEE', 'NNP'), (u':', ':')]), (u'He', 'PRP'), (u'would', 'MD'), (u'end', 'VB'), (u'up', 'RP'), (u'paying', 'VBG'), (u'a', 'DT'), (u'rate', 'NN'), (u'lower', 'JJR'), (u'than', 'IN'), (u'millions', 'NNS'), (u'of', 'IN'), (u'middle', 'JJ'), (u'class', 'NN'), (u'families', 'NNS'), (u'.', '.'), (u'Now', 'RB'), (u'that', 'IN'), (u'is', 'VBZ'), (u'assuming', 'VBG'), (u'he', 'PRP'), (u'pays', 'VBZ'), (u'any', 'DT'), (u'taxes', 'NNS'), (u'at', 'IN'), (u'all', 'DT'), (u'because', 'IN'), (u'we', 'PRP'), (u'really', 'RB'), (u'do', 'VBP'), (u"n't", 'RB'), (u'know', 'VB'), (u'since', 'IN'), (u'we', 'PRP'), (u'have', 'VBP'), (u"n't", 'RB'), (u'seen', 'VBN'), (u'his', 'PRP$'), (u'tax', 'NN'), (u'return', 'NN'), (u'.', '.'), (u'(', 'NN'), (u'END', 'NN'), Tree('speaker', [(u'VIDEO', 'NNP'), (u'CLIP', 'NNP'), (u')', 'NNP'), (u'COOPER', 'NNP'), (u':', ':')]), (u'While', 'IN'), (u'his', 'PRP$'), (u'polling', 'NN'), (u'shows', 'VBZ'), (u'Clinton', 'NNP'), (u'leading', 'VBG'), (u'Trump', 'NNP'), (u'by', 'IN'), (u'double', 'JJ'), (u'digits', 'NNS'), (u'.', '.'), (u'In', 'IN'), (u'Pennsylvania', 'NNP'), (u'a', 'DT'), (u'new', 'JJ'), (u'NBC', 'NNP'), (u'News/Wall', 'NNP'), (u'Street', 'NNP'), (u'Journal/Marris', 'NNP'), (u'poll', 'NN'), (u'in', 'IN'), (u'four', 'CD'), (u'key', 'JJ'), (u'battleground', 'NN'), (u'states', 'NNS'), (u'shows', 'VBZ'), (u'an', 'DT'), (u'up', 'NN'), (u'hill', 'NN'), (u'run', 'VBN'), (u'for', 'IN'), (u'Trump', 'NNP'), (u'.', '.'), (u'Our', 'NNP'), (u'``', '``'), (u'Inside', 'NNP'), (u'Politics', 'NNP'), (u"''", "''"), (u'anchor', 'NN'), (u'John', 'NNP'), (u'King', 'NNP'), (u'shows', 'VBZ'), (u'now', 'RB'), (u'the', 'DT'), (u'breaking', 'NN'), (u'``', '``'), (u'By', 'IN'), (u'the', 'DT'), (u'Numbers', 'NNP'), (u"''", "''"), (u'.', '.'), (u'So', 'RB'), (u'the', 'DT'), (u'new', 'JJ'), (u'battleground', 'NN'), (u'state', 'NN'), (u'polls', 'NNS'), (u'I', 'PRP'), (u'mean', 'VBP'), (u'is', 'VBZ'), (u'it', 'PRP'), (u'all', 'DT'), (u'bad', 'JJ'), (u'news', 'NN'), (u'for', 'IN'), (u'Trump', 'NNP'), (u'?', '.'), (u'Or', 'CC'), (u'what', 'WP'), (u'do', 'VBP'), (u' ...
#  Tree('S', [(u')', 'NN'), (u'[', '``'), (u'20:41:26', 'CD'), (u']', 'CD'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'It', 'PRP'), (u"'s", 'VBZ'), (u'an', 'DT'), (u'ominous', 'JJ'), (u'sounding', 'NN'), (u'report', 'NN'), (u'that', 'WDT'), (u'the', 'DT'), (u'head', 'NN'), (u'of', 'IN'), (u'Donald', 'NNP'), (u'Trump', 'NNP'), (u"'s", 'POS'), (u'campaign', 'NN'), (u'and', 'CC'), (u'Paul', 'NNP'), (u'Manafort', 'NNP'), (u'could', 'MD'), (u'have', 'VB'), (u'illegally', 'RB'), (u'received', 'VBN'), (u'millions', 'NNS'), (u'in', 'IN'), (u'secret', 'NN'), (u'cash', 'NN'), (u'from', 'IN'), (u'Ukraine', 'NNP'), (u"'s", 'POS'), (u'former', 'JJ'), (u'pro-Russian', 'JJ'), (u'ruling', 'NN'), (u'party', 'NN'), (u'.', '.'), (u'Ukrainian', 'JJ'), (u'authorities', 'NNS'), (u'they', 'PRP'), (u'are', 'VBP'), (u'investigating', 'VBG'), (u'.', '.'), (u'Hillary', 'NNP'), (u'Clinton', 'NNP'), (u"'s", 'POS'), (u'campaign', 'NN'), (u'manager', 'NN'), (u'is', 'VBZ'), (u'calling', 'VBG'), (u'on', 'IN'), (u'Trump', 'NNP'), (u'to', 'TO'), (u'disclose', 'VB'), (u'any', 'DT'), (u'in', 'IN'), (u'all', 'DT'), (u'campaign', 'NN'), (u'connections', 'NNS'), (u'to', 'TO'), (u'Russia', 'NNP'), (u'and', 'CC'), (u'Manafort', 'NNP'), (u'himself', 'PRP'), (u'is', 'VBZ'), (u'responded', 'VBN'), (u'.', '.'), (u'The', 'DT'), (u'``', '``'), (u'New', 'NNP'), (u'York', 'NNP'), (u'Times', 'NNP'), (u"''", "''"), (u'broke', 'NN'), (u'the', 'DT'), (u'story', 'NN'), (u'.', '.'), (u'We', 'PRP'), (u"'ll", 'MD'), (u'hear', 'VB'), (u'from', 'IN'), (u'one', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'reporters', 'NNS'), (u'in', 'IN'), (u'a', 'DT'), (u'moment', 'NN'), (u'.', '.'), (u'But', 'CC'), (u'first', 'RB'), (u'our', 'PRP$'), (u'Senior', 'NNP'), (u'Investigative', 'NNP'), (u'Correspondent', 'NNP'), (u'Drew', 'NNP'), (u'Griffin', 'NNP'), (u'has', 'VBZ'), (u'been', 'VBN'), (u'digging', 'VBG'), (u'and', 'CC'), (u'joins', 'NNS'), (u'us', 'PRP'), (u'now', 'RB'), (u'with', 'IN'), (u'what', 'WP'), (u'he', 'PRP'), (u'has', 'VBZ'), (u'found', 'VBN'), (u'.', '.'), (u'Drew', 'NNP'), (u'still', 'RB'), (u'a', 'DT'), (u'lot', 'NN'), (u'of', 'IN'), (u'unknowns', 'NNS'), (u'here', 'RB'), (u'help', 'VB'), (u'fill', 'RB'), (u'in', 'IN'), (u'some', 'DT'), (u'of', 'IN'), (u'what', 'WP'), (u'thus', 'RB'), (u'reporting', 'VBG'), (u'about', 'IN'), (u'the', 'DT'), (u'``', '``'), (u'New', 'NNP'), (u'York', 'NNP'), (u'Times', 'NNP'), (u"''", "''"), (u'for', 'IN'), (u'show', 'NN'), (u'.', '.'), (u'What', 'WP'), (u'do', 'VBP'), (u'we', 'PRP'), (u'know', 'VB'), (u'at', 'IN'), (u'this', 'DT'), (u'stage', 'NN'), (u'?', '.'), Tree('speaker', [(u'DREW', 'NNP'), (u'GRIFFIN', 'NNP'), (u'CNN', 'NNP'), (u'SENIOR', 'NNP'), (u'INVESTIGATOR', 'NNP'), (u'CORRESPONDENT', 'NNP'), (u':', ':')]), (u'This', 'DT'), (u'is', 'VBZ'), (u'what', 'WP'), (u'we', 'PRP'), (u'know', 'VBP'), (u'.', '.'), (u'Paul', 'NNP'), (u'Manafort', 'NNP'), (u'worked', 'VBD'), (u'for', 'IN'), (u'the', 'DT'), (u'past', 'JJ'), (u'government', 'NN'), (u'of', 'IN'), (u'Ukraine', 'NNP'), (u'.', '.'), (u'That', 'DT'), (u'past', 'JJ'), (u'government', 'NN'), (u'is', 'VBZ'), (u'now', 'RB'), (u'under', 'IN'), (u'investigation', 'NN'), (u'for', 'IN'), (u'what', 'WP'), (u'it', 'PRP'), (u'did', 'VBD'), (u'with', 'IN'), (u'a', 'DT'), (u'lot', 'NN'), (u'of', 'IN'), (u'money', 'NN'), (u'a', 'DT'), (u'lot', 'NN'), (u'of', 'IN'), (u'corruption', 'NN'), (u'.', '.'), (u'And', 'CC'), (u'there', 'EX'), (u"'s", 'VBZ'), (u'an', 'DT'), (u'actual', 'JJ'), (u'Anti-Corruption', 'NN'), (u'Bureau', 'NNP'), (u'that', 'IN'), (u'was', 'VBD'), (u'began', 'VBD'), (u'by', 'IN'), (u'the', 'DT'), (u'government', 'NN'), (u'of', 'IN'), (u'Ukraine', 'NNP'), (u'.', '.'), (u'But', 'CC'), (u'look', 'VB'), (u'at', 'IN'), (u'all', 'DT'), (u'this', 'DT'), (u'.', '.'), (u'They', 'PRP'), (u'began', 'VBD'), (u'looking', 'VBG'), (u'and', 'CC'), (u'they', 'PRP'), (u'dug', 'VBP'), (u'up', 'RP'), (u'this', 'DT'), (u'black', 'NN'), (u'ledger', 'NN'), (u'they', 'PRP'), (u'call', 'VBP'), (u'it', ...
#  Tree('S', [(u')', 'NN'), (u'[', '``'), (u'20:52:13', 'CD'), (u']', 'CD'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'A', 'DT'), (u'devastating', 'NN'), (u'flooding', 'VBG'), (u'has', 'VBZ'), (u'killed', 'VBN'), (u'at', 'IN'), (u'least', 'JJS'), (u'five', 'CD'), (u'people', 'NNS'), (u'in', 'IN'), (u'Louisiana', 'NNP'), (u'.', '.'), (u'The', 'DT'), (u'governor', 'NN'), (u'expects', 'VBZ'), (u'30', 'CD'), (u'parishes', 'NNS'), (u'will', 'MD'), (u'be', 'VB'), (u'declared', 'VBN'), (u'a', 'DT'), (u'major', 'JJ'), (u'disaster', 'NN'), (u'.', '.'), (u'That', 'DT'), (u"'s", 'VBZ'), (u'of', 'IN'), (u'half', 'PDT'), (u'the', 'DT'), (u'number', 'NN'), (u'of', 'IN'), (u'parishes', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'entire', 'JJ'), (u'state', 'NN'), (u'.', '.'), (u'Streets', 'NNS'), (u'and', 'CC'), (u'rivers', 'NNS'), (u'in', 'IN'), (u'some', 'DT'), (u'places', 'NNS'), (u'homes', 'VBZ'), (u'are', 'VBP'), (u'now', 'RB'), (u'islands', 'NNS'), (u'.', '.'), (u'More', 'RBR'), (u'than', 'IN'), (u'20000', 'CD'), (u'people', 'NNS'), (u'have', 'VBP'), (u'been', 'VBN'), (u'rescued', 'VBN'), (u'.', '.'), (u'The', 'DT'), (u'coast', 'NN'), (u'guard', 'NN'), (u'first', 'RB'), (u'responders', 'NNS'), (u'volunteers', 'NNS'), (u'are', 'VBP'), (u'helping', 'VBG'), (u'those', 'DT'), (u'trapped', 'JJ'), (u'in', 'IN'), (u'flood', 'NN'), (u'waters', 'NNS'), (u'trying', 'VBG'), (u'to', 'TO'), (u'get', 'VB'), (u'to', 'TO'), (u'dry', 'VB'), (u'land', 'NN'), (u'.', '.'), (u'Take', 'NNP'), (u'a', 'DT'), (u'look', 'NN'), (u'.', '.'), (u'(', 'NN'), Tree('speaker', [(u'BEGIN', 'NNP'), (u'VIDEO', 'NNP'), (u'CLIP', 'NNP'), (u')', 'NNP'), (u'COOPER', 'NNP'), (u':', ':')]), (u'Rescues', 'NNPS'), (u'by', 'IN'), (u'boat', 'JJ'), (u'from', 'IN'), (u'the', 'DT'), (u'air', 'NN'), (u'even', 'RB'), (u'from', 'IN'), (u'underneath', 'NN'), (u'the', 'DT'), (u'flood', 'NN'), (u'waters', 'NNS'), (u'.', '.'), Tree('speaker', [(u'UNIDENTIFIED', 'NNP'), (u'MALE', 'NNP'), (u':', ':')]), (u'Get', 'NNP'), (u'out', 'IN'), (u'!', '.'), Tree('speaker', [(u'UNIDENTIFIED', 'NNP'), (u'FEMALE', 'NNP'), (u':', ':')]), (u'I', 'PRP'), (u"'m", 'VBP'), (u'trying', 'VBG'), (u'!', '.'), Tree('speaker', [(u'UNIDENTIFIED', 'NNP'), (u'MALE', 'NNP'), (u':', ':')]), (u'Give', 'JJ'), (u'me', 'PRP'), (u'a', 'DT'), (u'knife', 'NN'), (u'.', '.'), (u'Give', 'NNP'), (u'me', 'PRP'), (u'a', 'DT'), (u'knife', 'NN'), (u'.', '.'), (u'Give', 'NNP'), (u'me', 'PRP'), (u'a', 'DT'), (u'knife', 'NN'), (u'.', '.'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'This', 'DT'), (u'rescue', 'NN'), (u'crew', 'VBD'), (u'in', 'IN'), (u'Baton', 'NNP'), (u'Rouge', 'NNP'), (u'found', 'VBD'), (u'a', 'DT'), (u'car', 'NN'), (u'which', 'WDT'), (u'was', 'VBD'), (u'quickly', 'RB'), (u'sinking', 'VBG'), (u'.', '.'), (u'The', 'DT'), (u'drives', 'NNS'), (u'was', 'VBD'), (u'trapped', 'VBN'), (u'inside', 'NN'), (u'.', '.'), (u'You', 'PRP'), (u'hear', 'VB'), (u'her', 'PRP$'), (u'calling', 'NN'), (u'for', 'IN'), (u'help', 'NN'), (u'.', '.'), Tree('speaker', [(u'UNIDENTIFIED', 'NNP'), (u'FEMALE', 'NNP'), (u':', ':')]), (u'Oh', 'NNP'), (u'my', 'PRP$'), (u'god', 'NN'), (u'I', 'PRP'), (u"'m", 'VBP'), (u'drowning', 'VBG'), (u'.', '.'), Tree('speaker', [(u'UNIDENTIFIED', 'NNP'), (u'MALE', 'NNP'), (u':', ':')]), (u'We', 'PRP'), (u"'re", 'VBP'), (u'coming', 'VBG'), (u'.', '.'), (u'We', 'PRP'), (u"'re", 'VBP'), (u'coming', 'VBG'), (u'.', '.'), (u'We', 'PRP'), (u"'re", 'VBP'), (u'breaking', 'VBG'), (u'the', 'DT'), (u'window', 'NN'), (u'.', '.'), Tree('speaker', [(u'COOPER', 'NNP'), (u':', ':')]), (u'But', 'CC'), (u'with', 'IN'), (u'the', 'DT'), (u'car', 'NN'), (u'now', 'RB'), (u'almost', 'RB'), (u'completely', 'RB'), (u'under', 'IN'), (u'water', 'NN'), (u'one', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'rescuers', 'NNS'), (u'David', 'NNP'), (u'Phung', 'NNP'), (u'jumps', 'VBZ'), (u'in', 'IN'), (u'the', 'DT'), (u'water', 'NN'), (u'.', '.'), (u'Grabbing', 'NNP'), (u'the', 'DT'), (u'driver', 'NN'), (u"'s", 'POS'), (u'arm', 'NN'), (u'and' ...
#  Tree('S', [(u')', 'NN')])]

# %%
for tree in speakers[0].subtrees():
    if tree.label()=="speaker":
        print(tree)
# Out:
# (speaker ANDERSON/NNP COOPER/NNP CNN/NNP ANCHOR/NNP :/:)
# (speaker
#   BEGIN/NNP
#   VIDEOTAPE/NNP
#   )/NNP
#   SARA/NNP
#   MURRAY/NNP
#   CNN/NNP
#   POLITICS/NNP
#   REPORTER/NNP
#   (/NNP
#   voice-over/NNP
#   )/NNP
#   :/:)
# (speaker
#   DONALD/NNP
#   TRUMP/NNP
#   (/NNP
#   R/NNP
#   )/NNP
#   PRESIDENTIAL/NNP
#   NOMINEE/NNP
#   :/:)
# (speaker MURRAY/NNP :/:)
# (speaker TRUMP/NNP :/:)
# (speaker MURRAY/NNP :/:)
# (speaker TRUMP/NNP :/:)
# (speaker MURRAY/NNP :/:)
# (speaker TRUMP/NNP :/:)
# (speaker MURRAY/NNP :/:)
# (speaker TRUMP/NNP :/:)
# (speaker MURRAY/NNP :/:)
# (speaker TRUMP/NNP :/:)
# (speaker COOPER/NNP :/:)
# (speaker MURRAY/NNP :/:)
# (speaker Mike/NNP Pence/NNP --/:)
# (speaker COOPER/NNP :/:)
# (speaker Sara/NNP Murray/NNP --/:)
# (speaker
#   COREY/NNP
#   LEWANDOWSKI/NNP
#   CNN/NNP
#   POLITICAL/NNP
#   COMMENTATOR/NNP
#   :/:)
# (speaker COOPER/NNP :/:)
# (speaker
#   REP./NNP
#   SETH/NNP
#   MOULTON/NNP
#   (/NNP
#   D/NNP
#   )/NNP
#   MASSACHUSETTS/NNP
#   :/:)
# (speaker COOPER/NNP :/:)
# (speaker MOULTON/NNP :/:)
# (speaker COOPER/NNP :/:)
# (speaker
#   CLARISSA/NNP
#   WARD/NNP
#   CNN/NNP
#   SENIOR/NNP
#   INTERNATIONAL/NNP
#   CORRESPONDENT/NNP
#   :/:)
# (speaker COOPER/NNP :/:)
# (speaker LEWANDOWSKI/NNP :/:)
# (speaker COOPER/NNP :/:)
# (speaker LEWANDOWSKI/NNP :/:)
# (speaker COOPER/NNP :/:)
# (speaker MOULTON/NNP :/:)
# (speaker COOPER/NNP :/:)

# %%
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
sentences = sent_detector.tokenize(transcript)

# %%
words = [nltk.word_tokenize(sent) for sent in sentences]
words
# Out:
# [[u'[',
#   u'20:00:21',
#   u']',
#   u'ANDERSON',
#   u'COOPER',
#   u'CNN',
#   u'ANCHOR',
#   u':',
#   u'Good',
#   u'evening',
#   u'.'],
#  [u'Thanks', u'for', u'joining', u'us', u'.'],
#  [u'Tonight',
#   u'Donald',
#   u'Trump',
#   u'on',
#   u'prompter',
#   u'and',
#   u'on',
#   u'message',
#   u'for',
#   u'a',
#   u'second',
#   u'straight',
#   u'Monday',
#   u'this',
#   u'time',
#   u'laying',
#   u'out',
#   u'his',
#   u'plan',
#   u'for',
#   u'defeating',
#   u'ISIS',
#   u'.'],
#  [u'And',
#   u'for',
#   u'a',
#   u'second',
#   u'straight',
#   u'Monday',
#   u'Republicans',
#   u'holding',
#   u'their',
#   u'breath',
#   u'hoping',
#   u'tomorrow',
#   u'wo',
#   u"n't",
#   u'be',
#   u'another',
#   u'Tuesday',
#   u'like',
#   u'last',
#   u'Tuesday',
#   u'when',
#   u'Trump',
#   u'got',
#   u'off',
#   u'message',
#   u'and',
#   u'to',
#   u'many',
#   u'campaign',
#   u'watchers',
#   u'stayed',
#   u'that',
#   u'way',
#   u'all',
#   u'week',
#   u'.'],
#  [u'So',
#   u'this',
#   u'afternoon',
#   u'under',
#   u'pressure',
#   u'from',
#   u'the',
#   u'party',
#   u'and',
#   u'trailing',
#   u'in',
#   u'a',
#   u'new',
#   u'batch',
#   u'of',
#   u'polling',
#   u'in',
#   u'key',
#   u'battleground',
#   u'states',
#   u'Trump',
#   u'stepped',
#   u'to',
#   u'the',
#   u'microphone',
#   u'looked',
#   u'into',
#   u'the',
#   u'teleprompter',
#   u'and',
#   u'started',
#   u'reading',
#   u'.'],
#  [u'CNN', u"'s", u'Sara', u'Murray', u'reports', u'.'],
#  [u'(',
#   u'BEGIN',
#   u'VIDEOTAPE',
#   u')',
#   u'SARA',
#   u'MURRAY',
#   u'CNN',
#   u'POLITICS',
#   u'REPORTER',
#   u'(',
#   u'voice-over',
#   u')',
#   u':',
#   u'Donald',
#   u'Trump',
#   u'battling',
#   u'to',
#   u'take',
#   u'control',
#   u'of',
#   u'his',
#   u'campaign',
#   u'message',
#   u'by',
#   u'laying',
#   u'out',
#   u'his',
#   u'vision',
#   u'to',
#   u'defeat',
#   u'ISIS',
#   u'.'],
#  [u'DONALD',
#   u'TRUMP',
#   u'(',
#   u'R',
#   u')',
#   u'PRESIDENTIAL',
#   u'NOMINEE',
#   u':',
#   u'We',
#   u'can',
#   u'not',
#   u'let',
#   u'this',
#   u'evil',
#   u'continue',
#   u'.'],
#  [u'MURRAY',
#   u':',
#   u'Trump',
#   u'looking',
#   u'to',
#   u'rebound',
#   u'from',
#   u'a',
#   u'rocky',
#   u'stretch',
#   u'and',
#   u'ginning',
#   u'up',
#   u'doubts',
#   u'about',
#   u'Hillary',
#   u'Clinton',
#   u"'s",
#   u'foreign',
#   u'policy',
#   u'chops',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'With',
#   u'one',
#   u'episode',
#   u'of',
#   u'bad',
#   u'judgment',
#   u'after',
#   u'another',
#   u'Hillary',
#   u'Clinton',
#   u"'s",
#   u'policies',
#   u'launched',
#   u'ISIS',
#   u'on',
#   u'to',
#   u'the',
#   u'world',
#   u'stage',
#   u'.'],
#  [u'Things',
#   u'turned',
#   u'out',
#   u'really',
#   u'to',
#   u'be',
#   u'not',
#   u'so',
#   u'hot',
#   u'for',
#   u'our',
#   u'world',
#   u'and',
#   u'our',
#   u'country',
#   u'.'],
#  [u'MURRAY',
#   u':',
#   u'Even',
#   u'questioning',
#   u'whether',
#   u'she',
#   u"'s",
#   u'physically',
#   u'fit',
#   u'to',
#   u'be',
#   u'commander',
#   u'in',
#   u'chief',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'She',
#   u'also',
#   u'lacks',
#   u'the',
#   u'mental',
#   u'and',
#   u'physical',
#   u'stamina',
#   u'to',
#   u'take',
#   u'on',
#   u'ISIS',
#   u'and',
#   u'all',
#   u'of',
#   u'the',
#   u'many',
#   u'adversaries',
#   u'we',
#   u'face',
#   u'.'],
#  [u'MURRAY',
#   u':',
#   u'The',
#   u'billionaire',
#   u'businessman',
#   u'calling',
#   u'on',
#   u'the',
#   u'U.S.',
#   u'to',
#   u'abandon',
#   u'the',
#   u'attempts',
#   u'at',
#   u'nation',
#   u'building',
#   u'and',
#   u'saying',
#   u'it',
#   u"'s",
#   u'time',
#   u'to',
#   u'focus',
#   u'on',
#   u'fighting',
#   u'ISIS',
#   u'on',
#   u'all',
#   u'fronts',
#   u'.'],
#  [u'The',
#   u'GOP',
#   u'nominee',
#   u'framing',
#   u'it',
#   u'as',
#   u'an',
#   u'ideological',
#   u'war',
#   u'harkening',
#   u'going',
#   u'back',
#   u'to',
#   u'the',
#   u'day',
#   u'of',
#   u'George',
#   u'W.',
#   u'Bush',
#   u'as',
#   u'he',
#   u'called',
#   u'on',
#   u'the',
#   u'U.S.',
#   u'to',
#   u'team',
#   u'up',
#   u'with',
#   u'any',
#   u'ally',
#   u'willing',
#   u'to',
#   u'help',
#   u'battle',
#   u'ISIS',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'We',
#   u'can',
#   u'not',
#   u'always',
#   u'choose',
#   u'our',
#   u'friends',
#   u'but',
#   u'we',
#   u'can',
#   u'never',
#   u'fail',
#   u'to',
#   u'recognize',
#   u'our',
#   u'enemies',
#   u'.'],
#  [u'MURRAY',
#   u':',
#   u'Trump',
#   u'also',
#   u'flushing',
#   u'out',
#   u'his',
#   u'controversial',
#   u'plan',
#   u'to',
#   u'block',
#   u'immigrants',
#   u'from',
#   u'countries',
#   u'that',
#   u'he',
#   u'claims',
#   u'breed',
#   u'terrorism',
#   u'proposing',
#   u'a',
#   u'test',
#   u'to',
#   u'determine',
#   u'whether',
#   u'immigrants',
#   u'hold',
#   u'extremist',
#   u'views',
#   u'that',
#   u'do',
#   u"n't",
#   u'mesh',
#   u'with',
#   u'American',
#   u'ideals',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'I',
#   u'call',
#   u'it',
#   u'extreme',
#   u'extreme',
#   u'vetting',
#   u'.'],
#  [u'Our', u'country', u'has', u'enough', u'problems', u'.'],
#  [u'We', u'do', u"n't", u'need', u'more', u'.'],
#  [u'And',
#   u'these',
#   u'are',
#   u'problems',
#   u'like',
#   u'we',
#   u'have',
#   u'never',
#   u'had',
#   u'before',
#   u'.'],
#  [u'MURRAY',
#   u':',
#   u'But',
#   u'such',
#   u'a',
#   u'screening',
#   u'comes',
#   u'with',
#   u'logistical',
#   u'hurdles',
#   u'and',
#   u'Trump',
#   u'offered',
#   u'few',
#   u'details',
#   u'on',
#   u'how',
#   u'he',
#   u'would',
#   u'implement',
#   u'the',
#   u'kind',
#   u'of',
#   u'ideological',
#   u'test',
#   u'he',
#   u'laid',
#   u'out',
#   u'today',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'In',
#   u'addition',
#   u'to',
#   u'screening',
#   u'out',
#   u'all',
#   u'members',
#   u'of',
#   u'the',
#   u'sympathizers',
#   u'of',
#   u'terrorist',
#   u'groups',
#   u'we',
#   u'must',
#   u'also',
#   u'screen',
#   u'out',
#   u'any',
#   u'of',
#   u'hostile',
#   u'attitudes',
#   u'toward',
#   u'our',
#   u'country',
#   u'or',
#   u'principles',
#   u'or',
#   u'who',
#   u'believe',
#   u'that',
#   u'Sharia',
#   u'law',
#   u'should',
#   u'supplant',
#   u'American',
#   u'law',
#   u'.'],
#  [u'Those',
#   u'who',
#   u'do',
#   u'not',
#   u'believe',
#   u'in',
#   u'our',
#   u'Constitution',
#   u'or',
#   u'who',
#   u'support',
#   u'bigotry',
#   u'and',
#   u'hatred',
#   u'will',
#   u'not',
#   u'be',
#   u'admitted',
#   u'for',
#   u'immigration',
#   u'into',
#   u'our',
#   u'country',
#   u'.'],
#  [u'Only',
#   u'those',
#   u'who',
#   u'we',
#   u'expect',
#   u'to',
#   u'flourish',
#   u'in',
#   u'our',
#   u'country',
#   u'and',
#   u'to',
#   u'embrace',
#   u'a',
#   u'tolerant',
#   u'American',
#   u'society',
#   u'should',
#   u'be',
#   u'issued',
#   u'visas',
#   u'.'],
#  [u'(',
#   u'END',
#   u'VIDEOTAPE',
#   u')',
#   u'COOPER',
#   u':',
#   u'Sara',
#   u'Murray',
#   u'joins',
#   u'us',
#   u'now',
#   u'.'],
#  [u'So', u'Donald', u'Trump', u'clearly', u'on', u'message', u'today', u'.'],
#  [u'How',
#   u'much',
#   u'concern',
#   u'is',
#   u'there',
#   u'tonight',
#   u'that',
#   u'he',
#   u'can',
#   u'actually',
#   u'stay',
#   u'on',
#   u'message',
#   u'?'],
#  [u'MURRAY',
#   u':',
#   u'Well',
#   u'Anderson',
#   u'I',
#   u'think',
#   u'that',
#   u"'s",
#   u'always',
#   u'a',
#   u'concern',
#   u'when',
#   u'it',
#   u'comes',
#   u'to',
#   u'Donald',
#   u'Trump',
#   u'especially',
#   u'since',
#   u'he',
#   u'has',
#   u'this',
#   u'pattern',
#   u'of',
#   u'one',
#   u'day',
#   u'showing',
#   u'up',
#   u'reading',
#   u'from',
#   u'the',
#   u'teleprompter',
#   u'sticking',
#   u'to',
#   u'the',
#   u'script',
#   u'and',
#   u'then',
#   u'just',
#   u'24',
#   u'hours',
#   u'later',
#   u'sometimes',
#   u'even',
#   u'less',
#   u'than',
#   u'that',
#   u'he',
#   u'veers',
#   u'off',
#   u'to',
#   u'the',
#   u'traditional',
#   u'Donald',
#   u'Trump',
#   u'off',
#   u'the',
#   u'cuff',
#   u'message',
#   u'.'],
#  [u'And',
#   u'in',
#   u'a',
#   u'sign',
#   u'of',
#   u'that',
#   u'frustration',
#   u'we',
#   u'saw',
#   u'``',
#   u'The',
#   u'Wall',
#   u'Street',
#   u'Journal',
#   u"''",
#   u'editorial',
#   u'page',
#   u'has',
#   u'been',
#   u'friendly',
#   u'to',
#   u'Republicans',
#   u'came',
#   u'out',
#   u'and',
#   u'go',
#   u'after',
#   u'Donald',
#   u'Trump',
#   u'saying',
#   u'he',
#   u'needs',
#   u'to',
#   u'stop',
#   u'blaming',
#   u'everybody',
#   u'else',
#   u'saying',
#   u'he',
#   u'needs',
#   u'to',
#   u'turn',
#   u'his',
#   u'campaign',
#   u'around',
#   u'by',
#   u'Labor',
#   u'Day',
#   u'and',
#   u'even',
#   u'suggesting',
#   u'that',
#   u'if',
#   u'he',
#   u'ca',
#   u"n't",
#   u'pull',
#   u'that',
#   u'off',
#   u'he',
#   u'should',
#   u'turn',
#   u'the',
#   u'nomination',
#   u'over',
#   u'to',
#   u'Mike',
#   u'Pence',
#   u'--',
#   u'Anderson',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Yes',
#   u'Sara',
#   u'Murray',
#   u'--',
#   u'Sara',
#   u'thanks',
#   u'.'],
#  [u'A',
#   u'closer',
#   u'look',
#   u'now',
#   u'the',
#   u'meat',
#   u'of',
#   u'the',
#   u'speech',
#   u'and',
#   u'substance',
#   u'of',
#   u'the',
#   u'plan',
#   u'.'],
#  [u'Joining',
#   u'us',
#   u'is',
#   u'Trump',
#   u'supporter',
#   u'former',
#   u'Trump',
#   u'campaign',
#   u'chairman',
#   u'excuse',
#   u'me',
#   u'campaign',
#   u'manager',
#   u'Corey',
#   u'Lewandowski',
#   u'also',
#   u'CNN',
#   u'senior',
#   u'international',
#   u'correspondent',
#   u'Clarissa',
#   u'Ward',
#   u'and',
#   u'Democratic',
#   u'Congressman',
#   u'Seth',
#   u'Moulton',
#   u'who',
#   u'served',
#   u'four',
#   u'tours',
#   u'of',
#   u'duty',
#   u'in',
#   u'Iraq',
#   u'including',
#   u'two',
#   u'as',
#   u'a',
#   u'special',
#   u'assistant',
#   u'to',
#   u'General',
#   u'David',
#   u'Petraeus',
#   u'.'],
#  [u'Corey', u'let', u"'s", u'start', u'with', u'you', u'.'],
#  [u'In',
#   u'terms',
#   u'of',
#   u'this',
#   u'idea',
#   u'of',
#   u'extreme',
#   u'vetting',
#   u'of',
#   u'some',
#   u'sort',
#   u'of',
#   u'a',
#   u'tolerant',
#   u'you',
#   u'know',
#   u'a',
#   u'test',
#   u'of',
#   u'tolerance',
#   u'how',
#   u'would',
#   u'that',
#   u'actually',
#   u'work',
#   u'?'],
#  [u'I',
#   u'mean',
#   u'asking',
#   u'somebody',
#   u'when',
#   u'they',
#   u'are',
#   u'coming',
#   u'over',
#   u'the',
#   u'border',
#   u'you',
#   u'know',
#   u'do',
#   u'you',
#   u'support',
#   u'women',
#   u"'s",
#   u'rights',
#   u'gay',
#   u'rights',
#   u'they',
#   u'are',
#   u'all',
#   u'things',
#   u'Trump',
#   u'mentioned',
#   u'.'],
#  [u'Is', u'that', u'for', u'real', u'?'],
#  [u'COREY',
#   u'LEWANDOWSKI',
#   u'CNN',
#   u'POLITICAL',
#   u'COMMENTATOR',
#   u':',
#   u'Well',
#   u'I',
#   u'think',
#   u'what',
#   u'you',
#   u'have',
#   u'and',
#   u'what',
#   u'Trump',
#   u'was',
#   u'alluding',
#   u'to',
#   u'in',
#   u'this',
#   u'particular',
#   u'case',
#   u'was',
#   u'when',
#   u'you',
#   u'look',
#   u'at',
#   u'the',
#   u'San',
#   u'Bernardino',
#   u'killer',
#   u'the',
#   u'woman',
#   u'who',
#   u'came',
#   u'in',
#   u'on',
#   u'a',
#   u'K-1',
#   u'visa',
#   u'because',
#   u'she',
#   u'married',
#   u'a',
#   u'U.S.',
#   u'citizen',
#   u'.'],
#  [u'What',
#   u'the',
#   u'State',
#   u'Department',
#   u'said',
#   u'the',
#   u'failures',
#   u'were',
#   u'in',
#   u'her',
#   u'position',
#   u'was',
#   u'they',
#   u'did',
#   u"n't",
#   u'go',
#   u'and',
#   u'check',
#   u'her',
#   u'social',
#   u'media',
#   u'accounts',
#   u'because',
#   u'they',
#   u'were',
#   u'precluded',
#   u'by',
#   u'doing',
#   u'that',
#   u'.'],
#  [u'And',
#   u'I',
#   u'think',
#   u'what',
#   u'he',
#   u"'s",
#   u'talking',
#   u'about',
#   u'is',
#   u'extreme',
#   u'vetting',
#   u'going',
#   u'and',
#   u'looking',
#   u'at',
#   u'social',
#   u'media',
#   u'activities',
#   u'.'],
#  [u'[',
#   u'20:05:03',
#   u']',
#   u'What',
#   u'we',
#   u'know',
#   u'is',
#   u'that',
#   u'the',
#   u'U.S.',
#   u'has',
#   u'accepted',
#   u'8000',
#   u'Syrian',
#   u'refugees',
#   u'to',
#   u'date',
#   u'which',
#   u'is',
#   u'more',
#   u'Syrian',
#   u'refugees',
#   u'into',
#   u'our',
#   u'country',
#   u'than',
#   u'all',
#   u'the',
#   u'E.U',
#   u'.'],
#  [u'combined', u'right', u'now', u'.'],
#  [u'So',
#   u'we',
#   u'need',
#   u'to',
#   u'make',
#   u'sure',
#   u'that',
#   u'the',
#   u'people',
#   u'who',
#   u'are',
#   u'coming',
#   u'here',
#   u'first',
#   u'and',
#   u'foremost',
#   u'do',
#   u"n't",
#   u'perpetuate',
#   u'or',
#   u'have',
#   u'the',
#   u'same',
#   u'type',
#   u'of',
#   u'mindset',
#   u'that',
#   u'the',
#   u'San',
#   u'Bernardino',
#   u'killer',
#   u'had',
#   u'which',
#   u'was',
#   u'to',
#   u'come',
#   u'here',
#   u'and',
#   u'commit',
#   u'jihad',
#   u'against',
#   u'our',
#   u'country',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Well',
#   u'Germany',
#   u'has',
#   u'accepted',
#   u'I',
#   u'think',
#   u'almost',
#   u'a',
#   u'million',
#   u'people',
#   u'.'],
#  [u'I',
#   u'mean',
#   u'not',
#   u'maybe',
#   u'formally',
#   u'as',
#   u'refugees',
#   u'but',
#   u'they',
#   u'allowed',
#   u'migrants',
#   u'in',
#   u'as',
#   u'many',
#   u'as',
#   u'a',
#   u'million',
#   u'800000',
#   u'to',
#   u'a',
#   u'million',
#   u'.'],
#  [u'But', u'I', u'get', u'your', u'point', u'.'],
#  [u'Congressman',
#   u'Moulton',
#   u'I',
#   u'mean',
#   u'the',
#   u'idea',
#   u'of',
#   u'a',
#   u'tolerance',
#   u'test',
#   u'for',
#   u'people',
#   u'that',
#   u'come',
#   u'to',
#   u'the',
#   u'United',
#   u'States',
#   u'does',
#   u'that',
#   u'make',
#   u'sense',
#   u'to',
#   u'you',
#   u'?'],
#  [u'REP.',
#   u'SETH',
#   u'MOULTON',
#   u'(',
#   u'D',
#   u')',
#   u'MASSACHUSETTS',
#   u':',
#   u'Well',
#   u'first',
#   u'of',
#   u'all',
#   u'there',
#   u"'s",
#   u'already',
#   u'extensive',
#   u'screening',
#   u'.'],
#  [u'It',
#   u"'s",
#   u'the',
#   u'toughest',
#   u'route',
#   u'possible',
#   u'to',
#   u'get',
#   u'to',
#   u'the',
#   u'United',
#   u'States',
#   u'as',
#   u'a',
#   u'refugee',
#   u'.'],
#  [u'Literally',
#   u'the',
#   u'most',
#   u'strict',
#   u'screening',
#   u'process',
#   u'possible',
#   u'.'],
#  [u'We',
#   u'are',
#   u'already',
#   u'doing',
#   u'things',
#   u'to',
#   u'improve',
#   u'it',
#   u'.'],
#  [u'This', u'does', u"n't", u'change', u'anything', u'.'],
#  [u'It',
#   u'might',
#   u'be',
#   u'unconstitutional',
#   u'but',
#   u'it',
#   u"'s",
#   u'not',
#   u'going',
#   u'to',
#   u'make',
#   u'us',
#   u'safer',
#   u'.'],
#  [u'And',
#   u'the',
#   u'other',
#   u'thing',
#   u'it',
#   u'does',
#   u"n't",
#   u'address',
#   u'the',
#   u'fact',
#   u'that',
#   u'what',
#   u'ISIS',
#   u'is',
#   u'trying',
#   u'to',
#   u'do',
#   u'is',
#   u'radicalize',
#   u'people',
#   u'who',
#   u'are',
#   u'right',
#   u'here',
#   u'at',
#   u'home',
#   u'.'],
#  [u'And',
#   u'they',
#   u'are',
#   u'using',
#   u'as',
#   u'tools',
#   u'to',
#   u'do',
#   u'that',
#   u'the',
#   u'rhetoric',
#   u'of',
#   u'people',
#   u'like',
#   u'Donald',
#   u'Trump',
#   u'who',
#   u'want',
#   u'to',
#   u'discriminate',
#   u'against',
#   u'people',
#   u'based',
#   u'on',
#   u'their',
#   u'religion',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'But',
#   u'Congressman',
#   u'you',
#   u'know',
#   u'the',
#   u'concern',
#   u'with',
#   u'the',
#   u'Syrian',
#   u'refugees',
#   u'certainly',
#   u'the',
#   u'migrants',
#   u'going',
#   u'to',
#   u'Germany',
#   u'.'],
#  [u'I',
#   u'mean',
#   u'I',
#   u'was',
#   u'on',
#   u'--',
#   u'I',
#   u'was',
#   u'in',
#   u'Greece',
#   u'when',
#   u'you',
#   u'know',
#   u'on',
#   u'the',
#   u'shores',
#   u'with',
#   u'hundreds',
#   u'coming',
#   u'ashore',
#   u'and',
#   u'you',
#   u'see',
#   u'passports',
#   u'ripped',
#   u'up',
#   u'.'],
#  [u'How',
#   u'you',
#   u'know',
#   u'easy',
#   u'is',
#   u'it',
#   u'to',
#   u'actually',
#   u'vet',
#   u'somebody',
#   u'when',
#   u'you',
#   u'ca',
#   u"n't",
#   u'work',
#   u'with',
#   u'the',
#   u'intelligence',
#   u'service',
#   u'in',
#   u'their',
#   u'home',
#   u'country',
#   u'in',
#   u'this',
#   u'case',
#   u'Syria',
#   u'to',
#   u'actually',
#   u'look',
#   u'at',
#   u'police',
#   u'records',
#   u'to',
#   u'look',
#   u'who',
#   u'they',
#   u'are',
#   u'?'],
#  [u'MOULTON', u':', u'It', u"'s", u'hard', u'to', u'do', u'it', u'.'],
#  [u'And',
#   u'that',
#   u"'s",
#   u'why',
#   u'it',
#   u'takes',
#   u'two',
#   u'years',
#   u'for',
#   u'someone',
#   u'to',
#   u'go',
#   u'through',
#   u'the',
#   u'refugee',
#   u'process',
#   u'to',
#   u'come',
#   u'to',
#   u'America',
#   u'.'],
#  [u'It',
#   u"'s",
#   u'simply',
#   u'not',
#   u'even',
#   u'comparable',
#   u'to',
#   u'these',
#   u'refugees',
#   u'who',
#   u'are',
#   u'swimming',
#   u'ashore',
#   u'in',
#   u'Europe',
#   u'.'],
#  [u'It', u"'s", u'silly', u'to', u'even', u'compare', u'the', u'two', u'.'],
#  [u'Migrants',
#   u'are',
#   u'flowing',
#   u'across',
#   u'borders',
#   u'freely',
#   u'into',
#   u'Europe',
#   u'.'],
#  [u'You', u'mentioned', u'800000', u'into', u'Germany', u'alone', u'.'],
#  [u'They', u'are', u'very', u'very', u'few', u'controls', u'.'],
#  [u'Totally',
#   u'different',
#   u'when',
#   u'a',
#   u'refugee',
#   u'comes',
#   u'to',
#   u'the',
#   u'United',
#   u'States',
#   u'.'],
#  [u'They',
#   u'go',
#   u'through',
#   u'the',
#   u'strictest',
#   u'screening',
#   u'of',
#   u'any',
#   u'traveler',
#   u'to',
#   u'the',
#   u'U.S',
#   u'.'],
#  [u'It',
#   u'usually',
#   u'takes',
#   u'upwards',
#   u'of',
#   u'18',
#   u'months',
#   u'to',
#   u'get',
#   u'through',
#   u'the',
#   u'process',
#   u'.'],
#  [u'Often', u'almost', u'two', u'years', u'.'],
#  [u'And',
#   u'that',
#   u'is',
#   u'because',
#   u'we',
#   u'are',
#   u'so',
#   u'strict',
#   u'and',
#   u'scrutinizing',
#   u'.'],
#  [u'So',
#   u'honestly',
#   u'if',
#   u'an',
#   u'ISIS',
#   u'terrorist',
#   u'wants',
#   u'to',
#   u'get',
#   u'to',
#   u'the',
#   u'United',
#   u'States',
#   u'coming',
#   u'as',
#   u'a',
#   u'refugee',
#   u'is',
#   u'about',
#   u'the',
#   u'worst',
#   u'route',
#   u'possible',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Clarissa',
#   u'you',
#   u'have',
#   u'worked',
#   u'obviously',
#   u'in',
#   u'Iraq',
#   u'and',
#   u'the',
#   u'Middle',
#   u'East',
#   u'.'],
#  [u'Many',
#   u'of',
#   u'the',
#   u'things',
#   u'Trump',
#   u'is',
#   u'talking',
#   u'about',
#   u'working',
#   u'excuse',
#   u'me',
#   u'with',
#   u'Jordan',
#   u'working',
#   u'with',
#   u'Egypt',
#   u'using',
#   u'NATO',
#   u'to',
#   u'fight',
#   u'terror',
#   u'.'],
#  [u'How',
#   u'many',
#   u'of',
#   u'these',
#   u'things',
#   u'are',
#   u'new',
#   u'ideas',
#   u'or',
#   u'things',
#   u'the',
#   u'U.S.',
#   u'is',
#   u'not',
#   u'already',
#   u'doing',
#   u'?'],
#  [u'CLARISSA',
#   u'WARD',
#   u'CNN',
#   u'SENIOR',
#   u'INTERNATIONAL',
#   u'CORRESPONDENT',
#   u':',
#   u'Well',
#   u'I',
#   u'think',
#   u'that',
#   u"'s",
#   u'what',
#   u'was',
#   u'really',
#   u'striking',
#   u'Anderson',
#   u'just',
#   u'listening',
#   u'to',
#   u'the',
#   u'speech',
#   u'is',
#   u'a',
#   u'lot',
#   u'of',
#   u'it',
#   u'sounded',
#   u'like',
#   u'policies',
#   u'that',
#   u'are',
#   u'already',
#   u'being',
#   u'implemented',
#   u'by',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'.'],
#  [u'Trump',
#   u'talked',
#   u'a',
#   u'lot',
#   u'about',
#   u'working',
#   u'closely',
#   u'with',
#   u'allies',
#   u'supporting',
#   u'allies',
#   u'who',
#   u'will',
#   u'fight',
#   u'ISIS',
#   u'cutting',
#   u'the',
#   u'source',
#   u'of',
#   u'ISIS',
#   u'funding',
#   u'.'],
#  [u'He',
#   u'talked',
#   u'about',
#   u'trying',
#   u'to',
#   u'put',
#   u'a',
#   u'stop',
#   u'to',
#   u'recruitment',
#   u'.'],
#  [u'His',
#   u'suggestion',
#   u'in',
#   u'that',
#   u'case',
#   u'was',
#   u'to',
#   u'shut',
#   u'down',
#   u'the',
#   u'Internet',
#   u'which',
#   u'I',
#   u'think',
#   u'is',
#   u'probably',
#   u'not',
#   u'only',
#   u'not',
#   u'feasible',
#   u'but',
#   u'also',
#   u'would',
#   u'be',
#   u'challenging',
#   u'for',
#   u'our',
#   u'security',
#   u'services',
#   u'who',
#   u'get',
#   u'a',
#   u'lot',
#   u'of',
#   u'their',
#   u'intelligence',
#   u'from',
#   u'that',
#   u'.'],
#  [u'But', u'then', u'he', u'went', u'one', u'step', u'further', u'.'],
#  [u'He',
#   u'almost',
#   u'seemed',
#   u'to',
#   u'put',
#   u'the',
#   u'entire',
#   u'Arab',
#   u'Spring',
#   u'at',
#   u'the',
#   u'feet',
#   u'of',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'as',
#   u'opposed',
#   u'at',
#   u'the',
#   u'feet',
#   u'of',
#   u'the',
#   u'brutal',
#   u'dictators',
#   u'who',
#   u'have',
#   u'been',
#   u'in',
#   u'charge',
#   u'in',
#   u'that',
#   u'region',
#   u'in',
#   u'those',
#   u'countries',
#   u'for',
#   u'many',
#   u'decades',
#   u'.'],
#  [u'And',
#   u'it',
#   u'seemed',
#   u'he',
#   u'almost',
#   u'had',
#   u'a',
#   u'nostalgia',
#   u'for',
#   u'the',
#   u'sort',
#   u'of',
#   u'heyday',
#   u'of',
#   u'the',
#   u'Middle',
#   u'East',
#   u'dictator',
#   u'.'],
#  [u'He',
#   u'talked',
#   u'about',
#   u'President',
#   u'Sisi',
#   u'of',
#   u'Egypt',
#   u'who',
#   u'we',
#   u'know',
#   u'does',
#   u'not',
#   u'aspire',
#   u'too',
#   u'many',
#   u'American',
#   u'values',
#   u'who',
#   u'has',
#   u'sentenced',
#   u'tens',
#   u'of',
#   u'thousands',
#   u'of',
#   u'people',
#   u'to',
#   u'death',
#   u'who',
#   u'came',
#   u'to',
#   u'power',
#   u'in',
#   u'a',
#   u'coup',
#   u'.'],
#  [u'So', u'there', u'were', u'a', u'lot', u'of', u'mixed', u'messages', u'.'],
#  [u'And',
#   u'even',
#   u'in',
#   u'his',
#   u'power',
#   u'he',
#   u'was',
#   u'drawing',
#   u'putting',
#   u'together',
#   u'or',
#   u'conflating',
#   u'Syria',
#   u'and',
#   u'Libya',
#   u'calling',
#   u'them',
#   u'both',
#   u'disastrous',
#   u'that',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'was',
#   u'responsible',
#   u'for',
#   u'.'],
#  [u'Well',
#   u'in',
#   u'Libya',
#   u'you',
#   u'had',
#   u'an',
#   u'intervention',
#   u'that',
#   u'had',
#   u'certain',
#   u'fairly',
#   u'disastrous',
#   u'consequences',
#   u'.'],
#  [u'In',
#   u'Syria',
#   u'there',
#   u"'s",
#   u'been',
#   u'no',
#   u'intervention',
#   u'and',
#   u'the',
#   u'consequences',
#   u'have',
#   u'been',
#   u'hugely',
#   u'disastrous',
#   u'.'],
#  [u'In',
#   u'fact',
#   u'Syria',
#   u'is',
#   u'the',
#   u'giant',
#   u'festering',
#   u'wound',
#   u'that',
#   u'ISIS',
#   u'really',
#   u'started',
#   u'to',
#   u'thrive',
#   u'in',
#   u'Anderson',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Corey',
#   u'though',
#   u'in',
#   u'terms',
#   u'of',
#   u'what',
#   u'Trump',
#   u'said',
#   u'about',
#   u'his',
#   u'own',
#   u'record',
#   u'I',
#   u'mean',
#   u'a',
#   u'lot',
#   u'of',
#   u'people',
#   u'are',
#   u'pointing',
#   u'to',
#   u'inaccuracies',
#   u'and',
#   u'things',
#   u'he',
#   u'has',
#   u'said',
#   u'.'],
#  [u'I',
#   u'mean',
#   u'he',
#   u'talked',
#   u'about',
#   u'the',
#   u'catastrophic',
#   u'mistake',
#   u'of',
#   u'pulling',
#   u'U.S.',
#   u'troops',
#   u'out',
#   u'of',
#   u'Iraq',
#   u'he',
#   u'said',
#   u'it',
#   u'happened',
#   u'too',
#   u'quickly',
#   u'not',
#   u'renegotiating',
#   u'the',
#   u'status',
#   u'of',
#   u'forces',
#   u'agreement',
#   u'.'],
#  [u'That',
#   u'was',
#   u'something',
#   u'he',
#   u'called',
#   u'for',
#   u'in',
#   u'multiple',
#   u'interviews',
#   u'in',
#   u'2006',
#   u'2007',
#   u'and',
#   u'2008',
#   u'on',
#   u'Larry',
#   u'King',
#   u'where',
#   u'he',
#   u'said',
#   u'just',
#   u'get',
#   u'out',
#   u'declare',
#   u'victory',
#   u'and',
#   u'get',
#   u'out',
#   u'essentially',
#   u'like',
#   u'we',
#   u'did',
#   u'in',
#   u'Vietnam',
#   u'.'],
#  [u'Is',
#   u'it',
#   u'hypercritical',
#   u'and',
#   u'Clarissa',
#   u'mentioned',
#   u'Libya',
#   u'he',
#   u'actually',
#   u'attacked',
#   u'President',
#   u'Obama',
#   u'for',
#   u'not',
#   u'going',
#   u'faster',
#   u'against',
#   u'Gadhafi',
#   u'.'],
#  [u'And',
#   u'so',
#   u'there',
#   u'were',
#   u'multiple',
#   u'instances',
#   u'where',
#   u'things',
#   u'he',
#   u'was',
#   u'critical',
#   u'of',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'were',
#   u'things',
#   u'he',
#   u'was',
#   u'supporting',
#   u'several',
#   u'years',
#   u'ago',
#   u'.'],
#  [u'LEWANDOWSKI',
#   u':',
#   u'I',
#   u'think',
#   u'you',
#   u'have',
#   u'to',
#   u'remember',
#   u'right',
#   u'Donald',
#   u'Trump',
#   u'is',
#   u'a',
#   u'businessman',
#   u'and',
#   u'has',
#   u'been',
#   u'a',
#   u'businessman',
#   u'throughout',
#   u'his',
#   u'entire',
#   u'career',
#   u'and',
#   u'does',
#   u"n't",
#   u'have',
#   u'access',
#   u'to',
#   u'the',
#   u'same',
#   u'type',
#   u'of',
#   u'information',
#   u'that',
#   u'this',
#   u'administration',
#   u'has',
#   u'access',
#   u'to',
#   u'or',
#   u'the',
#   u'previous',
#   u'administration',
#   u'had',
#   u'access',
#   u'to',
#   u'.'],
#  [u'[',
#   u'20:10:06',
#   u']',
#   u'So',
#   u'when',
#   u'you',
#   u'look',
#   u'at',
#   u'the',
#   u'things',
#   u'he',
#   u'was',
#   u'calling',
#   u'for',
#   u'like',
#   u'the',
#   u'congressman',
#   u'you',
#   u'know',
#   u'Mr.',
#   u'Trump',
#   u'said',
#   u'he',
#   u'was',
#   u'against',
#   u'the',
#   u'Iraq',
#   u'war',
#   u'you',
#   u'know',
#   u'the',
#   u'congressman',
#   u'was',
#   u'against',
#   u'the',
#   u'Iraq',
#   u'war',
#   u'but',
#   u'he',
#   u'went',
#   u'to',
#   u'war',
#   u'to',
#   u'fight',
#   u'for',
#   u'his',
#   u'country',
#   u'--',
#   u'COOPER',
#   u':',
#   u'But',
#   u'he',
#   u'actually',
#   u'was',
#   u'against',
#   u'--',
#   u'I',
#   u'mean',
#   u'on',
#   u'Howard',
#   u'Stern',
#   u'he',
#   u'said',
#   u'--',
#   u'LEWANDOWSKI',
#   u':',
#   u'Howard',
#   u'Stern',
#   u'was',
#   u'well',
#   u'okay',
#   u'maybe',
#   u'.'],
#  [u'That', u"'s", u'not', u'a', u'ringing', u'endorsement', u'.'],
#  [u'I',
#   u'think',
#   u'that',
#   u"'s",
#   u'really',
#   u'overplayed',
#   u'that',
#   u'he',
#   u'was',
#   u'in',
#   u'favor',
#   u'of',
#   u'the',
#   u'war',
#   u'when',
#   u'he',
#   u"'s",
#   u'been',
#   u'on',
#   u'record',
#   u'on',
#   u'multiple',
#   u'occasions',
#   u'saying',
#   u'he',
#   u'has',
#   u"n't",
#   u'been',
#   u'in',
#   u'favor',
#   u'of',
#   u'the',
#   u'war',
#   u'.'],
#  [u'The',
#   u'congressman',
#   u'was',
#   u"n't",
#   u'in',
#   u'favor',
#   u'but',
#   u'he',
#   u'went',
#   u'and',
#   u'served',
#   u'honorably',
#   u'four',
#   u'tours',
#   u'of',
#   u'duty',
#   u'.'],
#  [u'We', u'respect', u'him', u'for', u'that', u'.'],
#  [u'And',
#   u'I',
#   u'think',
#   u'what',
#   u'you',
#   u'have',
#   u'now',
#   u'is',
#   u'with',
#   u'the',
#   u'best',
#   u'information',
#   u'he',
#   u'had',
#   u'available',
#   u'he',
#   u'said',
#   u'look',
#   u'you',
#   u'just',
#   u'get',
#   u'out',
#   u'.'],
#  [u'He', u'said', u'to', u'Wolf', u'Blitzer', u'.'],
#  [u'He',
#   u'said',
#   u'to',
#   u'Larry',
#   u'King',
#   u'it',
#   u"'s",
#   u'time',
#   u'to',
#   u'get',
#   u'out',
#   u'.'],
#  [u'The',
#   u'problem',
#   u'became',
#   u'when',
#   u'the',
#   u'U.S.',
#   u'extracted',
#   u'itself',
#   u'right',
#   u'?'],
#  [u'That',
#   u'created',
#   u'a',
#   u'power',
#   u'vacuum',
#   u'that',
#   u'allowed',
#   u'ISIS',
#   u'to',
#   u'permeate',
#   u'and',
#   u'grow',
#   u'to',
#   u'what',
#   u'it',
#   u'is',
#   u'today',
#   u'which',
#   u'is',
#   u'the',
#   u'single',
#   u'biggest',
#   u'source',
#   u'of',
#   u'terror',
#   u'in',
#   u'our',
#   u'world',
#   u'.'],
#  [u'COOPER', u':', u'All', u'right', u'.'],
#  [u'But',
#   u'Congressman',
#   u'I',
#   u'mean',
#   u'what',
#   u'Trump',
#   u'said',
#   u'on',
#   u'Larry',
#   u'King',
#   u'in',
#   u'particular',
#   u'is',
#   u'like',
#   u'even',
#   u'if',
#   u'you',
#   u'know',
#   u'there',
#   u"'s",
#   u'going',
#   u'to',
#   u'be',
#   u'civil',
#   u'war',
#   u'no',
#   u'matter',
#   u'what',
#   u'get',
#   u'out',
#   u'declare',
#   u'victory',
#   u'.'],
#  [u'Do',
#   u'you',
#   u'think',
#   u'is',
#   u'it',
#   u'hypercritical',
#   u'of',
#   u'him',
#   u'now',
#   u'to',
#   u'attack',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'for',
#   u'not',
#   u'renegotiating',
#   u'the',
#   u'status',
#   u'of',
#   u'forces',
#   u'agreement',
#   u'?'],
#  [u'Which',
#   u'is',
#   u'a',
#   u'valid',
#   u'position',
#   u'to',
#   u'have',
#   u'but',
#   u'it',
#   u"'s",
#   u'counter',
#   u'to',
#   u'what',
#   u'he',
#   u'used',
#   u'to',
#   u'have',
#   u'.'],
#  [u'Is', u'that', u'hypercritical', u'?'],
#  [u'MOULTON', u':', u'Well', u'it', u'is', u'hypocritical', u'.'],
#  [u'And',
#   u'look',
#   u'Donald',
#   u'Trump',
#   u'is',
#   u'not',
#   u'running',
#   u'to',
#   u'be',
#   u'a',
#   u'businessman',
#   u'.'],
#  [u'He',
#   u'is',
#   u'running',
#   u'to',
#   u'be',
#   u'our',
#   u'commander-in-',
#   u'chief',
#   u'.'],
#  [u'He',
#   u'is',
#   u'someone',
#   u'that',
#   u'we',
#   u'have',
#   u'to',
#   u'trust',
#   u'him',
#   u'to',
#   u'make',
#   u'the',
#   u'right',
#   u'judgment',
#   u'calls',
#   u'in',
#   u'these',
#   u'situations',
#   u'.'],
#  [u'They', u'are', u'tough', u'calls', u'.'],
#  [u'I',
#   u'have',
#   u'been',
#   u'someone',
#   u'a',
#   u'Democrat',
#   u'who',
#   u"'s",
#   u'been',
#   u'critical',
#   u'of',
#   u'the',
#   u'Obama',
#   u'administration',
#   u'on',
#   u'some',
#   u'of',
#   u'that',
#   u'.'],
#  [u'But',
#   u'the',
#   u'fact',
#   u'that',
#   u'Donald',
#   u'Trump',
#   u'is',
#   u'so',
#   u'inconsistent',
#   u'so',
#   u'reckless',
#   u'with',
#   u'some',
#   u'of',
#   u'his',
#   u'recommendations',
#   u'and',
#   u'then',
#   u'hypocritical',
#   u'many',
#   u'times',
#   u'when',
#   u'he',
#   u'criticizes',
#   u'others',
#   u'just',
#   u'shows',
#   u'that',
#   u'he',
#   u"'s",
#   u'really',
#   u'not',
#   u'fit',
#   u'to',
#   u'be',
#   u'our',
#   u'commander-in-chief',
#   u'.'],
#  [u'He', u'might', u'be', u'a', u'great', u'businessman', u'.'],
#  [u'But',
#   u'the',
#   u'record',
#   u'is',
#   u'a',
#   u'little',
#   u'bit',
#   u'shoddy',
#   u'on',
#   u'that',
#   u'as',
#   u'well',
#   u'.'],
#  [u'But',
#   u'he',
#   u'clearly',
#   u'does',
#   u'not',
#   u'have',
#   u'a',
#   u'temperament',
#   u'or',
#   u'the',
#   u'judgment',
#   u'to',
#   u'be',
#   u'making',
#   u'these',
#   u'tough',
#   u'calls',
#   u'about',
#   u'the',
#   u'national',
#   u'security',
#   u'.'],
#  [u'And',
#   u'just',
#   u'by',
#   u'running',
#   u'for',
#   u'president',
#   u'and',
#   u'talking',
#   u'about',
#   u'things',
#   u'like',
#   u'banning',
#   u'Muslims',
#   u'which',
#   u'just',
#   u'inflames',
#   u'ISIS',
#   u'recruitment',
#   u'he',
#   u"'s",
#   u'actually',
#   u'putting',
#   u'the',
#   u'troops',
#   u'at',
#   u'risk',
#   u'he',
#   u"'s",
#   u'putting',
#   u'our',
#   u'national',
#   u'security',
#   u'at',
#   u'risk',
#   u'just',
#   u'through',
#   u'the',
#   u'course',
#   u'of',
#   u'his',
#   u'campaign',
#   u'.'],
#  [u'COOPER', u':', u'Congressman', u'appreciate', u'your', u'time', u'.'],
#  [u'Clarissa', u'Ward', u'always', u'.'],
#  [u'Corey', u'stay', u'with', u'us', u'.'],
#  [u'We',
#   u'are',
#   u'going',
#   u'have',
#   u'more',
#   u'with',
#   u'Corey',
#   u'in',
#   u'a',
#   u'second',
#   u'.'],
#  [u'And',
#   u'next',
#   u'what',
#   u'people',
#   u'at',
#   u'the',
#   u'speech',
#   u'thought',
#   u'of',
#   u'what',
#   u'he',
#   u'said',
#   u'and',
#   u'the',
#   u'way',
#   u'he',
#   u'said',
#   u'it',
#   u'minus',
#   u'all',
#   u'the',
#   u'traditional',
#   u'Donald',
#   u'Trump',
#   u'ad',
#   u'libs',
#   u'.'],
#  [u'The',
#   u'panel',
#   u'Corey',
#   u'included',
#   u'joins',
#   u'us',
#   u'as',
#   u'well',
#   u'.'],
#  [u'Later',
#   u'we',
#   u"'ll",
#   u'take',
#   u'you',
#   u'to',
#   u'the',
#   u'Louisiana',
#   u'flood',
#   u'zone',
#   u'where',
#   u'the',
#   u'danger',
#   u'remains',
#   u'the',
#   u'pictures',
#   u'suggests',
#   u'extraordinary',
#   u'the',
#   u'death',
#   u'toll',
#   u'the',
#   u'water',
#   u'keeps',
#   u'rising',
#   u'.'],
#  [u'A',
#   u'lot',
#   u'of',
#   u'raids',
#   u'towns',
#   u'and',
#   u'rescuers',
#   u'rising',
#   u'to',
#   u'the',
#   u'occasion',
#   u'to',
#   u'help',
#   u'.'],
#  [u'We', u"'ll", u'show', u'you', u'some', u'incredible', u'rescues', u'.'],
#  [u'(',
#   u'COMMERCIAL',
#   u'BREAK',
#   u')',
#   u'[',
#   u'20:16:13',
#   u']',
#   u'COOPER',
#   u':',
#   u'We',
#   u'are',
#   u'talking',
#   u'about',
#   u'Donald',
#   u'Trump',
#   u"'s",
#   u'second',
#   u'campaign',
#   u'the',
#   u'last',
#   u'two',
#   u'weeks',
#   u'and',
#   u'the',
#   u'pressure',
#   u'that',
#   u'he',
#   u'is',
#   u'under',
#   u'to',
#   u'stay',
#   u'focus',
#   u'today',
#   u'in',
#   u'Ohio',
#   u'.'],
#  [u'He',
#   u'stuck',
#   u'to',
#   u'a',
#   u'script',
#   u'and',
#   u'took',
#   u'the',
#   u'advice',
#   u'to',
#   u'those',
#   u'who',
#   u'wanted',
#   u'him',
#   u'to',
#   u'appear',
#   u'more',
#   u'presidential',
#   u'advice',
#   u'he',
#   u"'s",
#   u'belittled',
#   u'on',
#   u'occasion',
#   u'.'],
#  [u'Last',
#   u'April',
#   u'he',
#   u'told',
#   u'a',
#   u'crowd',
#   u'in',
#   u'Harrisburg',
#   u'Pennsylvania',
#   u'that',
#   u'one',
#   u'day',
#   u'he',
#   u'will',
#   u'be',
#   u'so',
#   u'presidential',
#   u'that',
#   u'he',
#   u'will',
#   u'bore',
#   u'people',
#   u'and',
#   u'they',
#   u'will',
#   u'stop',
#   u'coming',
#   u'to',
#   u'his',
#   u'rallies',
#   u'.'],
#  [u'The',
#   u'question',
#   u'tonight',
#   u'what',
#   u'did',
#   u'the',
#   u'crowd',
#   u'in',
#   u'Youngstown',
#   u'Ohio',
#   u'make',
#   u'of',
#   u'what',
#   u'they',
#   u'heard',
#   u'today',
#   u'?'],
#  [u'More', u'in', u'that', u'from', u'our', u'Gary', u'Tuchman', u'.'],
#  [u'(',
#   u'BEGIN',
#   u'VIDEOTAPE',
#   u')',
#   u'GARY',
#   u'TUCHMAN',
#   u'CNN',
#   u'CORRESPONDENT',
#   u'(',
#   u'voice-over',
#   u')',
#   u':',
#   u'An',
#   u'invitation',
#   u'only',
#   u'crowd',
#   u'of',
#   u'Donald',
#   u'Trump',
#   u'supporters',
#   u'waiting',
#   u'out',
#   u'in',
#   u'the',
#   u'Ohio',
#   u'rain',
#   u'waiting',
#   u'to',
#   u'find',
#   u'out',
#   u'how',
#   u'he',
#   u'plans',
#   u'to',
#   u'keep',
#   u'them',
#   u'safe',
#   u'.'],
#  [u'ROBIN',
#   u'MCCORMACK',
#   u'TRUMP',
#   u'SUPPORTER',
#   u':',
#   u'This',
#   u'has',
#   u'to',
#   u'stop',
#   u'.'],
#  [u'We', u"'ve", u'got', u'to', u'stop', u'being', u'victims', u'.'],
#  [u'We', u"'ve", u'got', u'to', u'stop', u'being', u'gentle', u'.'],
#  [u'TUCHMAN',
#   u':',
#   u'This',
#   u'woman',
#   u'says',
#   u'America',
#   u'has',
#   u'to',
#   u'do',
#   u'what',
#   u'America',
#   u'has',
#   u'to',
#   u'do',
#   u'.'],
#  [u'So',
#   u'does',
#   u'that',
#   u'include',
#   u'waterboarding',
#   u'at',
#   u'your',
#   u'estimation',
#   u'and',
#   u'hence',
#   u'interrogation',
#   u'techniques',
#   u'?'],
#  [u'MCCORMACK', u':', u'I', u"'m", u'not', u'opposed', u'to', u'it', u'.'],
#  [u'TUCHMAN',
#   u':',
#   u'And',
#   u'then',
#   u'there',
#   u'was',
#   u'this',
#   u'quote',
#   u'from',
#   u'this',
#   u'past',
#   u'December',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'Donald',
#   u'J.',
#   u'Trump',
#   u'is',
#   u'calling',
#   u'for',
#   u'a',
#   u'total',
#   u'and',
#   u'complete',
#   u'shutdown',
#   u'of',
#   u'Muslims',
#   u'entering',
#   u'the',
#   u'United',
#   u'States',
#   u'until',
#   u'our',
#   u'country',
#   u"'s",
#   u'representatives',
#   u'can',
#   u'figure',
#   u'out',
#   u'what',
#   u'the',
#   u'hell',
#   u'is',
#   u'going',
#   u'on',
#   u'.'],
#  [u'TUCHMAN',
#   u'(',
#   u'on',
#   u'camera',
#   u')',
#   u':',
#   u'So',
#   u'tell',
#   u'me',
#   u'specifically',
#   u'what',
#   u'you',
#   u'want',
#   u'to',
#   u'see',
#   u'.'],
#  [u'RON',
#   u'CAPITENA',
#   u'TRUMP',
#   u'SUPPORTER',
#   u':',
#   u'Just',
#   u'the',
#   u'Muslims',
#   u'people',
#   u'yes',
#   u'it',
#   u'has',
#   u'to',
#   u'stop',
#   u'.'],
#  [u'Just', u'until', u'we', u'get', u'it', u'ironed', u'out', u'.'],
#  [u'TUCHMAN',
#   u':',
#   u'What',
#   u'you',
#   u"'re",
#   u'saying',
#   u'you',
#   u'want',
#   u'to',
#   u'hear',
#   u'Donald',
#   u'Trump',
#   u'say',
#   u'that',
#   u'Muslims',
#   u'should',
#   u'be',
#   u'banned',
#   u'for',
#   u'the',
#   u'time',
#   u'being',
#   u'.'],
#  [u'CAPITENA',
#   u':',
#   u'For',
#   u'the',
#   u'time',
#   u'being',
#   u'yes',
#   u'just',
#   u'for',
#   u'the',
#   u'time',
#   u'being',
#   u'.'],
#  [u'TRUMP',
#   u':',
#   u'Only',
#   u'this',
#   u'way',
#   u'will',
#   u'we',
#   u'make',
#   u'America',
#   u'great',
#   u'again',
#   u'and',
#   u'safe',
#   u'again',
#   u'for',
#   u'everyone',
#   u'.'],
#  [u'Thank', u'you', u'very', u'much', u'.'],
#  [u'God', u'bless', u'you', u'.'],
#  [u'Thank', u'you', u'.'],
#  [u'Thank', u'you', u'.'],
#  [u'TUCHMAN',
#   u'(',
#   u'voice-over',
#   u')',
#   u':',
#   u'The',
#   u'speech',
#   u'was',
#   u'over',
#   u'the',
#   u'reviews',
#   u'from',
#   u'this',
#   u'crowd',
#   u'were',
#   u'kind',
#   u'.'],
#  [u'Trump',
#   u'did',
#   u'not',
#   u'specifically',
#   u'mention',
#   u'banning',
#   u'Muslims',
#   u'.'],
#  [u'But',
#   u'about',
#   u'his',
#   u'newly',
#   u'announced',
#   u'plan',
#   u'of',
#   u'so-called',
#   u'extreme',
#   u'vetting',
#   u'--',
#   u'MARK',
#   u'WEBB',
#   u'TRUMP',
#   u'SUPPORTER',
#   u':',
#   u'I',
#   u'thought',
#   u'it',
#   u'was',
#   u'very',
#   u'inspiring',
#   u'.'],
#  [u'I', u'think', u'it', u"'s", u'what', u'the', u'country', u'needs', u'.'],
#  [u'TUCHMAN',
#   u':',
#   u'What',
#   u'about',
#   u'his',
#   u'declaration',
#   u'that',
#   u'a',
#   u'country',
#   u'that',
#   u'shares',
#   u'the',
#   u'goal',
#   u'of',
#   u'halting',
#   u'in',
#   u'his',
#   u'words',
#   u'the',
#   u'spread',
#   u'of',
#   u'radical',
#   u'Islam',
#   u'will',
#   u'be',
#   u'an',
#   u'ally',
#   u'of',
#   u'the',
#   u'U.S.',
#   u'(',
#   u'on',
#   u'camera',
#   u')',
#   u':',
#   u'Would',
#   u'it',
#   u'trouble',
#   u'you',
#   u'though',
#   u'if',
#   u'Russia',
#   u'was',
#   u'allied',
#   u'with',
#   u'United',
#   u'States',
#   u'in',
#   u'fighting',
#   u'terrorism',
#   u'but',
#   u'it',
#   u'invaded',
#   u'Latvia',
#   u'Lithuania',
#   u'or',
#   u'Estonia',
#   u'how',
#   u'could',
#   u'Russia',
#   u'still',
#   u'be',
#   u'a',
#   u'U.S.',
#   u'ally',
#   u'?'],
#  [u'WEBB',
#   u':',
#   u'Well',
#   u'that',
#   u"'s",
#   u'a',
#   u'very',
#   u'good',
#   u'point',
#   u'.'],
#  [u'But',
#   u'I',
#   u'think',
#   u'there',
#   u"'s",
#   u'room',
#   u'for',
#   u'negotiation',
#   u'.'],
#  [u'I',
#   u'think',
#   u'at',
#   u'least',
#   u'we',
#   u'have',
#   u'somebody',
#   u'willing',
#   u'to',
#   u'talk',
#   u'to',
#   u'all',
#   u'parties',
#   u'to',
#   u'actually',
#   u'get',
#   u'something',
#   u'done',
#   u'that',
#   u"'s",
#   u'positive',
#   u'that',
#   u"'s",
#   u'in',
#   u'our',
#   u'interest',
#   u'.'],
#  [u'TUCHMAN',
#   u'(',
#   u'voice-over',
#   u')',
#   u':',
#   u'And',
#   u'on',
#   u'his',
#   u'criticism',
#   u'of',
#   u'Hillary',
#   u'Clinton',
#   u'and',
#   u'President',
#   u'Obama',
#   u'--',
#   u'UNIDENTIFIED',
#   u'FEMALE',
#   u':',
#   u'I',
#   u'thought',
#   u'he',
#   u'was',
#   u'forceful',
#   u'in',
#   u'what',
#   u'he',
#   u'has',
#   u'to',
#   u'say',
#   u'to',
#   u'America',
#   u'because',
#   u'we',
#   u'are',
#   u'in',
#   u'terrible',
#   u'shape',
#   u'.'],
#  [u'Our',
#   u'president',
#   u'is',
#   u'a',
#   u'Muslim',
#   u'who',
#   u'hates',
#   u'America',
#   u'.'],
#  [u'TUCHMAN',
#   u'(',
#   u'on',
#   u'camera',
#   u')',
#   u':',
#   u'What',
#   u'did',
#   u'you',
#   u'say',
#   u'?'],
#  [u'UNIDENTIFIED',
#   u'FEMALE',
#   u':',
#   u'I',
#   u'just',
#   u'said',
#   u'our',
#   u'president',
#   u'is',
#   u'a',
#   u'Muslim',
#   u'who',
#   u'hates',
#   u'America',
#   u'.'],
#  [u'TUCHMAN',
#   u':',
#   u'So',
#   u'you',
#   u'think',
#   u'Barack',
#   u'Obama',
#   u'is',
#   u'a',
#   u'Muslim',
#   u'?'],
#  [u'UNIDENTIFIED', u'FEMALE', u':', u'Oh', u'yes', u'.'],
#  [u'I',
#   u'think',
#   u'he',
#   u"'s",
#   u'--',
#   u'TUCHMAN',
#   u':',
#   u'He',
#   u"'s",
#   u'a',
#   u'Christian',
#   u'.'],
#  [u'UNIDENTIFIED', u'FEMALE', u':', u'No', u'.'],
#  [u'TUCHMAN', u':', u'He', u"'s", u'a', u'Christian', u'.'],
#  [u'(',
#   u'voice-over',
#   u')',
#   u':',
#   u'That',
#   u'was',
#   u"n't",
#   u'a',
#   u'typical',
#   u'response',
#   u'to',
#   u'the',
#   u'speech',
#   u'.'],
#  [u'This', u'was', u'.'],
#  [u'UNIDENTIFIED',
#   u'FEMALE',
#   u':',
#   u'I',
#   u'thought',
#   u'it',
#   u'was',
#   u'awesome',
#   u'.'],
#  [u'I', u'loved', u'his', u'speech', u'entirely', u'.'],
#  [u'(',
#   u'END',
#   u'VIDEOTAPE',
#   u')',
#   u'COOPER',
#   u':',
#   u'Gary',
#   u'Tuchman',
#   u'joins',
#   u'us',
#   u'.'],
#  [u'Now',
#   u'was',
#   u'there',
#   u'anything',
#   u'else',
#   u'that',
#   u'stood',
#   u'out',
#   u'to',
#   u'Trump',
#   u'supporters',
#   u'in',
#   u'particular',
#   u'about',
#   u'the',
#   u'speech',
#   u'?'],
#  [u'TUCHMAN',
#   u':',
#   u'I',
#   u'spoke',
#   u'to',
#   u'a',
#   u'lot',
#   u'of',
#   u'people',
#   u'today',
#   u'Anderson',
#   u'.'],
#  [u'One',
#   u'of',
#   u'the',
#   u'more',
#   u'interesting',
#   u'conversations',
#   u'I',
#   u'had',
#   u'was',
#   u'with',
#   u'a',
#   u'woman',
#   u'who',
#   u'was',
#   u'born',
#   u'in',
#   u'Puerto',
#   u'Rico',
#   u'but',
#   u'has',
#   u'lived',
#   u'in',
#   u'Ohio',
#   u'for',
#   u'many',
#   u'years',
#   u'and',
#   u'loves',
#   u'Donald',
#   u'Trump',
#   u'loves',
#   u'everything',
#   u'he',
#   u'said',
#   u'today',
#   u'and',
#   u'loves',
#   u'one',
#   u'thing',
#   u'he',
#   u'did',
#   u'not',
#   u'say',
#   u'today',
#   u'Donald',
#   u'Trump',
#   u'did',
#   u'not',
#   u'talk',
#   u'about',
#   u'his',
#   u'proposal',
#   u'to',
#   u'have',
#   u'a',
#   u'border',
#   u'wall',
#   u'on',
#   u'the',
#   u'border',
#   u'of',
#   u'the',
#   u'United',
#   u'States',
#   u'and',
#   u'Mexico',
#   u'.'],
#  [u'She',
#   u'does',
#   u"n't",
#   u'want',
#   u'to',
#   u'see',
#   u'a',
#   u'border',
#   u'wall',
#   u'.'],
#  [u'So',
#   u'I',
#   u'told',
#   u'her',
#   u'well',
#   u'there',
#   u"'s",
#   u'no',
#   u'indication',
#   u'at',
#   u'all',
#   u'that',
#   u'Donald',
#   u'Trump',
#   u'has',
#   u'abandoned',
#   u'his',
#   u'position',
#   u'to',
#   u'build',
#   u'a',
#   u'border',
#   u'wall',
#   u'between',
#   u'the',
#   u'United',
#   u'States',
#   u'and',
#   u'Mexico',
#   u'.'],
#  [u'As',
#   u'a',
#   u'matter',
#   u'of',
#   u'fact',
#   u'that',
#   u"'s",
#   u'what',
#   u'he',
#   u"'s",
#   u'best',
#   u'known',
#   u'for',
#   u'among',
#   u'some',
#   u'people',
#   u'.'],
#  [u'But',
#   u'she',
#   u'said',
#   u'it',
#   u"'s",
#   u'very',
#   u'significant',
#   u'that',
#   u'on',
#   u'the',
#   u'speech',
#   u'about',
#   u'national',
#   u'security',
#   u'he',
#   u'did',
#   u'not',
#   u'mention',
#   u'that',
#   u'border',
#   u'wall',
#   u'--',
#   u'Anderson',
#   u'.'],
#  [u'COOPER', u':', u'All', u'right', u'.'],
#  [u'Gary', u'thanks', u'very', u'much', u'.'],
#  [u'I', u'just', u'want', u'to', u'bring', u'in', u'the', u'panel', u'.'],
#  [u'CNN',
#   u'political',
#   u'analyst',
#   u'and',
#   u'``',
#   u'Daily',
#   u'Beast',
#   u"''",
#   u'Washington',
#   u'bureau',
#   u'chief',
#   u'Jackie',
#   u'Kucinich',
#   u'Clinton',
#   u'supporter',
#   u'and',
#   u'former',
#   u'New',
#   u'York',
#   u'City',
#   u'council',
#   u'speaker',
#   u'Christine',
#   u'Quinn',
#   u'Corey',
#   u'Lewandowski',
#   u'is',
#   u'back',
#   u'with',
#   u'us',
#   u'.'],
#  [u'[',
#   u'20:20:01',
#   u']',
#   u'Also',
#   u'as',
#   u'well',
#   u'former',
#   u'New',
#   u'York',
#   u'Republican',
#   u'Congressman',
#   u'Rick',
#   u'Lazio',
#   u'who',
#   u'unsuccessfully',
#   u'run',
#   u'for',
#   u'the',
#   u'Senate',
#   u'against',
#   u'Hillary',
#   u'Clinton',
#   u'16',
#   u'years',
#   u'go',
#   u'also',
#   u'Democratic',
#   u'strategist',
#   u'and',
#   u'former',
#   u'Congressional',
#   u'Black',
#   u'Caucus',
#   u'executive',
#   u'director',
#   u'Angela',
#   u'Rye',
#   u'and',
#   u'last',
#   u'but',
#   u'not',
#   u'the',
#   u'least',
#   u'Trump',
#   u'supporter',
#   u'and',
#   u'New',
#   u'York',
#   u'City',
#   u'Council',
#   u'Member',
#   u'Joseph',
#   u'Borelli',
#   u'.'],
#  [u'Appreciate', u'you', u'all', u'being', u'with', u'us', u'.'],
#  [u'Jackie', u'let', u"'s", u'start', u'off', u'with', u'you', u'.'],
#  [u'I',
#   u'mean',
#   u'obviously',
#   u'for',
#   u'the',
#   u'folks',
#   u'in',
#   u'that',
#   u'room',
#   u'who',
#   u'all',
#   u'Trump',
#   u'supporters',
#   u'it',
#   u'was',
#   u'very',
#   u'well-received',
#   u'.'],
#  [u'Donald',
#   u'Trump',
#   u'needs',
#   u'to',
#   u'reach',
#   u'out',
#   u'to',
#   u'other',
#   u'people',
#   u'who',
#   u'have',
#   u"n't",
#   u'been',
#   u'receptive',
#   u'to',
#   u'him',
#   u'yet',
#   u'.'],
#  [u'Do',
#   u'you',
#   u'think',
#   u'he',
#   u'did',
#   u'that',
#   u'with',
#   u'his',
#   u'speech',
#   u'?'],
#  [u'JACKIE',
#   u'KUCINICH',
#   u'CNN',
#   u'POLITICAL',
#   u'ANALYST',
#   u':',
#   u'It',
#   u'sure',
#   u'did',
#   u"n't",
#   u'sound',
#   u'like',
#   u'it',
#   u'.'],
#  [u'Yes',
#   u'Trump',
#   u'supporters',
#   u'would',
#   u'be',
#   u'very',
#   u'pleased',
#   u'by',
#   u'that',
#   u'speech',
#   u'.'],
#  [u'But',
#   u'this',
#   u'is',
#   u"n't",
#   u'a',
#   u'speech',
#   u'that',
#   u'really',
#   u'was',
#   u'meant',
#   u'to',
#   u'expand',
#   u'to',
#   u'other',
#   u'people',
#   u'or',
#   u'at',
#   u'least',
#   u'did',
#   u"n't",
#   u'sound',
#   u'that',
#   u'way',
#   u'.'],
#  [u'When',
#   u'talking',
#   u'about',
#   u'extreme',
#   u'immigration',
#   u'when',
#   u'you',
#   u"'re",
#   u'talking',
#   u'about',
#   u'--',
#   u'I',
#   u'mean',
#   u'it',
#   u'already',
#   u'takes',
#   u'18-24',
#   u'months',
#   u'to',
#   u'allow',
#   u'refugees',
#   u'into',
#   u'this',
#   u'country',
#   u'.'],
#  [u'There',
#   u'were',
#   u'a',
#   u'lot',
#   u'of',
#   u'things',
#   u'did',
#   u"n't",
#   u'seem',
#   u'targeted',
#   u'to',
#   u'a',
#   u'broader',
#   u'audience',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Congressman',
#   u'Lazio',
#   u'you',
#   u'have',
#   u'never',
#   u'been',
#   u'on',
#   u'the',
#   u'Trump',
#   u'train',
#   u'.'],
#  [u'Did', u'this', u'speech', u'reach', u'out', u'to', u'you', u'?'],
#  [u'RICK',
#   u'LAZIO',
#   u'FORMER',
#   u'NEW',
#   u'YORK',
#   u'CONGRESSMAN',
#   u':',
#   u'I',
#   u'think',
#   u'Donald',
#   u'Trump',
#   u"'s",
#   u'problem',
#   u'is',
#   u'does',
#   u'he',
#   u'appear',
#   u'presidential',
#   u'?'],
#  [u'So',
#   u'that',
#   u'is',
#   u'an',
#   u'issue',
#   u'that',
#   u"'s",
#   u'been',
#   u'exacerbated',
#   u'from',
#   u'I',
#   u'thought',
#   u'the',
#   u'suggestive',
#   u'prohibition',
#   u'and',
#   u'allowing',
#   u'people',
#   u'based',
#   u'on',
#   u'religious',
#   u'orientation',
#   u'to',
#   u'come',
#   u'into',
#   u'the',
#   u'country',
#   u'which',
#   u'is',
#   u'completely',
#   u'anti-republic',
#   u'and',
#   u'completely',
#   u'anti-',
#   u'American',
#   u'.'],
#  [u'Not',
#   u'what',
#   u'makes',
#   u'America',
#   u'great',
#   u'to',
#   u'the',
#   u'controversy',
#   u'with',
#   u'the',
#   u'Khans',
#   u'through',
#   u'the',
#   u'convention',
#   u'.'],
#  [u'And',
#   u'so',
#   u'his',
#   u'struggle',
#   u'is',
#   u'to',
#   u'really',
#   u'appear',
#   u'to',
#   u'be',
#   u'the',
#   u'commander-in-chief',
#   u'to',
#   u'be',
#   u'confident',
#   u'enough',
#   u'to',
#   u'be',
#   u'knowledgeable',
#   u'enough',
#   u'and',
#   u'to',
#   u'have',
#   u'the',
#   u'ability',
#   u'to',
#   u'project',
#   u'American',
#   u'power',
#   u'appropriately',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Do',
#   u'you',
#   u'think',
#   u'he',
#   u'came',
#   u'out',
#   u'like',
#   u'that',
#   u'today',
#   u'?'],
#  [u'LAZIO', u':', u'I', u'think', u'he', u'struggles', u'with', u'that', u'.'],
#  [u'I', u'think', u'he', u'struggles', u'.'],
#  [u'I',
#   u'think',
#   u'there',
#   u"'s",
#   u'something',
#   u'--',
#   u'I',
#   u'think',
#   u'most',
#   u'Americans',
#   u'would',
#   u'say',
#   u'do',
#   u'you',
#   u'want',
#   u'to',
#   u'do',
#   u'enhanced',
#   u'background',
#   u'checks',
#   u'for',
#   u'new',
#   u'immigrants',
#   u'?'],
#  [u'There', u"'s", u'no', u'right', u'for', u'immigration', u'.'],
#  [u'It',
#   u"'s",
#   u'a',
#   u'privilege',
#   u'to',
#   u'come',
#   u'into',
#   u'the',
#   u'country',
#   u'.'],
#  [u'We',
#   u'should',
#   u'make',
#   u'sure',
#   u'that',
#   u'every',
#   u'immigrant',
#   u'that',
#   u'comes',
#   u'in',
#   u'here',
#   u'has',
#   u'a',
#   u'commitment',
#   u'to',
#   u'America',
#   u'and',
#   u'America',
#   u"'s",
#   u'values',
#   u'.'],
#  [u'I',
#   u"'m",
#   u'completely',
#   u'comfortable',
#   u'with',
#   u'that',
#   u'and',
#   u'I',
#   u'think',
#   u'most',
#   u'Americans',
#   u'are',
#   u'.'],
#  [u'So', u'he', u"'s", u'right', u'about', u'that', u'.'],
#  [u'Where',
#   u'he',
#   u'veers',
#   u'into',
#   u'the',
#   u'religious',
#   u'litmus',
#   u'test',
#   u'is',
#   u'where',
#   u'he',
#   u'loses',
#   u'people',
#   u'where',
#   u'he',
#   u'gets',
#   u'off',
#   u'message',
#   u'.'],
#  [u'He',
#   u"'s",
#   u'got',
#   u'a',
#   u'fantastic',
#   u'critique',
#   u'against',
#   u'Hillary',
#   u'Clinton',
#   u'and',
#   u'Barack',
#   u'Obama',
#   u'in',
#   u'Libya',
#   u'in',
#   u'Egypt',
#   u'and',
#   u'among',
#   u'our',
#   u'allies',
#   u'in',
#   u'Israel',
#   u'.'],
#  [u'A',
#   u'former',
#   u'ally',
#   u'our',
#   u'so-so',
#   u'ally',
#   u'in',
#   u'Turkey',
#   u'and',
#   u'what',
#   u"'s",
#   u'going',
#   u'on',
#   u'in',
#   u'Syria',
#   u'where',
#   u'over',
#   u'a',
#   u'half',
#   u'million',
#   u'people',
#   u'have',
#   u'been',
#   u'slaughtered',
#   u'.'],
#  [u'I',
#   u'mean',
#   u'that',
#   u"'s",
#   u'a',
#   u'fantastic',
#   u'critique',
#   u'He',
#   u'ought',
#   u'to',
#   u'stay',
#   u'on',
#   u'message',
#   u'.'],
#  [u'He',
#   u'ought',
#   u'to',
#   u'talk',
#   u'about',
#   u'America',
#   u"'s",
#   u'power',
#   u'.'],
#  [u'And',
#   u'I',
#   u'think',
#   u'those',
#   u'things',
#   u'that',
#   u'they',
#   u'have',
#   u'to',
#   u'be',
#   u'careful',
#   u'.'],
#  [u'It',
#   u"'s",
#   u'issue',
#   u'de',
#   u'jure',
#   u'to',
#   u'criticize',
#   u'nation',
#   u'building',
#   u'.'],
#  [u'Two',
#   u'of',
#   u'the',
#   u'most',
#   u'successful',
#   u'foreign',
#   u'policy',
#   u'interventions',
#   u'in',
#   u'the',
#   u'post-',
#   u'World',
#   u'War',
#   u'II',
#   u'period',
#   u'were',
#   u'nation-building',
#   u'in',
#   u'Germany',
#   u'and',
#   u'Japan',
#   u'.'],
#  [u'So',
#   u'if',
#   u'done',
#   u'correctly',
#   u'if',
#   u'you',
#   u'can',
#   u'understand',
#   u'the',
#   u'capacity',
#   u'of',
#   u'those',
#   u'countries',
#   u'their',
#   u'ability',
#   u'to',
#   u'have',
#   u'self',
#   u'leadership',
#   u'and',
#   u'understanding',
#   u'of',
#   u'what',
#   u'those',
#   u'values',
#   u'lend',
#   u'themselves',
#   u'then',
#   u'there',
#   u'maybe',
#   u'times',
#   u'when',
#   u'you',
#   u'want',
#   u'to',
#   u'do',
#   u'that',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Angela',
#   u'what',
#   u"'s",
#   u'wrong',
#   u'with',
#   u'extreme',
#   u'vetting',
#   u'?'],
#  [u'I',
#   u'mean',
#   u'why',
#   u'not',
#   u'know',
#   u'everything',
#   u'you',
#   u'can',
#   u'about',
#   u'people',
#   u'who',
#   u'are',
#   u'coming',
#   u'to',
#   u'the',
#   u'country',
#   u'and',
#   u'have',
#   u'them',
#   u'ascribed',
#   u'to',
#   u'American',
#   u'values',
#   u'?'],
#  [u'ANGELA',
#   u'RYE',
#   u'DEMOCRATIC',
#   u'STRATEGIST',
#   u':',
#   u'A',
#   u'couple',
#   u'things',
#   u'.'],
#  [u'One',
#   u'is',
#   u'I',
#   u'find',
#   u'it',
#   u'really',
#   u'challenges',
#   u'that',
#   u'he',
#   u'used',
#   u'the',
#   u'term',
#   u'extreme',
#   u'when',
#   u'talking',
#   u'combating',
#   u'terrorism',
#   u'.'],
#  [u'I',
#   u'do',
#   u"n't",
#   u'know',
#   u'if',
#   u'I',
#   u"'m",
#   u'the',
#   u'only',
#   u'one',
#   u'who',
#   u'struggled',
#   u'with',
#   u'that',
#   u'wording',
#   u'.'],
#  [u'But',
#   u'when',
#   u'you',
#   u"'re",
#   u'talking',
#   u'about',
#   u'extreme',
#   u'vetting',
#   u'again',
#   u'going',
#   u'back',
#   u'into',
#   u'the',
#   u'processes',
#   u'that',
#   u'already',
#   u'exists',
#   u'not',
#   u'only',
#   u'under',
#   u'this',
#   u'current',
#   u'administration',
#   u'but',
#   u'preceding',
#   u'administrations',
#   u'.'],
#  [u'What',
#   u'exactly',
#   u'does',
#   u'extreme',
#   u'vetting',
#   u'look',
#   u'like',
#   u'when',
#   u'you',
#   u"'re",
#   u'talking',
#   u'about',
#   u'the',
#   u'candidate',
#   u'who',
#   u'also',
#   u'supports',
#   u'waterboarding',
#   u'he',
#   u'supports',
#   u'torture',
#   u'?'],
#  [u'So',
#   u'I',
#   u'want',
#   u'to',
#   u'know',
#   u'what',
#   u'exactly',
#   u'that',
#   u'means',
#   u'how',
#   u'does',
#   u'extreme',
#   u'vetting',
#   u'pan',
#   u'when',
#   u'you',
#   u'are',
#   u'talking',
#   u'about',
#   u'states',
#   u'that',
#   u'have',
#   u'the',
#   u'same',
#   u'types',
#   u'of',
#   u'sponsored',
#   u'policies',
#   u'and',
#   u'laws',
#   u'on',
#   u'your',
#   u'books',
#   u'like',
#   u'Russia',
#   u'that',
#   u'are',
#   u'anti-',
#   u'LGBTQ',
#   u'.'],
#  [u'And',
#   u'I',
#   u"'m",
#   u'just',
#   u'saying',
#   u'to',
#   u'that',
#   u'end',
#   u'you',
#   u'said',
#   u'a',
#   u'lot',
#   u'of',
#   u'things',
#   u'that',
#   u'were',
#   u'hypercritical',
#   u'about',
# ...
#   u'a',
#   u'bookmaker',
#   u'.'],
#  [u'You',
#   u'know',
#   u'the',
#   u'part',
#   u'of',
#   u'regions',
#   u'Yanukovych',
#   u'...',
#   u'COOPER',
#   u':',
#   u'In',
#   u'RNC',
#   u'of',
#   u'so',
#   u'called',
#   u'they',
#   u"'re",
#   u'calling',
#   u'a',
#   u'black',
#   u'ledger',
#   u'black',
#   u'book',
#   u'essentially',
#   u'it',
#   u'was',
#   u'found',
#   u'in',
#   u'one',
#   u'of',
#   u'the',
#   u'presidential',
#   u'offices',
#   u'right',
#   u'?'],
#  [u'MEIER', u':', u'Correct', u'.'],
#  [u'And',
#   u'so',
#   u'basically',
#   u'you',
#   u'know',
#   u'they',
#   u'probably',
#   u'had',
#   u'two',
#   u'sets',
#   u'of',
#   u'books',
#   u'one',
#   u'said',
#   u'that',
#   u'they',
#   u'showed',
#   u'to',
#   u'the',
#   u'tax',
#   u'people',
#   u'and',
#   u'another',
#   u'set',
#   u'of',
#   u'books',
#   u'said',
#   u'had',
#   u'all',
#   u'this',
#   u'cash',
#   u'payments',
#   u'in',
#   u'it',
#   u'.'],
#  [u'And',
#   u'so',
#   u'the',
#   u'question',
#   u'is',
#   u'did',
#   u'this',
#   u'money',
#   u'go',
#   u'to',
#   u'Mr.',
#   u'Manafort',
#   u'to',
#   u'his',
#   u'firm',
#   u'to',
#   u'his',
#   u'associates',
#   u'.'],
#  [u'Could',
#   u'--',
#   u'anybody',
#   u'...',
#   u'COOPER',
#   u':',
#   u'Could',
#   u"n't",
#   u'have',
#   u'been',
#   u'I',
#   u'mean',
#   u'he',
#   u'was',
#   u'helping',
#   u'the',
#   u'guy',
#   u'who',
#   u'became',
#   u'president',
#   u'get',
#   u're-elected',
#   u'helping',
#   u'you',
#   u'know',
#   u'organize',
#   u'a',
#   u'campaign',
#   u'election',
#   u'stuff',
#   u'like',
#   u'that',
#   u'which',
#   u'is',
#   u'why',
#   u'I',
#   u'think',
#   u'he',
#   u'said',
#   u'he',
#   u'never',
#   u'worked',
#   u'for',
#   u'the',
#   u'government',
#   u'itself',
#   u'.'],
#  [u'He', u'was', u'working', u'for', u'the', u'campaign', u'.'],
#  [u'Is',
#   u'it',
#   u'possible',
#   u'this',
#   u'were',
#   u'--',
#   u'if',
#   u'these',
#   u'payments',
#   u'were',
#   u'actually',
#   u'made',
#   u'it',
#   u'they',
#   u'were',
#   u'completely',
#   u'legitimate',
#   u'payments',
#   u'for',
#   u'work',
#   u'done',
#   u'on',
#   u'a',
#   u'campaign',
#   u'?'],
#  [u'MEIER', u':', u'Well', u'anything', u'is', u'possible', u'.'],
#  [u'But',
#   u'I',
#   u'mean',
#   u'the',
#   u'question',
#   u'is',
#   u'why',
#   u'were',
#   u'they',
#   u'cash',
#   u'payments',
#   u'?'],
#  [u'And',
#   u'how',
#   u'do',
#   u'those',
#   u'payments',
#   u'or',
#   u'that',
#   u'sum',
#   u'of',
#   u'money',
#   u'relate',
#   u'to',
#   u'the',
#   u'actual',
#   u'money',
#   u'that',
#   u'Mr.',
#   u'Manafort',
#   u'or',
#   u'his',
#   u'you',
#   u'know',
#   u'firm',
#   u'received',
#   u'for',
#   u'the',
#   u'services',
#   u'they',
#   u'provided',
#   u'to',
#   u'Mr.',
#   u'Yanukovych',
#   u'and',
#   u'his',
#   u'party',
#   u'?'],
#  [u'We', u'do', u"n't", u'know', u'what', u'that', u'sum', u'is', u'.'],
#  [u'COOPER', u':', u'Right', u'.'],
#  [u'MEIER',
#   u':',
#   u'And',
#   u'it',
#   u"'s",
#   u'only',
#   u'when',
#   u'you',
#   u'know',
#   u'that',
#   u'sum',
#   u'that',
#   u'you',
#   u'could',
#   u'put',
#   u'these',
#   u'sums',
#   u'into',
#   u'context',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'In',
#   u'his',
#   u'statement',
#   u'he',
#   u'--',
#   u'Manafort',
#   u'seems',
#   u'to',
#   u'take',
#   u'issue',
#   u'with',
#   u'the',
#   u'term',
#   u'off',
#   u'the',
#   u'books',
#   u'cash',
#   u'payment',
#   u'.'],
#  [u'What', u'do', u'you', u'make', u'of', u'that', u'?'],
#  [u'MEIER',
#   u':',
#   u'Well',
#   u'he',
#   u'says',
#   u'I',
#   u'never',
#   u'personally',
#   u'received',
#   u'it',
#   u'.'],
#  [u'He', u'Mr.', u'Manafort', u'.'],
#  [u'So',
#   u'the',
#   u'question',
#   u'was',
#   u'what',
#   u'did',
#   u'his',
#   u'firm',
#   u'receive',
#   u'them',
#   u'?'],
#  [u'Did',
#   u'some',
#   u'of',
#   u'its',
#   u'associates',
#   u'receive',
#   u'these',
#   u'payments',
#   u'?'],
#  [u'That',
#   u'he',
#   u'really',
#   u'does',
#   u"n't",
#   u'address',
#   u'that',
#   u'in',
#   u'his',
#   u'statement',
#   u'and',
#   u'we',
#   u'have',
#   u'really',
#   u'do',
#   u"n't",
#   u'know',
#   u'the',
#   u'answer',
#   u'to',
#   u'that',
#   u'question',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'The',
#   u'other',
#   u'question',
#   u'of',
#   u'course',
#   u'is',
#   u'there',
#   u'linkage',
#   u'between',
#   u'his',
#   u'work',
#   u'for',
#   u'the',
#   u'guy',
#   u'the',
#   u'president',
#   u'of',
#   u'Ukraine',
#   u'and',
#   u'Donald',
#   u'Trump',
#   u"'s",
#   u'positions',
#   u'toward',
#   u'Russia',
#   u'?'],
#  [u'The',
#   u'president',
#   u'--',
#   u'that',
#   u'as',
#   u'I',
#   u'said',
#   u'is',
#   u'no',
#   u'fled',
#   u'he',
#   u"'s",
#   u'living',
#   u'in',
#   u'Russia',
#   u'.'],
#  [u'MEIER', u':', u'Right', u'.'],
#  [u'COOPER',
#   u':',
#   u'And',
#   u'that',
#   u"'s",
#   u'--',
#   u'again',
#   u'what',
#   u'makes',
#   u'this',
#   u'kind',
#   u'of',
#   u'another',
#   u'aspect',
#   u'of',
#   u'the',
#   u'story',
#   u'.'],
#  [u'MEIER', u':', u'I', u'have', u'no', u'idea', u'.'],
#  [u'I',
#   u'mean',
#   u'I',
#   u'have',
#   u'no',
#   u'idea',
#   u'what',
#   u'informed',
#   u'Mr.',
#   u'Trump',
#   u"'s",
#   u'positions',
#   u'on',
#   u'those',
#   u'subjects',
#   u'nor',
#   u'do',
#   u'I',
#   u'know',
#   u'the',
#   u'input',
#   u'Mr.',
#   u'Manafort',
#   u'has',
#   u'into',
#   u'those',
#   u'...',
#   u'(',
#   u'OFF-MIC',
#   u')',
#   u'COOPER',
#   u':',
#   u'What',
#   u'surprised',
#   u'you',
#   u'most',
#   u'about',
#   u'the',
#   u'story',
#   u'about',
#   u'what',
#   u'you',
#   u'find',
#   u'?'],
#  [u'MEIER',
#   u':',
#   u'That',
#   u'you',
#   u'know',
#   u'there',
#   u'would',
#   u'these',
#   u'books',
#   u'showing',
#   u'these',
#   u'payments',
#   u'and',
#   u'there',
#   u"'s",
#   u'this',
#   u'money',
#   u'and',
#   u'either',
#   u'that',
#   u'money',
#   u'exists',
#   u'or',
#   u'does',
#   u"n't",
#   u'exist',
#   u'and',
#   u'somebody',
#   u'got',
#   u'that',
#   u'money',
#   u'.'],
#  [u'And',
#   u'hopefully',
#   u'in',
#   u'days',
#   u'and',
#   u'weeks',
#   u'to',
#   u'come',
#   u'we',
#   u"'ll",
#   u'know',
#   u'more',
#   u'...',
#   u'COOPER',
#   u':',
#   u'Yeah',
#   u'.'],
#  [u'MEIER', u':', u'...', u'where', u'that', u'money', u'went', u'.'],
#  [u'COOPER', u':', u'The', u'investigation', u'continues', u'.'],
#  [u'And', u'you', u'Barry', u'Meier', u'thank', u'you', u'so', u'much', u'.'],
#  [u'Appreciate', u'it', u'.'],
#  [u'Up', u'next', u'historic', u'flooding', u'in', u'Louisiana', u'.'],
#  [u'More',
#   u'than',
#   u'20000',
#   u'people',
#   u'rescued',
#   u'including',
#   u'woman',
#   u'and',
#   u'her',
#   u'dog',
#   u'who',
#   u'were',
#   u'trapped',
#   u'in',
#   u'a',
#   u'car',
#   u'.'],
#  [u'I',
#   u'show',
#   u'you',
#   u'--',
#   u'it',
#   u'was',
#   u'caught',
#   u'on',
#   u'video',
#   u'.'],
#  [u'And',
#   u'look',
#   u'at',
#   u'how',
#   u'they',
#   u'got',
#   u'out',
#   u'when',
#   u'``',
#   u'360',
#   u"''",
#   u'continues',
#   u'.'],
#  [u'(',
#   u'COMMERCIAL',
#   u'BREAK',
#   u')',
#   u'[',
#   u'20:52:13',
#   u']',
#   u'COOPER',
#   u':',
#   u'A',
#   u'devastating',
#   u'flooding',
#   u'has',
#   u'killed',
#   u'at',
#   u'least',
#   u'five',
#   u'people',
#   u'in',
#   u'Louisiana',
#   u'.'],
#  [u'The',
#   u'governor',
#   u'expects',
#   u'30',
#   u'parishes',
#   u'will',
#   u'be',
#   u'declared',
#   u'a',
#   u'major',
#   u'disaster',
#   u'.'],
#  [u'That',
#   u"'s",
#   u'of',
#   u'half',
#   u'the',
#   u'number',
#   u'of',
#   u'parishes',
#   u'in',
#   u'the',
#   u'entire',
#   u'state',
#   u'.'],
#  [u'Streets',
#   u'and',
#   u'rivers',
#   u'in',
#   u'some',
#   u'places',
#   u'homes',
#   u'are',
#   u'now',
#   u'islands',
#   u'.'],
#  [u'More', u'than', u'20000', u'people', u'have', u'been', u'rescued', u'.'],
#  [u'The',
#   u'coast',
#   u'guard',
#   u'first',
#   u'responders',
#   u'volunteers',
#   u'are',
#   u'helping',
#   u'those',
#   u'trapped',
#   u'in',
#   u'flood',
#   u'waters',
#   u'trying',
#   u'to',
#   u'get',
#   u'to',
#   u'dry',
#   u'land',
#   u'.'],
#  [u'Take', u'a', u'look', u'.'],
#  [u'(',
#   u'BEGIN',
#   u'VIDEO',
#   u'CLIP',
#   u')',
#   u'COOPER',
#   u':',
#   u'Rescues',
#   u'by',
#   u'boat',
#   u'from',
#   u'the',
#   u'air',
#   u'even',
#   u'from',
#   u'underneath',
#   u'the',
#   u'flood',
#   u'waters',
#   u'.'],
#  [u'UNIDENTIFIED', u'MALE', u':', u'Get', u'out', u'!'],
#  [u'UNIDENTIFIED', u'FEMALE', u':', u'I', u"'m", u'trying', u'!'],
#  [u'UNIDENTIFIED', u'MALE', u':', u'Give', u'me', u'a', u'knife', u'.'],
#  [u'Give', u'me', u'a', u'knife', u'.'],
#  [u'Give', u'me', u'a', u'knife', u'.'],
#  [u'COOPER',
#   u':',
#   u'This',
#   u'rescue',
#   u'crew',
#   u'in',
#   u'Baton',
#   u'Rouge',
#   u'found',
#   u'a',
#   u'car',
#   u'which',
#   u'was',
#   u'quickly',
#   u'sinking',
#   u'.'],
#  [u'The', u'drives', u'was', u'trapped', u'inside', u'.'],
#  [u'You', u'hear', u'her', u'calling', u'for', u'help', u'.'],
#  [u'UNIDENTIFIED',
#   u'FEMALE',
#   u':',
#   u'Oh',
#   u'my',
#   u'god',
#   u'I',
#   u"'m",
#   u'drowning',
#   u'.'],
#  [u'UNIDENTIFIED', u'MALE', u':', u'We', u"'re", u'coming', u'.'],
#  [u'We', u"'re", u'coming', u'.'],
#  [u'We', u"'re", u'breaking', u'the', u'window', u'.'],
#  [u'COOPER',
#   u':',
#   u'But',
#   u'with',
#   u'the',
#   u'car',
#   u'now',
#   u'almost',
#   u'completely',
#   u'under',
#   u'water',
#   u'one',
#   u'of',
#   u'the',
#   u'rescuers',
#   u'David',
#   u'Phung',
#   u'jumps',
#   u'in',
#   u'the',
#   u'water',
#   u'.'],
#  [u'Grabbing',
#   u'the',
#   u'driver',
#   u"'s",
#   u'arm',
#   u'and',
#   u'pulling',
#   u'her',
#   u'out',
#   u'of',
#   u'the',
#   u'car',
#   u'up',
#   u'to',
#   u'safety',
#   u'.'],
#  [u'UNIDENTIFIED', u'FEMALE', u':', u'Get', u'my', u'dog', u'!'],
#  [u'Get', u'my', u'dog', u'!'],
#  [u'COOPER',
#   u':',
#   u'As',
#   u'soon',
#   u'as',
#   u'she',
#   u"'s",
#   u'able',
#   u'to',
#   u'take',
#   u'a',
#   u'breath',
#   u'she',
#   u'pleads',
#   u'with',
#   u'Phung',
#   u'to',
#   u'save',
#   u'her',
#   u'dog',
#   u'still',
#   u'trapped',
#   u'inside',
#   u'the',
#   u'car',
#   u'.'],
#  [u'DAVID',
#   u'PHUNG',
#   u'LOUISIANA',
#   u'RESCUER',
#   u':',
#   u'I',
#   u'will',
#   u'get',
#   u'the',
#   u'dog',
#   u'.'],
#  [u'Here', u'here', u'.'],
#  [u'I', u'ca', u"n't", u'get', u'the', u'dog', u'.'],
#  [u'UNIDENTIFIED',
#   u'FEMALE',
#   u':',
#   u'(',
#   u'Inaudible',
#   u')',
#   u'PHUNG',
#   u':',
#   u'Then',
#   u'she',
#   u"'s",
#   u'gone',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'So',
#   u'he',
#   u'dives',
#   u'back',
#   u'down',
#   u'under',
#   u'the',
#   u'water',
#   u'.'],
#  [u'PHUNG', u':', u'I', u'got', u'your', u'dog', u'!'],
#  [u'UNIDENTIFIED', u'FEMALE', u':', u'Oh', u'you', u'are', u'amazing', u'.'],
#  [u'COOPER', u':', u'In', u'the', u'end', u'saving', u'them', u'both', u'.'],
#  [u'Officials',
#   u'and',
#   u'volunteers',
#   u'in',
#   u'Louisiana',
#   u'are',
#   u'working',
#   u'around',
#   u'the',
#   u'clock',
#   u'to',
#   u'help',
#   u'those',
#   u'stranded',
#   u'by',
#   u'the',
#   u'devastating',
#   u'floods',
#   u'.'],
#  [u'Those',
#   u'able',
#   u'to',
#   u'walk',
#   u'through',
#   u'the',
#   u'rushing',
#   u'water',
#   u'are',
#   u'given',
#   u'a',
#   u'helping',
#   u'hand',
#   u'to',
#   u'higher',
#   u'ground',
#   u'.'],
#  [u'Those',
#   u'unable',
#   u'to',
#   u'make',
#   u'it',
#   u'on',
#   u'their',
#   u'own',
#   u'are',
#   u'carried',
#   u'to',
#   u'safety',
#   u'.'],
#  [u'GOV', u'.'],
#  [u'JOHN',
#   u'BEL',
#   u'EDWARDS',
#   u'(',
#   u'D',
#   u')',
#   u'LOUISIANA',
#   u':',
#   u'As',
#   u'of',
#   u'right',
#   u'now',
#   u'there',
#   u'have',
#   u'been',
#   u'more',
#   u'than',
#   u'20000',
#   u'people',
#   u'rescued',
#   u'from',
#   u'their',
#   u'homes',
#   u'in',
#   u'and',
#   u'around',
#   u'southern',
#   u'Louisiana',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'Pets',
#   u'were',
#   u"n't",
#   u'left',
#   u'behind',
#   u'in',
#   u'these',
#   u'rescues',
#   u'.'],
#  [u'This',
#   u'military',
#   u'convoy',
#   u'made',
#   u'room',
#   u'for',
#   u'dogs',
#   u'as',
#   u'well',
#   u'as',
#   u'people',
#   u'.'],
#  [u'They', u'fled', u'the', u'Baton', u'Rouge', u'area', u'.'],
#  [u'The',
#   u'flood',
#   u'waters',
#   u'are',
#   u'not',
#   u'expected',
#   u'to',
#   u'recede',
#   u'for',
#   u'days',
#   u'with',
#   u'many',
#   u'still',
#   u'trapped',
#   u'inside',
#   u'their',
#   u'homes',
#   u'rescue',
#   u'operations',
#   u'continue',
#   u'.'],
#  [u'Images',
#   u'like',
#   u'these',
#   u'evoking',
#   u'memories',
#   u'of',
#   u'Hurricane',
#   u'Katrina',
#   u'which',
#   u'hit',
#   u'this',
#   u'region',
#   u'11',
#   u'years',
#   u'ago',
#   u'this',
#   u'month',
#   u'.'],
#  [u'(',
#   u'END',
#   u'VIDEO',
#   u'CLIP',
#   u')',
#   u'COOPER',
#   u':',
#   u'Over',
#   u'the',
#   u'weekend',
#   u'more',
#   u'than',
#   u'20',
#   u'inches',
#   u'of',
#   u'rain',
#   u'fell',
#   u'in',
#   u'and',
#   u'around',
#   u'Baton',
#   u'Rouge',
#   u'and',
#   u'more',
#   u'is',
#   u'on',
#   u'the',
#   u'way',
#   u'.'],
#  [u'The',
#   u'water',
#   u'is',
#   u'not',
#   u'done',
#   u'rising',
#   u'in',
#   u'Louisiana',
#   u'.'],
#  [u'Our',
#   u'meteorologist',
#   u'Jennifer',
#   u'Gray',
#   u'joins',
#   u'us',
#   u'from',
#   u'Baton',
#   u'Rouge',
#   u'with',
#   u'more',
#   u'.'],
#  [u'So',
#   u'almost',
#   u'two',
#   u'feet',
#   u'of',
#   u'rain',
#   u'in',
#   u'just',
#   u'a',
#   u'few',
#   u'days',
#   u'.'],
#  [u'How', u'is', u'the', u'community', u'coping', u'?'],
#  [u'[',
#   u'20:55:07',
#   u']',
#   u'JENNIFER',
#   u'GRAY',
#   u'CNN',
#   u'METEOROLOGIST',
#   u':',
#   u'Well',
#   u'this',
#   u'is',
#   u'a',
#   u'one',
#   u'in',
#   u'1000',
#   u'year',
#   u'flood',
#   u'.'],
#  [u'And',
#   u'this',
#   u'comes',
#   u'just',
#   u'on',
#   u'the',
#   u'heels',
#   u'six',
#   u'months',
#   u'ago',
#   u'we',
#   u'had',
#   u'a',
#   u'historic',
#   u'flood',
#   u'across',
#   u'south',
#   u'Louisiana',
#   u'and',
#   u'so',
#   u'now',
#   u'we',
#   u"'re",
#   u'seeing',
#   u'another',
#   u'one',
#   u'.'],
#  [u'And',
#   u'you',
#   u'know',
#   u'the',
#   u'front',
#   u'cover',
#   u'of',
#   u'the',
#   u'``',
#   u'Time',
#   u"''",
#   u'newspaper',
#   u'this',
#   u'morning',
#   u'said',
#   u'like',
#   u'Katrina',
#   u'all',
#   u'over',
#   u'again',
#   u'.'],
#  [u'And',
#   u'Anderson',
#   u'I',
#   u'think',
#   u'the',
#   u'images',
#   u'of',
#   u'people',
#   u'climbing',
#   u'out',
#   u'of',
#   u'their',
#   u'roofs',
#   u'to',
#   u'get',
#   u'to',
#   u'safety',
#   u'to',
#   u'get',
#   u'on',
#   u'people',
#   u"'s",
#   u'boats',
#   u'to',
#   u'get',
#   u'out',
#   u'of',
#   u'their',
#   u'neighborhoods',
#   u'was',
#   u'haunting',
#   u'for',
#   u'people',
#   u'across',
#   u'south',
#   u'Louisiana',
#   u'.'],
#  [u'We',
#   u'have',
#   u'drone',
#   u'footage',
#   u'now',
#   u'and',
#   u'you',
#   u'can',
#   u'see',
#   u'the',
#   u'scope',
#   u'of',
#   u'what',
#   u'we',
#   u"'re",
#   u'talking',
#   u'about',
#   u'water',
#   u'chest-high',
#   u'inside',
#   u'people',
#   u"'s",
#   u'homes',
#   u'.'],
#  [u'It',
#   u"'s",
#   u'going',
#   u'to',
#   u'be',
#   u'a',
#   u'long',
#   u'time',
#   u'before',
#   u'they',
#   u'are',
#   u'able',
#   u'to',
#   u'get',
#   u'back',
#   u'in',
#   u'Anderson',
#   u'.'],
#  [u'COOPER',
#   u':',
#   u'That',
#   u"'s",
#   u'drone',
#   u'footage',
#   u'from',
#   u'the',
#   u'area',
#   u'where',
#   u'you',
#   u'are',
#   u'in',
#   u'.'],
#  [u'Jennifer', u'I', u'mean', u'is', u'more', u'rain', u'expected', u'?'],
#  [u'What', u"'s", u'the', u'forecast', u'?'],
#  [u'GRAY',
#   u':',
#   u'Well',
#   u'we',
#   u'are',
#   u'looking',
#   u'at',
#   u'a',
#   u'little',
#   u'bit',
#   u'more',
#   u'rain',
#   u'each',
#   u'day',
#   u'.'],
#  [u'We',
#   u"'re",
#   u'not',
#   u'going',
#   u'to',
#   u'see',
#   u'some',
#   u'widespread',
#   u'all',
#   u'day',
#   u'rain',
#   u'but',
#   u'we',
#   u'will',
#   u'see',
#   u'pop-up',
#   u'showers',
#   u'that',
#   u'it',
#   u'should',
#   u"n't",
#   u'do',
#   u'too',
#   u'much',
#   u'as',
#   u'far',
#   u'as',
#   u'worsen',
#   u'the',
#   u'flood',
#   u'but',
#   u'lot',
#   u'of',
#   u'the',
#   u'rivers',
#   u'have',
#   u'already',
#   u'crested',
#   u'.'],
#  [u'But',
#   u'keep',
#   u'in',
#   u'mind',
#   u'this',
#   u'is',
#   u'going',
#   u'to',
#   u'be',
#   u'a',
#   u'very',
#   u'slow',
#   u'climb',
#   u'downwards',
#   u'.'],
#  [u'We', u'are', u'talking', u'about', u'days', u'not', u'hours', u'.'],
#  [u'So',
#   u'some',
#   u'of',
#   u'these',
#   u'rivers',
#   u'could',
#   u'sit',
#   u'at',
#   u'where',
#   u'they',
#   u'crested',
#   u'for',
#   u'several',
#   u'days',
#   u'.'],
#  [u'So',
#   u'we',
#   u"'re",
#   u'talking',
#   u'about',
#   u'these',
#   u'houses',
#   u'behind',
#   u'me',
#   u'with',
#   u'water',
#   u'inside',
#   u'.'],
#  [u'It',
#   u'could',
#   u'be',
#   u'the',
#   u'end',
#   u'of',
#   u'the',
#   u'week',
#   u'before',
#   u'they',
#   u"'re",
#   u'able',
#   u'to',
#   u'get',
#   u'in',
#   u'their',
#   u'front',
#   u'door',
#   u'Anderson',
#   u'.'],
#  [u'COOPER', u':', u'Just', u'terrible', u'.'],
#  [u'Jennifer', u'Gray', u'I', u'appreciate', u'you', u'being', u'there', u'.'],
#  [u'Thank', u'you', u'.'],
#  [u'In',
#   u'the',
#   u'next',
#   u'hour',
#   u'of',
#   u'``',
#   u'360',
#   u"''",
#   u'Donald',
#   u'Trump',
#   u'proposes',
#   u'what',
#   u'he',
#   u'calls',
#   u'extreme',
#   u'vetting',
#   u'of',
#   u'immigrants',
#   u'and',
#   u'other',
#   u'steps',
#   u'as',
#   u'he',
#   u'unveils',
#   u'his',
#   u'plan',
#   u'to',
#   u'defeat',
#   u'ISIS',
#   u'.'],
#  [u'(', u'COMMERCIAL', u'BREAK', u')']]

# %%
pos = [nltk.pos_tag(word) for word in words]

# %%
pos
# Out:
# [[(u'[', 'NN'),
#   (u'20:00:21', 'CD'),
#   (u']', 'CD'),
#   (u'ANDERSON', 'NNP'),
#   (u'COOPER', 'NNP'),
#   (u'CNN', 'NNP'),
#   (u'ANCHOR', 'NNP'),
#   (u':', ':'),
#   (u'Good', 'NNP'),
#   (u'evening', 'NN'),
#   (u'.', '.')],
#  [(u'Thanks', 'NNS'),
#   (u'for', 'IN'),
#   (u'joining', 'VBG'),
#   (u'us', 'PRP'),
#   (u'.', '.')],
#  [(u'Tonight', 'NNP'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'on', 'IN'),
#   (u'prompter', 'NN'),
#   (u'and', 'CC'),
#   (u'on', 'IN'),
#   (u'message', 'NN'),
#   (u'for', 'IN'),
#   (u'a', 'DT'),
#   (u'second', 'JJ'),
#   (u'straight', 'NN'),
#   (u'Monday', 'NNP'),
#   (u'this', 'DT'),
#   (u'time', 'NN'),
#   (u'laying', 'VBG'),
#   (u'out', 'RP'),
#   (u'his', 'PRP$'),
#   (u'plan', 'NN'),
#   (u'for', 'IN'),
#   (u'defeating', 'NN'),
#   (u'ISIS', 'NNP'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'for', 'IN'),
#   (u'a', 'DT'),
#   (u'second', 'JJ'),
#   (u'straight', 'NN'),
#   (u'Monday', 'NNP'),
#   (u'Republicans', 'NNP'),
#   (u'holding', 'VBG'),
#   (u'their', 'PRP$'),
#   (u'breath', 'NN'),
#   (u'hoping', 'VBG'),
#   (u'tomorrow', 'NN'),
#   (u'wo', 'MD'),
#   (u"n't", 'RB'),
#   (u'be', 'VB'),
#   (u'another', 'DT'),
#   (u'Tuesday', 'NNP'),
#   (u'like', 'IN'),
#   (u'last', 'JJ'),
#   (u'Tuesday', 'NNP'),
#   (u'when', 'WRB'),
#   (u'Trump', 'NNP'),
#   (u'got', 'VBD'),
#   (u'off', 'RP'),
#   (u'message', 'NN'),
#   (u'and', 'CC'),
#   (u'to', 'TO'),
#   (u'many', 'JJ'),
#   (u'campaign', 'NN'),
#   (u'watchers', 'NNS'),
#   (u'stayed', 'VBD'),
#   (u'that', 'IN'),
#   (u'way', 'NN'),
#   (u'all', 'DT'),
#   (u'week', 'NN'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'this', 'DT'),
#   (u'afternoon', 'NN'),
#   (u'under', 'IN'),
#   (u'pressure', 'NN'),
#   (u'from', 'IN'),
#   (u'the', 'DT'),
#   (u'party', 'NN'),
#   (u'and', 'CC'),
#   (u'trailing', 'VBG'),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'new', 'JJ'),
#   (u'batch', 'NN'),
#   (u'of', 'IN'),
#   (u'polling', 'VBG'),
#   (u'in', 'IN'),
#   (u'key', 'JJ'),
#   (u'battleground', 'NN'),
#   (u'states', 'NNS'),
#   (u'Trump', 'NNP'),
#   (u'stepped', 'VBD'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'microphone', 'NN'),
#   (u'looked', 'VBD'),
#   (u'into', 'IN'),
#   (u'the', 'DT'),
#   (u'teleprompter', 'NN'),
#   (u'and', 'CC'),
#   (u'started', 'VBD'),
#   (u'reading', 'NN'),
#   (u'.', '.')],
#  [(u'CNN', 'NNP'),
#   (u"'s", 'POS'),
#   (u'Sara', 'NNP'),
#   (u'Murray', 'NNP'),
#   (u'reports', 'VBZ'),
#   (u'.', '.')],
#  [(u'(', 'NN'),
#   (u'BEGIN', 'NNP'),
#   (u'VIDEOTAPE', 'NNP'),
#   (u')', 'NNP'),
#   (u'SARA', 'NNP'),
#   (u'MURRAY', 'NNP'),
#   (u'CNN', 'NNP'),
#   (u'POLITICS', 'NNP'),
#   (u'REPORTER', 'NNP'),
#   (u'(', 'NNP'),
#   (u'voice-over', 'NNP'),
#   (u')', 'NNP'),
#   (u':', ':'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'battling', 'NN'),
#   (u'to', 'TO'),
#   (u'take', 'VB'),
#   (u'control', 'NN'),
#   (u'of', 'IN'),
#   (u'his', 'PRP$'),
#   (u'campaign', 'NN'),
#   (u'message', 'NN'),
#   (u'by', 'IN'),
#   (u'laying', 'NN'),
#   (u'out', 'IN'),
#   (u'his', 'PRP$'),
#   (u'vision', 'NN'),
#   (u'to', 'TO'),
#   (u'defeat', 'VB'),
#   (u'ISIS', 'NNP'),
#   (u'.', '.')],
#  [(u'DONALD', 'NNP'),
#   (u'TRUMP', 'NNP'),
#   (u'(', 'NNP'),
#   (u'R', 'NNP'),
#   (u')', 'NNP'),
#   (u'PRESIDENTIAL', 'NNP'),
#   (u'NOMINEE', 'NNP'),
#   (u':', ':'),
#   (u'We', 'PRP'),
#   (u'can', 'MD'),
#   (u'not', 'RB'),
#   (u'let', 'VB'),
#   (u'this', 'DT'),
#   (u'evil', 'JJ'),
#   (u'continue', 'NN'),
#   (u'.', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'Trump', 'NNP'),
#   (u'looking', 'NN'),
#   (u'to', 'TO'),
#   (u'rebound', 'VB'),
#   (u'from', 'IN'),
#   (u'a', 'DT'),
#   (u'rocky', 'JJ'),
#   (u'stretch', 'NN'),
#   (u'and', 'CC'),
#   (u'ginning', 'VBG'),
#   (u'up', 'RP'),
#   (u'doubts', 'NNS'),
#   (u'about', 'IN'),
#   (u'Hillary', 'NNP'),
#   (u'Clinton', 'NNP'),
#   (u"'s", 'POS'),
#   (u'foreign', 'JJ'),
#   (u'policy', 'NN'),
#   (u'chops', 'NNS'),
#   (u'.', '.')],
#  [(u'TRUMP', 'NNP'),
#   (u':', ':'),
#   (u'With', 'IN'),
#   (u'one', 'CD'),
#   (u'episode', 'NN'),
#   (u'of', 'IN'),
#   (u'bad', 'JJ'),
#   (u'judgment', 'NN'),
#   (u'after', 'IN'),
#   (u'another', 'DT'),
#   (u'Hillary', 'NNP'),
#   (u'Clinton', 'NNP'),
#   (u"'s", 'POS'),
#   (u'policies', 'NNS'),
#   (u'launched', 'VBD'),
#   (u'ISIS', 'NNP'),
#   (u'on', 'IN'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'world', 'NN'),
#   (u'stage', 'NN'),
#   (u'.', '.')],
#  [(u'Things', 'NNS'),
#   (u'turned', 'VBD'),
#   (u'out', 'RP'),
#   (u'really', 'RB'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'not', 'RB'),
#   (u'so', 'RB'),
#   (u'hot', 'JJ'),
#   (u'for', 'IN'),
#   (u'our', 'PRP$'),
#   (u'world', 'NN'),
#   (u'and', 'CC'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'.', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'Even', 'RB'),
#   (u'questioning', 'VBG'),
#   (u'whether', 'IN'),
#   (u'she', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'physically', 'RB'),
#   (u'fit', 'JJ'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'commander', 'NN'),
#   (u'in', 'IN'),
#   (u'chief', 'NN'),
#   (u'.', '.')],
#  [(u'TRUMP', 'NNP'),
#   (u':', ':'),
#   (u'She', 'PRP'),
#   (u'also', 'RB'),
#   (u'lacks', 'VBZ'),
#   (u'the', 'DT'),
#   (u'mental', 'JJ'),
#   (u'and', 'CC'),
#   (u'physical', 'JJ'),
#   (u'stamina', 'NN'),
#   (u'to', 'TO'),
#   (u'take', 'VB'),
#   (u'on', 'IN'),
#   (u'ISIS', 'NNP'),
#   (u'and', 'CC'),
#   (u'all', 'DT'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'many', 'JJ'),
#   (u'adversaries', 'NNS'),
#   (u'we', 'PRP'),
#   (u'face', 'VBP'),
#   (u'.', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'The', 'DT'),
#   (u'billionaire', 'NN'),
#   (u'businessman', 'NN'),
#   (u'calling', 'VBG'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'to', 'TO'),
#   (u'abandon', 'VB'),
#   (u'the', 'DT'),
#   (u'attempts', 'NNS'),
#   (u'at', 'IN'),
#   (u'nation', 'NN'),
#   (u'building', 'NN'),
#   (u'and', 'CC'),
#   (u'saying', 'VBG'),
#   (u'it', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'time', 'NN'),
#   (u'to', 'TO'),
#   (u'focus', 'VB'),
#   (u'on', 'IN'),
#   (u'fighting', 'NN'),
#   (u'ISIS', 'NNP'),
#   (u'on', 'IN'),
#   (u'all', 'DT'),
#   (u'fronts', 'NNS'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'GOP', 'NNP'),
#   (u'nominee', 'NN'),
#   (u'framing', 'VBG'),
#   (u'it', 'PRP'),
#   (u'as', 'IN'),
#   (u'an', 'DT'),
#   (u'ideological', 'JJ'),
#   (u'war', 'NN'),
#   (u'harkening', 'VBG'),
#   (u'going', 'VBG'),
#   (u'back', 'RB'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'day', 'NN'),
#   (u'of', 'IN'),
#   (u'George', 'NNP'),
#   (u'W.', 'NNP'),
#   (u'Bush', 'NNP'),
#   (u'as', 'IN'),
#   (u'he', 'PRP'),
#   (u'called', 'VBD'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'to', 'TO'),
#   (u'team', 'VB'),
#   (u'up', 'RP'),
#   (u'with', 'IN'),
#   (u'any', 'DT'),
#   (u'ally', 'RB'),
#   (u'willing', 'JJ'),
#   (u'to', 'TO'),
#   (u'help', 'VB'),
#   (u'battle', 'NN'),
#   (u'ISIS', 'NNP'),
#   (u'.', '.')],
#  [(u'TRUMP', 'NNP'),
#   (u':', ':'),
#   (u'We', 'PRP'),
#   (u'can', 'MD'),
#   (u'not', 'RB'),
#   (u'always', 'RB'),
#   (u'choose', 'VB'),
#   (u'our', 'PRP$'),
#   (u'friends', 'NNS'),
#   (u'but', 'CC'),
#   (u'we', 'PRP'),
#   (u'can', 'MD'),
#   (u'never', 'RB'),
#   (u'fail', 'VB'),
#   (u'to', 'TO'),
#   (u'recognize', 'VB'),
#   (u'our', 'PRP$'),
#   (u'enemies', 'NNS'),
#   (u'.', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'Trump', 'NNP'),
#   (u'also', 'RB'),
#   (u'flushing', 'VBG'),
#   (u'out', 'RP'),
#   (u'his', 'PRP$'),
#   (u'controversial', 'JJ'),
#   (u'plan', 'NN'),
#   (u'to', 'TO'),
#   (u'block', 'VB'),
#   (u'immigrants', 'NNS'),
#   (u'from', 'IN'),
#   (u'countries', 'NNS'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u'claims', 'VBZ'),
#   (u'breed', 'VBN'),
#   (u'terrorism', 'NN'),
#   (u'proposing', 'VBG'),
#   (u'a', 'DT'),
#   (u'test', 'NN'),
#   (u'to', 'TO'),
#   (u'determine', 'VB'),
#   (u'whether', 'IN'),
#   (u'immigrants', 'NNS'),
#   (u'hold', 'VBP'),
#   (u'extremist', 'JJ'),
#   (u'views', 'NNS'),
#   (u'that', 'WDT'),
#   (u'do', 'VBP'),
#   (u"n't", 'RB'),
#   (u'mesh', 'VB'),
#   (u'with', 'IN'),
#   (u'American', 'JJ'),
#   (u'ideals', 'NNS'),
#   (u'.', '.')],
#  [(u'TRUMP', 'NNP'),
#   (u':', ':'),
#   (u'I', 'PRP'),
#   (u'call', 'VBP'),
#   (u'it', 'PRP'),
#   (u'extreme', 'RB'),
#   (u'extreme', 'VB'),
#   (u'vetting', 'VBG'),
#   (u'.', '.')],
#  [(u'Our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'has', 'VBZ'),
#   (u'enough', 'RB'),
#   (u'problems', 'NNS'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u'do', 'VBP'),
#   (u"n't", 'RB'),
#   (u'need', 'VB'),
#   (u'more', 'JJR'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'these', 'DT'),
#   (u'are', 'VBP'),
#   (u'problems', 'NNS'),
#   (u'like', 'IN'),
#   (u'we', 'PRP'),
#   (u'have', 'VBP'),
#   (u'never', 'RB'),
#   (u'had', 'VBD'),
#   (u'before', 'IN'),
#   (u'.', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'But', 'CC'),
#   (u'such', 'JJ'),
#   (u'a', 'DT'),
#   (u'screening', 'NN'),
#   (u'comes', 'VBZ'),
#   (u'with', 'IN'),
#   (u'logistical', 'JJ'),
#   (u'hurdles', 'NNS'),
#   (u'and', 'CC'),
#   (u'Trump', 'NNP'),
#   (u'offered', 'VBD'),
#   (u'few', 'JJ'),
#   (u'details', 'NNS'),
#   (u'on', 'IN'),
#   (u'how', 'WRB'),
#   (u'he', 'PRP'),
#   (u'would', 'MD'),
#   (u'implement', 'VB'),
#   (u'the', 'DT'),
#   (u'kind', 'NN'),
#   (u'of', 'IN'),
#   (u'ideological', 'JJ'),
#   (u'test', 'NN'),
#   (u'he', 'PRP'),
#   (u'laid', 'VBD'),
#   (u'out', 'RP'),
#   (u'today', 'NN'),
#   (u'.', '.')],
#  [(u'TRUMP', 'NNP'),
#   (u':', ':'),
#   (u'In', 'NNP'),
#   (u'addition', 'NN'),
#   (u'to', 'TO'),
#   (u'screening', 'VBG'),
#   (u'out', 'RP'),
#   (u'all', 'DT'),
#   (u'members', 'NNS'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'sympathizers', 'NNS'),
#   (u'of', 'IN'),
#   (u'terrorist', 'NN'),
#   (u'groups', 'NNS'),
#   (u'we', 'PRP'),
#   (u'must', 'MD'),
#   (u'also', 'RB'),
#   (u'screen', 'VB'),
#   (u'out', 'RP'),
#   (u'any', 'DT'),
#   (u'of', 'IN'),
#   (u'hostile', 'NN'),
#   (u'attitudes', 'NNS'),
#   (u'toward', 'IN'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'or', 'CC'),
#   (u'principles', 'NNS'),
#   (u'or', 'CC'),
#   (u'who', 'WP'),
#   (u'believe', 'VBP'),
#   (u'that', 'IN'),
#   (u'Sharia', 'NNP'),
#   (u'law', 'NN'),
#   (u'should', 'MD'),
#   (u'supplant', 'VB'),
#   (u'American', 'JJ'),
#   (u'law', 'NN'),
#   (u'.', '.')],
#  [(u'Those', 'DT'),
#   (u'who', 'WP'),
#   (u'do', 'VBP'),
#   (u'not', 'RB'),
#   (u'believe', 'VB'),
#   (u'in', 'IN'),
#   (u'our', 'PRP$'),
#   (u'Constitution', 'NNP'),
#   (u'or', 'CC'),
#   (u'who', 'WP'),
#   (u'support', 'NN'),
#   (u'bigotry', 'VBP'),
#   (u'and', 'CC'),
#   (u'hatred', 'VBN'),
#   (u'will', 'MD'),
#   (u'not', 'RB'),
#   (u'be', 'VB'),
#   (u'admitted', 'VBN'),
#   (u'for', 'IN'),
#   (u'immigration', 'NN'),
#   (u'into', 'IN'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'.', '.')],
#  [(u'Only', 'RB'),
#   (u'those', 'DT'),
#   (u'who', 'WP'),
#   (u'we', 'PRP'),
#   (u'expect', 'VBP'),
#   (u'to', 'TO'),
#   (u'flourish', 'VB'),
#   (u'in', 'IN'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'and', 'CC'),
#   (u'to', 'TO'),
#   (u'embrace', 'VB'),
#   (u'a', 'DT'),
#   (u'tolerant', 'JJ'),
#   (u'American', 'JJ'),
#   (u'society', 'NN'),
#   (u'should', 'MD'),
#   (u'be', 'VB'),
#   (u'issued', 'VBN'),
#   (u'visas', 'NNS'),
#   (u'.', '.')],
#  [(u'(', 'NN'),
#   (u'END', 'NN'),
#   (u'VIDEOTAPE', 'NN'),
#   (u')', ':'),
#   (u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Sara', 'NNP'),
#   (u'Murray', 'NNP'),
#   (u'joins', 'VBZ'),
#   (u'us', 'PRP'),
#   (u'now', 'RB'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'clearly', 'RB'),
#   (u'on', 'IN'),
#   (u'message', 'NN'),
#   (u'today', 'NN'),
#   (u'.', '.')],
#  [(u'How', 'WRB'),
#   (u'much', 'JJ'),
#   (u'concern', 'NN'),
#   (u'is', 'VBZ'),
#   (u'there', 'EX'),
#   (u'tonight', 'NN'),
#   (u'that', 'WDT'),
#   (u'he', 'PRP'),
#   (u'can', 'MD'),
#   (u'actually', 'RB'),
#   (u'stay', 'VB'),
#   (u'on', 'IN'),
#   (u'message', 'NN'),
#   (u'?', '.')],
#  [(u'MURRAY', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'Anderson', 'NNP'),
#   (u'I', 'NNP'),
#   (u'think', 'VBP'),
#   (u'that', 'IN'),
#   (u"'s", 'POS'),
#   (u'always', 'NNS'),
#   (u'a', 'DT'),
#   (u'concern', 'NN'),
#   (u'when', 'WRB'),
#   (u'it', 'PRP'),
#   (u'comes', 'VBZ'),
#   (u'to', 'TO'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'especially', 'RB'),
#   (u'since', 'IN'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'this', 'DT'),
#   (u'pattern', 'NN'),
#   (u'of', 'IN'),
#   (u'one', 'CD'),
#   (u'day', 'NN'),
#   (u'showing', 'NN'),
#   (u'up', 'IN'),
#   (u'reading', 'NN'),
#   (u'from', 'IN'),
#   (u'the', 'DT'),
#   (u'teleprompter', 'NN'),
#   (u'sticking', 'VBG'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'script', 'NN'),
#   (u'and', 'CC'),
#   (u'then', 'RB'),
#   (u'just', 'RB'),
#   (u'24', 'CD'),
#   (u'hours', 'NNS'),
#   (u'later', 'JJ'),
#   (u'sometimes', 'NNS'),
#   (u'even', 'RB'),
#   (u'less', 'JJR'),
#   (u'than', 'IN'),
#   (u'that', 'DT'),
#   (u'he', 'PRP'),
#   (u'veers', 'VBZ'),
#   (u'off', 'RP'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'traditional', 'JJ'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'off', 'IN'),
#   (u'the', 'DT'),
#   (u'cuff', 'NN'),
#   (u'message', 'NN'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'sign', 'NN'),
#   (u'of', 'IN'),
#   (u'that', 'DT'),
#   (u'frustration', 'NN'),
#   (u'we', 'PRP'),
#   (u'saw', 'VBD'),
#   (u'``', '``'),
#   (u'The', 'DT'),
#   (u'Wall', 'NNP'),
#   (u'Street', 'NNP'),
#   (u'Journal', 'NNP'),
#   (u"''", "''"),
#   (u'editorial', 'NN'),
#   (u'page', 'NN'),
#   (u'has', 'VBZ'),
#   (u'been', 'VBN'),
#   (u'friendly', 'JJ'),
#   (u'to', 'TO'),
#   (u'Republicans', 'NNP'),
#   (u'came', 'VBD'),
#   (u'out', 'RP'),
#   (u'and', 'CC'),
#   (u'go', 'VB'),
#   (u'after', 'IN'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'saying', 'VBG'),
#   (u'he', 'PRP'),
#   (u'needs', 'VBZ'),
#   (u'to', 'TO'),
#   (u'stop', 'VB'),
#   (u'blaming', 'NN'),
#   (u'everybody', 'NN'),
#   (u'else', 'RB'),
#   (u'saying', 'VBG'),
#   (u'he', 'PRP'),
#   (u'needs', 'VBZ'),
#   (u'to', 'TO'),
#   (u'turn', 'VB'),
#   (u'his', 'PRP$'),
#   (u'campaign', 'NN'),
#   (u'around', 'IN'),
#   (u'by', 'IN'),
#   (u'Labor', 'NNP'),
#   (u'Day', 'NNP'),
#   (u'and', 'CC'),
#   (u'even', 'RB'),
#   (u'suggesting', 'VBG'),
#   (u'that', 'IN'),
#   (u'if', 'IN'),
#   (u'he', 'PRP'),
#   (u'ca', 'MD'),
#   (u"n't", 'RB'),
#   (u'pull', 'VB'),
#   (u'that', 'IN'),
#   (u'off', 'IN'),
#   (u'he', 'PRP'),
#   (u'should', 'MD'),
#   (u'turn', 'VB'),
#   (u'the', 'DT'),
#   (u'nomination', 'NN'),
#   (u'over', 'IN'),
#   (u'to', 'TO'),
#   (u'Mike', 'NNP'),
#   (u'Pence', 'NNP'),
#   (u'--', ':'),
#   (u'Anderson', 'NNP'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Yes', 'NNPS'),
#   (u'Sara', 'NNP'),
#   (u'Murray', 'NNP'),
#   (u'--', ':'),
#   (u'Sara', 'NNP'),
#   (u'thanks', 'NNS'),
#   (u'.', '.')],
#  [(u'A', 'DT'),
#   (u'closer', 'NN'),
#   (u'look', 'NN'),
#   (u'now', 'RB'),
#   (u'the', 'DT'),
#   (u'meat', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'speech', 'NN'),
#   (u'and', 'CC'),
#   (u'substance', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'plan', 'NN'),
#   (u'.', '.')],
#  [(u'Joining', 'VBG'),
#   (u'us', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'Trump', 'NNP'),
#   (u'supporter', 'NN'),
#   (u'former', 'NN'),
#   (u'Trump', 'NNP'),
#   (u'campaign', 'NN'),
#   (u'chairman', 'NN'),
#   (u'excuse', 'NN'),
#   (u'me', 'PRP'),
#   (u'campaign', 'NN'),
#   (u'manager', 'NN'),
#   (u'Corey', 'NNP'),
#   (u'Lewandowski', 'NNP'),
#   (u'also', 'RB'),
#   (u'CNN', 'NNP'),
#   (u'senior', 'JJ'),
#   (u'international', 'JJ'),
#   (u'correspondent', 'NN'),
#   (u'Clarissa', 'NNP'),
#   (u'Ward', 'NNP'),
#   (u'and', 'CC'),
#   (u'Democratic', 'JJ'),
#   (u'Congressman', 'NNP'),
#   (u'Seth', 'NNP'),
#   (u'Moulton', 'NNP'),
#   (u'who', 'WP'),
#   (u'served', 'VBD'),
#   (u'four', 'CD'),
#   (u'tours', 'NNS'),
#   (u'of', 'IN'),
#   (u'duty', 'NN'),
#   (u'in', 'IN'),
#   (u'Iraq', 'NNP'),
#   (u'including', 'VBG'),
#   (u'two', 'CD'),
#   (u'as', 'IN'),
#   (u'a', 'DT'),
#   (u'special', 'JJ'),
#   (u'assistant', 'NN'),
#   (u'to', 'TO'),
#   (u'General', 'NNP'),
#   (u'David', 'NNP'),
#   (u'Petraeus', 'NNP'),
#   (u'.', '.')],
#  [(u'Corey', 'NNP'),
#   (u'let', 'VBD'),
#   (u"'s", 'POS'),
#   (u'start', 'NN'),
#   (u'with', 'IN'),
#   (u'you', 'PRP'),
#   (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'terms', 'NNS'),
#   (u'of', 'IN'),
#   (u'this', 'DT'),
#   (u'idea', 'NN'),
#   (u'of', 'IN'),
#   (u'extreme', 'NN'),
#   (u'vetting', 'VBG'),
#   (u'of', 'IN'),
#   (u'some', 'DT'),
#   (u'sort', 'NN'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'tolerant', 'JJ'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'a', 'DT'),
#   (u'test', 'NN'),
#   (u'of', 'IN'),
#   (u'tolerance', 'NN'),
#   (u'how', 'WRB'),
#   (u'would', 'MD'),
#   (u'that', 'DT'),
#   (u'actually', 'RB'),
#   (u'work', 'VBP'),
#   (u'?', '.')],
#  [(u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'asking', 'VBG'),
#   (u'somebody', 'NN'),
#   (u'when', 'WRB'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'coming', 'VBG'),
#   (u'over', 'IN'),
#   (u'the', 'DT'),
#   (u'border', 'NN'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'do', 'VBP'),
#   (u'you', 'PRP'),
#   (u'support', 'VB'),
#   (u'women', 'NNS'),
#   (u"'s", 'POS'),
#   (u'rights', 'NNS'),
#   (u'gay', 'NN'),
#   (u'rights', 'NNS'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'all', 'RB'),
#   (u'things', 'NNS'),
#   (u'Trump', 'NNP'),
#   (u'mentioned', 'VBD'),
#   (u'.', '.')],
#  [(u'Is', 'VBZ'),
#   (u'that', 'IN'),
#   (u'for', 'IN'),
#   (u'real', 'JJ'),
#   (u'?', '.')],
#  [(u'COREY', 'NNP'),
#   (u'LEWANDOWSKI', 'NNP'),
#   (u'CNN', 'NNP'),
#   (u'POLITICAL', 'NNP'),
#   (u'COMMENTATOR', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'what', 'WP'),
#   (u'you', 'PRP'),
#   (u'have', 'VBP'),
#   (u'and', 'CC'),
#   (u'what', 'WP'),
#   (u'Trump', 'NNP'),
#   (u'was', 'VBD'),
#   (u'alluding', 'VBG'),
#   (u'to', 'TO'),
#   (u'in', 'IN'),
#   (u'this', 'DT'),
#   (u'particular', 'JJ'),
#   (u'case', 'NN'),
#   (u'was', 'VBD'),
#   (u'when', 'WRB'),
#   (u'you', 'PRP'),
#   (u'look', 'VBP'),
#   (u'at', 'IN'),
#   (u'the', 'DT'),
#   (u'San', 'NNP'),
#   (u'Bernardino', 'NNP'),
#   (u'killer', 'NN'),
#   (u'the', 'DT'),
#   (u'woman', 'NN'),
#   (u'who', 'WP'),
#   (u'came', 'VBD'),
#   (u'in', 'IN'),
#   (u'on', 'IN'),
#   (u'a', 'DT'),
#   (u'K-1', 'NN'),
#   (u'visa', 'NN'),
#   (u'because', 'IN'),
#   (u'she', 'PRP'),
#   (u'married', 'VBD'),
#   (u'a', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'citizen', 'NN'),
#   (u'.', '.')],
#  [(u'What', 'WP'),
#   (u'the', 'DT'),
#   (u'State', 'NNP'),
#   (u'Department', 'NNP'),
#   (u'said', 'VBD'),
#   (u'the', 'DT'),
#   (u'failures', 'NNS'),
#   (u'were', 'VBD'),
#   (u'in', 'IN'),
#   (u'her', 'PRP$'),
#   (u'position', 'NN'),
#   (u'was', 'VBD'),
#   (u'they', 'PRP'),
#   (u'did', 'VBD'),
#   (u"n't", 'RB'),
#   (u'go', 'VB'),
#   (u'and', 'CC'),
#   (u'check', 'VB'),
#   (u'her', 'PRP$'),
#   (u'social', 'JJ'),
#   (u'media', 'NNS'),
#   (u'accounts', 'NNS'),
#   (u'because', 'IN'),
#   (u'they', 'PRP'),
#   (u'were', 'VBD'),
#   (u'precluded', 'VBN'),
#   (u'by', 'IN'),
#   (u'doing', 'NN'),
#   (u'that', 'IN'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'what', 'WP'),
#   (u'he', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'is', 'VBZ'),
#   (u'extreme', 'NN'),
#   (u'vetting', 'VBG'),
#   (u'going', 'VBG'),
#   (u'and', 'CC'),
#   (u'looking', 'VBG'),
#   (u'at', 'IN'),
#   (u'social', 'JJ'),
#   (u'media', 'NNS'),
#   (u'activities', 'NNS'),
#   (u'.', '.')],
#  [(u'[', 'NN'),
#   (u'20:05:03', 'CD'),
#   (u']', 'CD'),
#   (u'What', 'WP'),
#   (u'we', 'PRP'),
#   (u'know', 'VBP'),
#   (u'is', 'VBZ'),
#   (u'that', 'IN'),
#   (u'the', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'has', 'VBZ'),
#   (u'accepted', 'VBN'),
#   (u'8000', 'CD'),
#   (u'Syrian', 'NNP'),
#   (u'refugees', 'NNS'),
#   (u'to', 'TO'),
#   (u'date', 'NN'),
#   (u'which', 'WDT'),
#   (u'is', 'VBZ'),
#   (u'more', 'RBR'),
#   (u'Syrian', 'JJ'),
#   (u'refugees', 'NNS'),
#   (u'into', 'IN'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'than', 'IN'),
#   (u'all', 'DT'),
#   (u'the', 'DT'),
#   (u'E.U', 'NNP'),
#   (u'.', '.')],
#  [(u'combined', 'VBN'), (u'right', 'RB'), (u'now', 'RB'), (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'we', 'PRP'),
#   (u'need', 'VBP'),
#   (u'to', 'TO'),
#   (u'make', 'VB'),
#   (u'sure', 'JJ'),
#   (u'that', 'IN'),
#   (u'the', 'DT'),
#   (u'people', 'NNS'),
#   (u'who', 'WP'),
#   (u'are', 'VBP'),
#   (u'coming', 'VBG'),
#   (u'here', 'RB'),
#   (u'first', 'JJ'),
#   (u'and', 'CC'),
#   (u'foremost', 'RB'),
#   (u'do', 'VBP'),
#   (u"n't", 'RB'),
#   (u'perpetuate', 'VB'),
#   (u'or', 'CC'),
#   (u'have', 'VB'),
#   (u'the', 'DT'),
#   (u'same', 'JJ'),
#   (u'type', 'NN'),
#   (u'of', 'IN'),
#   (u'mindset', 'NN'),
#   (u'that', 'IN'),
#   (u'the', 'DT'),
#   (u'San', 'NNP'),
#   (u'Bernardino', 'NNP'),
#   (u'killer', 'NN'),
#   (u'had', 'VBD'),
#   (u'which', 'WDT'),
#   (u'was', 'VBD'),
#   (u'to', 'TO'),
#   (u'come', 'VB'),
#   (u'here', 'RB'),
#   (u'and', 'CC'),
#   (u'commit', 'NN'),
#   (u'jihad', 'VBD'),
#   (u'against', 'IN'),
#   (u'our', 'PRP$'),
#   (u'country', 'NN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'Germany', 'NNP'),
#   (u'has', 'VBZ'),
#   (u'accepted', 'VBN'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'almost', 'RB'),
#   (u'a', 'DT'),
#   (u'million', 'NN'),
#   (u'people', 'NNS'),
#   (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'not', 'RB'),
#   (u'maybe', 'RB'),
#   (u'formally', 'RB'),
#   (u'as', 'IN'),
#   (u'refugees', 'NNS'),
#   (u'but', 'CC'),
#   (u'they', 'PRP'),
#   (u'allowed', 'VBD'),
#   (u'migrants', 'NNS'),
#   (u'in', 'IN'),
#   (u'as', 'IN'),
#   (u'many', 'JJ'),
#   (u'as', 'IN'),
#   (u'a', 'DT'),
#   (u'million', 'CD'),
#   (u'800000', 'CD'),
#   (u'to', 'TO'),
#   (u'a', 'DT'),
#   (u'million', 'NN'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'I', 'PRP'),
#   (u'get', 'VBP'),
#   (u'your', 'PRP$'),
#   (u'point', 'NN'),
#   (u'.', '.')],
#  [(u'Congressman', 'NNP'),
#   (u'Moulton', 'NNP'),
#   (u'I', 'NNP'),
#   (u'mean', 'VBP'),
#   (u'the', 'DT'),
#   (u'idea', 'NN'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'tolerance', 'NN'),
#   (u'test', 'NN'),
#   (u'for', 'IN'),
#   (u'people', 'NNS'),
#   (u'that', 'WDT'),
#   (u'come', 'NN'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'United', 'NNP'),
#   (u'States', 'NNPS'),
#   (u'does', 'VBZ'),
#   (u'that', 'IN'),
#   (u'make', 'VB'),
#   (u'sense', 'NN'),
#   (u'to', 'TO'),
#   (u'you', 'PRP'),
#   (u'?', '.')],
#  [(u'REP.', 'NNP'),
#   (u'SETH', 'NNP'),
#   (u'MOULTON', 'NNP'),
#   (u'(', 'NNP'),
#   (u'D', 'NNP'),
#   (u')', 'NNP'),
#   (u'MASSACHUSETTS', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'first', 'RB'),
#   (u'of', 'IN'),
#   (u'all', 'DT'),
#   (u'there', 'EX'),
#   (u"'s", 'VBZ'),
#   (u'already', 'RB'),
#   (u'extensive', 'JJ'),
#   (u'screening', 'NN'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'the', 'DT'),
#   (u'toughest', 'JJS'),
#   (u'route', 'NN'),
#   (u'possible', 'JJ'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'United', 'NNP'),
#   (u'States', 'NNPS'),
#   (u'as', 'IN'),
#   (u'a', 'DT'),
#   (u'refugee', 'NN'),
#   (u'.', '.')],
#  [(u'Literally', 'RB'),
#   (u'the', 'DT'),
#   (u'most', 'RBS'),
#   (u'strict', 'JJ'),
#   (u'screening', 'NN'),
#   (u'process', 'NN'),
#   (u'possible', 'JJ'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u'are', 'VBP'),
#   (u'already', 'RB'),
#   (u'doing', 'VBG'),
#   (u'things', 'NNS'),
#   (u'to', 'TO'),
#   (u'improve', 'VB'),
#   (u'it', 'PRP'),
#   (u'.', '.')],
#  [(u'This', 'DT'),
#   (u'does', 'VBZ'),
#   (u"n't", 'RB'),
#   (u'change', 'VB'),
#   (u'anything', 'NN'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u'might', 'MD'),
#   (u'be', 'VB'),
#   (u'unconstitutional', 'JJ'),
#   (u'but', 'CC'),
#   (u'it', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'not', 'RB'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'make', 'VB'),
#   (u'us', 'PRP'),
#   (u'safer', 'JJR'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'the', 'DT'),
#   (u'other', 'JJ'),
#   (u'thing', 'NN'),
#   (u'it', 'PRP'),
#   (u'does', 'VBZ'),
#   (u"n't", 'RB'),
#   (u'address', 'VB'),
#   (u'the', 'DT'),
#   (u'fact', 'NN'),
#   (u'that', 'IN'),
#   (u'what', 'WP'),
#   (u'ISIS', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'trying', 'VBG'),
#   (u'to', 'TO'),
#   (u'do', 'VB'),
#   (u'is', 'VBZ'),
#   (u'radicalize', 'VB'),
#   (u'people', 'NNS'),
#   (u'who', 'WP'),
#   (u'are', 'VBP'),
#   (u'right', 'RB'),
#   (u'here', 'RB'),
#   (u'at', 'IN'),
#   (u'home', 'NN'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'using', 'VBG'),
#   (u'as', 'IN'),
#   (u'tools', 'NNS'),
#   (u'to', 'TO'),
#   (u'do', 'VB'),
#   (u'that', 'DT'),
#   (u'the', 'DT'),
#   (u'rhetoric', 'NN'),
#   (u'of', 'IN'),
#   (u'people', 'NNS'),
#   (u'like', 'IN'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'who', 'WP'),
#   (u'want', 'NN'),
#   (u'to', 'TO'),
#   (u'discriminate', 'VB'),
#   (u'against', 'IN'),
#   (u'people', 'NNS'),
#   (u'based', 'VBN'),
#   (u'on', 'IN'),
#   (u'their', 'PRP$'),
#   (u'religion', 'NN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'But', 'CC'),
#   (u'Congressman', 'NNP'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'the', 'DT'),
#   (u'concern', 'NN'),
#   (u'with', 'IN'),
#   (u'the', 'DT'),
#   (u'Syrian', 'NNP'),
#   (u'refugees', 'VBZ'),
#   (u'certainly', 'RB'),
#   (u'the', 'DT'),
#   (u'migrants', 'NNS'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'Germany', 'NNP'),
#   (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'I', 'PRP'),
#   (u'was', 'VBD'),
#   (u'on', 'IN'),
#   (u'--', ':'),
#   (u'I', 'PRP'),
#   (u'was', 'VBD'),
#   (u'in', 'IN'),
#   (u'Greece', 'NNP'),
#   (u'when', 'WRB'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'shores', 'NNS'),
#   (u'with', 'IN'),
#   (u'hundreds', 'NNS'),
#   (u'coming', 'VBG'),
#   (u'ashore', 'JJR'),
#   (u'and', 'CC'),
#   (u'you', 'PRP'),
#   (u'see', 'VBP'),
#   (u'passports', 'NNS'),
#   (u'ripped', 'VBN'),
#   (u'up', 'RP'),
#   (u'.', '.')],
#  [(u'How', 'WRB'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'easy', 'JJ'),
#   (u'is', 'VBZ'),
#   (u'it', 'PRP'),
#   (u'to', 'TO'),
#   (u'actually', 'RB'),
#   (u'vet', 'VB'),
#   (u'somebody', 'NN'),
#   (u'when', 'WRB'),
#   (u'you', 'PRP'),
#   (u'ca', 'MD'),
#   (u"n't", 'RB'),
#   (u'work', 'VB'),
#   (u'with', 'IN'),
#   (u'the', 'DT'),
#   (u'intelligence', 'NN'),
#   (u'service', 'NN'),
#   (u'in', 'IN'),
#   (u'their', 'PRP$'),
#   (u'home', 'NN'),
#   (u'country', 'NN'),
#   (u'in', 'IN'),
#   (u'this', 'DT'),
#   (u'case', 'NN'),
#   (u'Syria', 'NNP'),
#   (u'to', 'TO'),
#   (u'actually', 'RB'),
#   (u'look', 'VB'),
#   (u'at', 'IN'),
#   (u'police', 'NN'),
#   (u'records', 'NNS'),
#   (u'to', 'TO'),
#   (u'look', 'VB'),
#   (u'who', 'WP'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'?', '.')],
#  [(u'MOULTON', 'NNP'),
#   (u':', ':'),
#   (u'It', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'hard', 'JJ'),
#   (u'to', 'TO'),
#   (u'do', 'VB'),
#   (u'it', 'PRP'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'that', 'DT'),
#   (u"'s", 'VBZ'),
#   (u'why', 'WRB'),
#   (u'it', 'PRP'),
#   (u'takes', 'VBZ'),
#   (u'two', 'CD'),
#   (u'years', 'NNS'),
#   (u'for', 'IN'),
#   (u'someone', 'NN'),
#   (u'to', 'TO'),
#   (u'go', 'VB'),
#   (u'through', 'RP'),
#   (u'the', 'DT'),
#   (u'refugee', 'NN'),
#   (u'process', 'NN'),
#   (u'to', 'TO'),
#   (u'come', 'VB'),
#   (u'to', 'TO'),
#   (u'America', 'NNP'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'simply', 'RB'),
#   (u'not', 'RB'),
#   (u'even', 'RB'),
#   (u'comparable', 'JJ'),
#   (u'to', 'TO'),
#   (u'these', 'DT'),
#   (u'refugees', 'NNS'),
#   (u'who', 'WP'),
#   (u'are', 'VBP'),
#   (u'swimming', 'VBG'),
#   (u'ashore', 'RBR'),
#   (u'in', 'IN'),
#   (u'Europe', 'NNP'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'silly', 'RB'),
#   (u'to', 'TO'),
#   (u'even', 'RB'),
#   (u'compare', 'VB'),
#   (u'the', 'DT'),
#   (u'two', 'CD'),
#   (u'.', '.')],
#  [(u'Migrants', 'NNS'),
#   (u'are', 'VBP'),
#   (u'flowing', 'VBG'),
#   (u'across', 'IN'),
#   (u'borders', 'NNS'),
#   (u'freely', 'RB'),
#   (u'into', 'IN'),
#   (u'Europe', 'NNP'),
#   (u'.', '.')],
#  [(u'You', 'PRP'),
#   (u'mentioned', 'VBD'),
#   (u'800000', 'CD'),
#   (u'into', 'IN'),
#   (u'Germany', 'NNP'),
#   (u'alone', 'RB'),
#   (u'.', '.')],
#  [(u'They', 'PRP'),
#   (u'are', 'VBP'),
#   (u'very', 'RB'),
#   (u'very', 'RB'),
#   (u'few', 'JJ'),
#   (u'controls', 'NNS'),
#   (u'.', '.')],
#  [(u'Totally', 'RB'),
#   (u'different', 'JJ'),
#   (u'when', 'WRB'),
#   (u'a', 'DT'),
#   (u'refugee', 'NN'),
#   (u'comes', 'VBZ'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'United', 'NNP'),
#   (u'States', 'NNPS'),
#   (u'.', '.')],
#  [(u'They', 'PRP'),
#   (u'go', 'VBP'),
#   (u'through', 'IN'),
#   (u'the', 'DT'),
#   (u'strictest', 'JJS'),
#   (u'screening', 'VBG'),
#   (u'of', 'IN'),
#   (u'any', 'DT'),
#   (u'traveler', 'NN'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'U.S', 'NNS'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u'usually', 'RB'),
#   (u'takes', 'VBZ'),
#   (u'upwards', 'NNS'),
#   (u'of', 'IN'),
#   (u'18', 'CD'),
#   (u'months', 'NNS'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'through', 'IN'),
#   (u'the', 'DT'),
#   (u'process', 'NN'),
#   (u'.', '.')],
#  [(u'Often', 'RB'),
#   (u'almost', 'RB'),
#   (u'two', 'CD'),
#   (u'years', 'NNS'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'that', 'DT'),
#   (u'is', 'VBZ'),
#   (u'because', 'IN'),
#   (u'we', 'PRP'),
#   (u'are', 'VBP'),
#   (u'so', 'RB'),
#   (u'strict', 'JJ'),
#   (u'and', 'CC'),
#   (u'scrutinizing', 'VBG'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'honestly', 'RB'),
#   (u'if', 'IN'),
#   (u'an', 'DT'),
#   (u'ISIS', 'NNP'),
#   (u'terrorist', 'NN'),
#   (u'wants', 'VBZ'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'United', 'NNP'),
#   (u'States', 'NNPS'),
#   (u'coming', 'VBG'),
#   (u'as', 'IN'),
#   (u'a', 'DT'),
#   (u'refugee', 'NN'),
#   (u'is', 'VBZ'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'worst', 'JJS'),
#   (u'route', 'NN'),
#   (u'possible', 'JJ'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Clarissa', 'NNP'),
#   (u'you', 'PRP'),
#   (u'have', 'VBP'),
#   (u'worked', 'VBN'),
#   (u'obviously', 'RB'),
#   (u'in', 'IN'),
#   (u'Iraq', 'NNP'),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'Middle', 'NNP'),
#   (u'East', 'NNP'),
#   (u'.', '.')],
#  [(u'Many', 'JJ'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'things', 'NNS'),
#   (u'Trump', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'working', 'VBG'),
#   (u'excuse', 'NN'),
#   (u'me', 'PRP'),
#   (u'with', 'IN'),
#   (u'Jordan', 'NNP'),
#   (u'working', 'VBG'),
#   (u'with', 'IN'),
#   (u'Egypt', 'NNP'),
#   (u'using', 'VBG'),
#   (u'NATO', 'NNP'),
#   (u'to', 'TO'),
#   (u'fight', 'NN'),
#   (u'terror', 'NN'),
#   (u'.', '.')],
#  [(u'How', 'WRB'),
#   (u'many', 'JJ'),
#   (u'of', 'IN'),
#   (u'these', 'DT'),
#   (u'things', 'NNS'),
#   (u'are', 'VBP'),
#   (u'new', 'JJ'),
#   (u'ideas', 'NNS'),
#   (u'or', 'CC'),
#   (u'things', 'NNS'),
#   (u'the', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'not', 'RB'),
#   (u'already', 'RB'),
#   (u'doing', 'VBG'),
#   (u'?', '.')],
#  [(u'CLARISSA', 'NNP'),
#   (u'WARD', 'NNP'),
#   (u'CNN', 'NNP'),
#   (u'SENIOR', 'NNP'),
#   (u'INTERNATIONAL', 'NNP'),
#   (u'CORRESPONDENT', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'that', 'IN'),
#   (u"'s", 'POS'),
#   (u'what', 'WP'),
#   (u'was', 'VBD'),
#   (u'really', 'RB'),
#   (u'striking', 'VBG'),
#   (u'Anderson', 'NNP'),
#   (u'just', 'RB'),
#   (u'listening', 'VBG'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'speech', 'NN'),
#   (u'is', 'VBZ'),
#   (u'a', 'DT'),
#   (u'lot', 'NN'),
#   (u'of', 'IN'),
#   (u'it', 'PRP'),
#   (u'sounded', 'VBD'),
#   (u'like', 'IN'),
#   (u'policies', 'NNS'),
#   (u'that', 'WDT'),
#   (u'are', 'VBP'),
#   (u'already', 'RB'),
#   (u'being', 'VBG'),
#   (u'implemented', 'VBN'),
#   (u'by', 'IN'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'.', '.')],
#  [(u'Trump', 'NNP'),
#   (u'talked', 'VBD'),
#   (u'a', 'DT'),
#   (u'lot', 'NN'),
#   (u'about', 'IN'),
#   (u'working', 'VBG'),
#   (u'closely', 'RB'),
#   (u'with', 'IN'),
#   (u'allies', 'NNS'),
#   (u'supporting', 'VBG'),
#   (u'allies', 'NNS'),
#   (u'who', 'WP'),
#   (u'will', 'MD'),
#   (u'fight', 'VB'),
#   (u'ISIS', 'NNP'),
#   (u'cutting', 'NN'),
#   (u'the', 'DT'),
#   (u'source', 'NN'),
#   (u'of', 'IN'),
#   (u'ISIS', 'NNP'),
#   (u'funding', 'NN'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'talked', 'VBD'),
#   (u'about', 'IN'),
#   (u'trying', 'VBG'),
#   (u'to', 'TO'),
#   (u'put', 'VB'),
#   (u'a', 'DT'),
#   (u'stop', 'NN'),
#   (u'to', 'TO'),
#   (u'recruitment', 'VB'),
#   (u'.', '.')],
#  [(u'His', 'PRP$'),
#   (u'suggestion', 'NN'),
#   (u'in', 'IN'),
#   (u'that', 'DT'),
#   (u'case', 'NN'),
#   (u'was', 'VBD'),
#   (u'to', 'TO'),
#   (u'shut', 'VB'),
#   (u'down', 'RP'),
#   (u'the', 'DT'),
#   (u'Internet', 'NNP'),
#   (u'which', 'WDT'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'is', 'VBZ'),
#   (u'probably', 'RB'),
#   (u'not', 'RB'),
#   (u'only', 'RB'),
#   (u'not', 'RB'),
#   (u'feasible', 'JJ'),
#   (u'but', 'CC'),
#   (u'also', 'RB'),
#   (u'would', 'MD'),
#   (u'be', 'VB'),
#   (u'challenging', 'VBG'),
#   (u'for', 'IN'),
#   (u'our', 'PRP$'),
#   (u'security', 'NN'),
#   (u'services', 'NNS'),
#   (u'who', 'WP'),
#   (u'get', 'NN'),
#   (u'a', 'DT'),
#   (u'lot', 'NN'),
#   (u'of', 'IN'),
#   (u'their', 'PRP$'),
#   (u'intelligence', 'NN'),
#   (u'from', 'IN'),
#   (u'that', 'DT'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'then', 'RB'),
#   (u'he', 'PRP'),
#   (u'went', 'VBD'),
#   (u'one', 'CD'),
#   (u'step', 'NN'),
#   (u'further', 'RB'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'almost', 'RB'),
#   (u'seemed', 'VBD'),
#   (u'to', 'TO'),
#   (u'put', 'VB'),
#   (u'the', 'DT'),
#   (u'entire', 'JJ'),
#   (u'Arab', 'NNP'),
#   (u'Spring', 'NNP'),
#   (u'at', 'IN'),
#   (u'the', 'DT'),
#   (u'feet', 'NNS'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'as', 'IN'),
#   (u'opposed', 'VBN'),
#   (u'at', 'IN'),
#   (u'the', 'DT'),
#   (u'feet', 'NNS'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'brutal', 'JJ'),
#   (u'dictators', 'NNS'),
#   (u'who', 'WP'),
#   (u'have', 'VBP'),
#   (u'been', 'VBN'),
#   (u'in', 'IN'),
#   (u'charge', 'NN'),
#   (u'in', 'IN'),
#   (u'that', 'DT'),
#   (u'region', 'NN'),
#   (u'in', 'IN'),
#   (u'those', 'DT'),
#   (u'countries', 'NNS'),
#   (u'for', 'IN'),
#   (u'many', 'JJ'),
#   (u'decades', 'NNS'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'it', 'PRP'),
#   (u'seemed', 'VBD'),
#   (u'he', 'PRP'),
#   (u'almost', 'RB'),
#   (u'had', 'VBD'),
#   (u'a', 'DT'),
#   (u'nostalgia', 'NN'),
#   (u'for', 'IN'),
#   (u'the', 'DT'),
#   (u'sort', 'NN'),
#   (u'of', 'IN'),
#   (u'heyday', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'Middle', 'NNP'),
#   (u'East', 'NNP'),
#   (u'dictator', 'NN'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'talked', 'VBD'),
#   (u'about', 'IN'),
#   (u'President', 'NNP'),
#   (u'Sisi', 'NNP'),
#   (u'of', 'IN'),
#   (u'Egypt', 'NNP'),
#   (u'who', 'WP'),
#   (u'we', 'PRP'),
#   (u'know', 'VBP'),
#   (u'does', 'VBZ'),
#   (u'not', 'RB'),
#   (u'aspire', 'VB'),
#   (u'too', 'RB'),
#   (u'many', 'JJ'),
#   (u'American', 'JJ'),
#   (u'values', 'NNS'),
#   (u'who', 'WP'),
#   (u'has', 'VBZ'),
#   (u'sentenced', 'VBN'),
#   (u'tens', 'NNS'),
#   (u'of', 'IN'),
#   (u'thousands', 'NNS'),
#   (u'of', 'IN'),
#   (u'people', 'NNS'),
#   (u'to', 'TO'),
#   (u'death', 'NN'),
#   (u'who', 'WP'),
#   (u'came', 'VBD'),
#   (u'to', 'TO'),
#   (u'power', 'NN'),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'coup', 'NN'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'there', 'EX'),
#   (u'were', 'VBD'),
#   (u'a', 'DT'),
#   (u'lot', 'NN'),
#   (u'of', 'IN'),
#   (u'mixed', 'VBN'),
#   (u'messages', 'NNS'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'even', 'RB'),
#   (u'in', 'IN'),
#   (u'his', 'PRP$'),
#   (u'power', 'NN'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'drawing', 'VBG'),
#   (u'putting', 'NN'),
#   (u'together', 'RB'),
#   (u'or', 'CC'),
#   (u'conflating', 'VBG'),
#   (u'Syria', 'NNP'),
#   (u'and', 'CC'),
#   (u'Libya', 'NNP'),
#   (u'calling', 'NN'),
#   (u'them', 'PRP'),
#   (u'both', 'DT'),
#   (u'disastrous', 'JJ'),
#   (u'that', 'IN'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'was', 'VBD'),
#   (u'responsible', 'JJ'),
#   (u'for', 'IN'),
#   (u'.', '.')],
#  [(u'Well', 'NNP'),
#   (u'in', 'IN'),
#   (u'Libya', 'NNP'),
#   (u'you', 'PRP'),
#   (u'had', 'VBD'),
#   (u'an', 'DT'),
#   (u'intervention', 'NN'),
#   (u'that', 'IN'),
#   (u'had', 'VBD'),
#   (u'certain', 'JJ'),
#   (u'fairly', 'RB'),
#   (u'disastrous', 'JJ'),
#   (u'consequences', 'NNS'),
#   (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'Syria', 'NNP'),
#   (u'there', 'EX'),
#   (u"'s", 'VBZ'),
#   (u'been', 'VBN'),
#   (u'no', 'DT'),
#   (u'intervention', 'NN'),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'consequences', 'NNS'),
#   (u'have', 'VBP'),
#   (u'been', 'VBN'),
#   (u'hugely', 'RB'),
#   (u'disastrous', 'JJ'),
#   (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'fact', 'NN'),
#   (u'Syria', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'the', 'DT'),
#   (u'giant', 'JJ'),
#   (u'festering', 'NN'),
#   (u'wound', 'NN'),
#   (u'that', 'WDT'),
#   (u'ISIS', 'NNP'),
#   (u'really', 'RB'),
#   (u'started', 'VBD'),
#   (u'to', 'TO'),
#   (u'thrive', 'VB'),
#   (u'in', 'IN'),
#   (u'Anderson', 'NNP'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Corey', 'NNP'),
#   (u'though', 'IN'),
#   (u'in', 'IN'),
#   (u'terms', 'NNS'),
#   (u'of', 'IN'),
#   (u'what', 'WP'),
#   (u'Trump', 'NNP'),
#   (u'said', 'VBD'),
#   (u'about', 'IN'),
#   (u'his', 'PRP$'),
#   (u'own', 'JJ'),
#   (u'record', 'NN'),
#   (u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'a', 'DT'),
#   (u'lot', 'NN'),
#   (u'of', 'IN'),
#   (u'people', 'NNS'),
#   (u'are', 'VBP'),
#   (u'pointing', 'VBG'),
#   (u'to', 'TO'),
#   (u'inaccuracies', 'NNS'),
#   (u'and', 'CC'),
#   (u'things', 'NNS'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'said', 'VBN'),
#   (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'he', 'PRP'),
#   (u'talked', 'VBD'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'catastrophic', 'JJ'),
#   (u'mistake', 'NN'),
#   (u'of', 'IN'),
#   (u'pulling', 'VBG'),
#   (u'U.S.', 'NNP'),
#   (u'troops', 'NNS'),
#   (u'out', 'IN'),
#   (u'of', 'IN'),
#   (u'Iraq', 'NNP'),
#   (u'he', 'PRP'),
#   (u'said', 'VBD'),
#   (u'it', 'PRP'),
#   (u'happened', 'VBD'),
#   (u'too', 'RB'),
#   (u'quickly', 'RB'),
#   (u'not', 'RB'),
#   (u'renegotiating', 'VBG'),
#   (u'the', 'DT'),
#   (u'status', 'NN'),
#   (u'of', 'IN'),
#   (u'forces', 'NNS'),
#   (u'agreement', 'NN'),
#   (u'.', '.')],
#  [(u'That', 'DT'),
#   (u'was', 'VBD'),
#   (u'something', 'NN'),
#   (u'he', 'PRP'),
#   (u'called', 'VBD'),
#   (u'for', 'IN'),
#   (u'in', 'IN'),
#   (u'multiple', 'NN'),
#   (u'interviews', 'NNS'),
#   (u'in', 'IN'),
#   (u'2006', 'CD'),
#   (u'2007', 'CD'),
#   (u'and', 'CC'),
#   (u'2008', 'CD'),
#   (u'on', 'IN'),
#   (u'Larry', 'NNP'),
#   (u'King', 'NNP'),
#   (u'where', 'WRB'),
#   (u'he', 'PRP'),
#   (u'said', 'VBD'),
#   (u'just', 'RB'),
#   (u'get', 'VB'),
#   (u'out', 'IN'),
#   (u'declare', 'NN'),
#   (u'victory', 'NN'),
#   (u'and', 'CC'),
#   (u'get', 'VB'),
#   (u'out', 'IN'),
#   (u'essentially', 'RB'),
#   (u'like', 'IN'),
#   (u'we', 'PRP'),
#   (u'did', 'VBD'),
#   (u'in', 'IN'),
#   (u'Vietnam', 'NNP'),
#   (u'.', '.')],
#  [(u'Is', 'VBZ'),
#   (u'it', 'PRP'),
#   (u'hypercritical', 'JJ'),
#   (u'and', 'CC'),
#   (u'Clarissa', 'NNP'),
#   (u'mentioned', 'VBD'),
#   (u'Libya', 'NNP'),
#   (u'he', 'PRP'),
#   (u'actually', 'RB'),
#   (u'attacked', 'VBD'),
#   (u'President', 'NNP'),
#   (u'Obama', 'NNP'),
#   (u'for', 'IN'),
#   (u'not', 'RB'),
#   (u'going', 'VBG'),
#   (u'faster', 'JJR'),
#   (u'against', 'IN'),
#   (u'Gadhafi', 'NNP'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'so', 'RB'),
#   (u'there', 'RB'),
#   (u'were', 'VBD'),
#   (u'multiple', 'NNS'),
#   (u'instances', 'NNS'),
#   (u'where', 'WRB'),
#   (u'things', 'NNS'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'critical', 'JJ'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'were', 'VBD'),
#   (u'things', 'NNS'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'supporting', 'VBG'),
#   (u'several', 'JJ'),
#   (u'years', 'NNS'),
#   (u'ago', 'IN'),
#   (u'.', '.')],
#  [(u'LEWANDOWSKI', 'NNP'),
#   (u':', ':'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'you', 'PRP'),
#   (u'have', 'VBP'),
#   (u'to', 'TO'),
#   (u'remember', 'VB'),
#   (u'right', 'RB'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'a', 'DT'),
#   (u'businessman', 'NN'),
#   (u'and', 'CC'),
#   (u'has', 'VBZ'),
#   (u'been', 'VBN'),
#   (u'a', 'DT'),
#   (u'businessman', 'NN'),
#   (u'throughout', 'IN'),
#   (u'his', 'PRP$'),
#   (u'entire', 'JJ'),
#   (u'career', 'NN'),
#   (u'and', 'CC'),
#   (u'does', 'VBZ'),
#   (u"n't", 'RB'),
#   (u'have', 'VB'),
#   (u'access', 'NN'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'same', 'JJ'),
#   (u'type', 'NN'),
#   (u'of', 'IN'),
#   (u'information', 'NN'),
#   (u'that', 'IN'),
#   (u'this', 'DT'),
#   (u'administration', 'NN'),
#   (u'has', 'VBZ'),
#   (u'access', 'NN'),
#   (u'to', 'TO'),
#   (u'or', 'CC'),
#   (u'the', 'DT'),
#   (u'previous', 'JJ'),
#   (u'administration', 'NN'),
#   (u'had', 'VBD'),
#   (u'access', 'NN'),
#   (u'to', 'TO'),
#   (u'.', '.')],
#  [(u'[', 'NN'),
#   (u'20:10:06', 'CD'),
#   (u']', 'CD'),
#   (u'So', 'NNP'),
#   (u'when', 'WRB'),
#   (u'you', 'PRP'),
#   (u'look', 'VBP'),
#   (u'at', 'IN'),
#   (u'the', 'DT'),
#   (u'things', 'NNS'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'calling', 'VBG'),
#   (u'for', 'IN'),
#   (u'like', 'IN'),
#   (u'the', 'DT'),
#   (u'congressman', 'NN'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'Mr.', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'said', 'VBD'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'against', 'IN'),
#   (u'the', 'DT'),
#   (u'Iraq', 'NNP'),
#   (u'war', 'NN'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'the', 'DT'),
#   (u'congressman', 'NN'),
#   (u'was', 'VBD'),
#   (u'against', 'IN'),
#   (u'the', 'DT'),
#   (u'Iraq', 'NNP'),
#   (u'war', 'NN'),
#   (u'but', 'CC'),
#   (u'he', 'PRP'),
#   (u'went', 'VBD'),
#   (u'to', 'TO'),
#   (u'war', 'NN'),
#   (u'to', 'TO'),
#   (u'fight', 'NN'),
#   (u'for', 'IN'),
#   (u'his', 'PRP$'),
#   (u'country', 'NN'),
#   (u'--', ':'),
#   (u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'But', 'CC'),
#   (u'he', 'PRP'),
#   (u'actually', 'RB'),
#   (u'was', 'VBD'),
#   (u'against', 'IN'),
#   (u'--', ':'),
#   (u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'on', 'IN'),
#   (u'Howard', 'NNP'),
#   (u'Stern', 'NNP'),
#   (u'he', 'PRP'),
#   (u'said', 'VBD'),
#   (u'--', ':'),
#   (u'LEWANDOWSKI', 'NNP'),
#   (u':', ':'),
#   (u'Howard', 'NNP'),
#   (u'Stern', 'NNP'),
#   (u'was', 'VBD'),
#   (u'well', 'RB'),
#   (u'okay', 'RB'),
#   (u'maybe', 'RB'),
#   (u'.', '.')],
#  [(u'That', 'DT'),
#   (u"'s", 'VBZ'),
#   (u'not', 'RB'),
#   (u'a', 'DT'),
#   (u'ringing', 'NN'),
#   (u'endorsement', 'NN'),
#   (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'that', 'IN'),
#   (u"'s", 'POS'),
#   (u'really', 'RB'),
#   (u'overplayed', 'VBN'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'in', 'IN'),
#   (u'favor', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'war', 'NN'),
#   (u'when', 'WRB'),
#   (u'he', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'been', 'VBN'),
#   (u'on', 'IN'),
#   (u'record', 'NN'),
#   (u'on', 'IN'),
#   (u'multiple', 'NN'),
#   (u'occasions', 'NNS'),
#   (u'saying', 'VBG'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u"n't", 'RB'),
#   (u'been', 'VBN'),
#   (u'in', 'IN'),
#   (u'favor', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'war', 'NN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'congressman', 'NN'),
#   (u'was', 'VBD'),
#   (u"n't", 'RB'),
#   (u'in', 'IN'),
#   (u'favor', 'NN'),
#   (u'but', 'CC'),
#   (u'he', 'PRP'),
#   (u'went', 'VBD'),
#   (u'and', 'CC'),
#   (u'served', 'VBN'),
#   (u'honorably', 'RB'),
#   (u'four', 'CD'),
#   (u'tours', 'NNS'),
#   (u'of', 'IN'),
#   (u'duty', 'NN'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u'respect', 'VBP'),
#   (u'him', 'PRP'),
#   (u'for', 'IN'),
#   (u'that', 'DT'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'I', 'PRP'),
#   (u'think', 'VBP'),
#   (u'what', 'WP'),
#   (u'you', 'PRP'),
#   (u'have', 'VBP'),
#   (u'now', 'RB'),
#   (u'is', 'VBZ'),
#   (u'with', 'IN'),
#   (u'the', 'DT'),
#   (u'best', 'JJS'),
#   (u'information', 'NN'),
#   (u'he', 'PRP'),
#   (u'had', 'VBD'),
#   (u'available', 'JJ'),
#   (u'he', 'PRP'),
#   (u'said', 'VBD'),
#   (u'look', 'NN'),
#   (u'you', 'PRP'),
#   (u'just', 'RB'),
#   (u'get', 'VB'),
#   (u'out', 'IN'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'said', 'VBD'),
#   (u'to', 'TO'),
#   (u'Wolf', 'NNP'),
#   (u'Blitzer', 'NNP'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'said', 'VBD'),
#   (u'to', 'TO'),
#   (u'Larry', 'NNP'),
#   (u'King', 'NNP'),
#   (u'it', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'time', 'NN'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'out', 'IN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'problem', 'NN'),
#   (u'became', 'VBD'),
#   (u'when', 'WRB'),
#   (u'the', 'DT'),
#   (u'U.S.', 'NNP'),
#   (u'extracted', 'VBD'),
#   (u'itself', 'PRP'),
#   (u'right', 'RB'),
#   (u'?', '.')],
#  [(u'That', 'DT'),
#   (u'created', 'VBN'),
#   (u'a', 'DT'),
#   (u'power', 'NN'),
#   (u'vacuum', 'NN'),
#   (u'that', 'IN'),
#   (u'allowed', 'VBN'),
#   (u'ISIS', 'NNP'),
#   (u'to', 'TO'),
#   (u'permeate', 'VB'),
#   (u'and', 'CC'),
#   (u'grow', 'NN'),
#   (u'to', 'TO'),
#   (u'what', 'WP'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'today', 'NN'),
#   (u'which', 'WDT'),
#   (u'is', 'VBZ'),
#   (u'the', 'DT'),
#   (u'single', 'JJ'),
#   (u'biggest', 'JJS'),
#   (u'source', 'NN'),
#   (u'of', 'IN'),
#   (u'terror', 'NN'),
#   (u'in', 'IN'),
#   (u'our', 'PRP$'),
#   (u'world', 'NN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'All', 'DT'),
#   (u'right', 'NN'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'Congressman', 'NNP'),
#   (u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'what', 'WP'),
#   (u'Trump', 'NNP'),
#   (u'said', 'VBD'),
#   (u'on', 'IN'),
#   (u'Larry', 'NNP'),
#   (u'King', 'NNP'),
#   (u'in', 'IN'),
#   (u'particular', 'JJ'),
#   (u'is', 'VBZ'),
#   (u'like', 'IN'),
#   (u'even', 'RB'),
#   (u'if', 'IN'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'there', 'RB'),
#   (u"'s", 'VBZ'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'civil', 'JJ'),
#   (u'war', 'NN'),
#   (u'no', 'DT'),
#   (u'matter', 'NN'),
#   (u'what', 'WP'),
#   (u'get', 'NN'),
#   (u'out', 'IN'),
#   (u'declare', 'NN'),
#   (u'victory', 'NN'),
#   (u'.', '.')],
#  [(u'Do', 'NNP'),
#   (u'you', 'PRP'),
#   (u'think', 'VBP'),
#   (u'is', 'VBZ'),
#   (u'it', 'PRP'),
#   (u'hypercritical', 'JJ'),
#   (u'of', 'IN'),
#   (u'him', 'PRP'),
#   (u'now', 'RB'),
#   (u'to', 'TO'),
#   (u'attack', 'VB'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'for', 'IN'),
#   (u'not', 'RB'),
#   (u'renegotiating', 'VBG'),
#   (u'the', 'DT'),
#   (u'status', 'NN'),
#   (u'of', 'IN'),
#   (u'forces', 'NNS'),
#   (u'agreement', 'NN'),
#   (u'?', '.')],
#  [(u'Which', 'WDT'),
#   (u'is', 'VBZ'),
#   (u'a', 'DT'),
#   (u'valid', 'JJ'),
#   (u'position', 'NN'),
#   (u'to', 'TO'),
#   (u'have', 'VB'),
#   (u'but', 'CC'),
#   (u'it', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'counter', 'JJR'),
#   (u'to', 'TO'),
#   (u'what', 'WP'),
#   (u'he', 'PRP'),
#   (u'used', 'VBD'),
#   (u'to', 'TO'),
#   (u'have', 'VB'),
#   (u'.', '.')],
#  [(u'Is', 'VBZ'), (u'that', 'IN'), (u'hypercritical', 'JJ'), (u'?', '.')],
#  [(u'MOULTON', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'hypocritical', 'JJ'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'look', 'VBD'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'not', 'RB'),
#   (u'running', 'VBG'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'businessman', 'NN'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'running', 'VBG'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'our', 'PRP$'),
#   (u'commander-in-', '-NONE-'),
#   (u'chief', 'NN'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'someone', 'VBN'),
#   (u'that', 'IN'),
#   (u'we', 'PRP'),
#   (u'have', 'VBP'),
#   (u'to', 'TO'),
#   (u'trust', 'VB'),
#   (u'him', 'PRP'),
#   (u'to', 'TO'),
#   (u'make', 'VB'),
#   (u'the', 'DT'),
#   (u'right', 'NN'),
#   (u'judgment', 'NN'),
#   (u'calls', 'VBZ'),
#   (u'in', 'IN'),
#   (u'these', 'DT'),
#   (u'situations', 'NNS'),
#   (u'.', '.')],
#  [(u'They', 'PRP'),
#   (u'are', 'VBP'),
#   (u'tough', 'JJ'),
#   (u'calls', 'NNS'),
#   (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'have', 'VBP'),
#   (u'been', 'VBN'),
#   (u'someone', 'NN'),
#   (u'a', 'DT'),
#   (u'Democrat', 'NNP'),
#   (u'who', 'WP'),
#   (u"'s", 'POS'),
#   (u'been', 'VBN'),
#   (u'critical', 'JJ'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'Obama', 'NNP'),
#   (u'administration', 'NN'),
#   (u'on', 'IN'),
#   (u'some', 'DT'),
#   (u'of', 'IN'),
#   (u'that', 'DT'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'the', 'DT'),
#   (u'fact', 'NN'),
#   (u'that', 'IN'),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'so', 'RB'),
#   (u'inconsistent', 'JJ'),
#   (u'so', 'IN'),
#   (u'reckless', 'JJ'),
#   (u'with', 'IN'),
#   (u'some', 'DT'),
#   (u'of', 'IN'),
#   (u'his', 'PRP$'),
#   (u'recommendations', 'NNS'),
#   (u'and', 'CC'),
#   (u'then', 'RB'),
#   (u'hypocritical', 'JJ'),
#   (u'many', 'JJ'),
#   (u'times', 'NNS'),
#   (u'when', 'WRB'),
#   (u'he', 'PRP'),
#   (u'criticizes', 'VBZ'),
#   (u'others', 'NNS'),
#   (u'just', 'RB'),
#   (u'shows', 'VBZ'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'really', 'RB'),
#   (u'not', 'RB'),
#   (u'fit', 'VB'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'our', 'PRP$'),
#   (u'commander-in-chief', 'JJ'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'might', 'MD'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'great', 'JJ'),
#   (u'businessman', 'NN'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'the', 'DT'),
#   (u'record', 'NN'),
#   (u'is', 'VBZ'),
#   (u'a', 'DT'),
#   (u'little', 'RB'),
#   (u'bit', 'NN'),
#   (u'shoddy', 'NN'),
#   (u'on', 'IN'),
#   (u'that', 'DT'),
#   (u'as', 'IN'),
#   (u'well', 'RB'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'he', 'PRP'),
#   (u'clearly', 'RB'),
#   (u'does', 'VBZ'),
#   (u'not', 'RB'),
#   (u'have', 'VB'),
#   (u'a', 'DT'),
#   (u'temperament', 'NN'),
#   (u'or', 'CC'),
#   (u'the', 'DT'),
#   (u'judgment', 'NN'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'making', 'VBG'),
#   (u'these', 'DT'),
#   (u'tough', 'JJ'),
#   (u'calls', 'NNS'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'national', 'JJ'),
#   (u'security', 'NN'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'just', 'RB'),
#   (u'by', 'IN'),
#   (u'running', 'VBG'),
#   (u'for', 'IN'),
#   (u'president', 'NN'),
#   (u'and', 'CC'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'things', 'NNS'),
#   (u'like', 'IN'),
#   (u'banning', 'VBG'),
#   (u'Muslims', 'NNP'),
#   (u'which', 'WDT'),
#   (u'just', 'RB'),
# ...
#   (u'helping', 'VBG'),
#   (u'those', 'DT'),
#   (u'trapped', 'JJ'),
#   (u'in', 'IN'),
#   (u'flood', 'NN'),
#   (u'waters', 'NNS'),
#   (u'trying', 'VBG'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'to', 'TO'),
#   (u'dry', 'VB'),
#   (u'land', 'NN'),
#   (u'.', '.')],
#  [(u'Take', 'NNP'), (u'a', 'DT'), (u'look', 'NN'), (u'.', '.')],
#  [(u'(', 'NN'),
#   (u'BEGIN', 'NNP'),
#   (u'VIDEO', 'NNP'),
#   (u'CLIP', 'NNP'),
#   (u')', 'NNP'),
#   (u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Rescues', 'NNPS'),
#   (u'by', 'IN'),
#   (u'boat', 'JJ'),
#   (u'from', 'IN'),
#   (u'the', 'DT'),
#   (u'air', 'NN'),
#   (u'even', 'RB'),
#   (u'from', 'IN'),
#   (u'underneath', 'NN'),
#   (u'the', 'DT'),
#   (u'flood', 'NN'),
#   (u'waters', 'NNS'),
#   (u'.', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'MALE', 'NNP'),
#   (u':', ':'),
#   (u'Get', 'NNP'),
#   (u'out', 'IN'),
#   (u'!', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'FEMALE', 'NNP'),
#   (u':', ':'),
#   (u'I', 'PRP'),
#   (u"'m", 'VBP'),
#   (u'trying', 'VBG'),
#   (u'!', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'MALE', 'NNP'),
#   (u':', ':'),
#   (u'Give', 'JJ'),
#   (u'me', 'PRP'),
#   (u'a', 'DT'),
#   (u'knife', 'NN'),
#   (u'.', '.')],
#  [(u'Give', 'JJ'),
#   (u'me', 'PRP'),
#   (u'a', 'DT'),
#   (u'knife', 'NN'),
#   (u'.', '.')],
#  [(u'Give', 'JJ'),
#   (u'me', 'PRP'),
#   (u'a', 'DT'),
#   (u'knife', 'NN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'This', 'DT'),
#   (u'rescue', 'NN'),
#   (u'crew', 'VBD'),
#   (u'in', 'IN'),
#   (u'Baton', 'NNP'),
#   (u'Rouge', 'NNP'),
#   (u'found', 'VBD'),
#   (u'a', 'DT'),
#   (u'car', 'NN'),
#   (u'which', 'WDT'),
#   (u'was', 'VBD'),
#   (u'quickly', 'RB'),
#   (u'sinking', 'VBG'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'drives', 'NNS'),
#   (u'was', 'VBD'),
#   (u'trapped', 'VBN'),
#   (u'inside', 'NN'),
#   (u'.', '.')],
#  [(u'You', 'PRP'),
#   (u'hear', 'VBP'),
#   (u'her', 'PRP'),
#   (u'calling', 'VBG'),
#   (u'for', 'IN'),
#   (u'help', 'NN'),
#   (u'.', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'FEMALE', 'NNP'),
#   (u':', ':'),
#   (u'Oh', 'NNP'),
#   (u'my', 'PRP$'),
#   (u'god', 'NN'),
#   (u'I', 'PRP'),
#   (u"'m", 'VBP'),
#   (u'drowning', 'VBG'),
#   (u'.', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'MALE', 'NNP'),
#   (u':', ':'),
#   (u'We', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'coming', 'VBG'),
#   (u'.', '.')],
#  [(u'We', 'PRP'), (u"'re", 'VBP'), (u'coming', 'VBG'), (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'breaking', 'VBG'),
#   (u'the', 'DT'),
#   (u'window', 'NN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'But', 'CC'),
#   (u'with', 'IN'),
#   (u'the', 'DT'),
#   (u'car', 'NN'),
#   (u'now', 'RB'),
#   (u'almost', 'RB'),
#   (u'completely', 'RB'),
#   (u'under', 'IN'),
#   (u'water', 'NN'),
#   (u'one', 'CD'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'rescuers', 'NNS'),
#   (u'David', 'NNP'),
#   (u'Phung', 'NNP'),
#   (u'jumps', 'VBZ'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'water', 'NN'),
#   (u'.', '.')],
#  [(u'Grabbing', 'VBG'),
#   (u'the', 'DT'),
#   (u'driver', 'NN'),
#   (u"'s", 'POS'),
#   (u'arm', 'NN'),
#   (u'and', 'CC'),
#   (u'pulling', 'VBG'),
#   (u'her', 'PRP$'),
#   (u'out', 'RP'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'car', 'NN'),
#   (u'up', 'RP'),
#   (u'to', 'TO'),
#   (u'safety', 'NN'),
#   (u'.', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'FEMALE', 'NNP'),
#   (u':', ':'),
#   (u'Get', 'NNP'),
#   (u'my', 'PRP$'),
#   (u'dog', 'NN'),
#   (u'!', '.')],
#  [(u'Get', 'NN'), (u'my', 'PRP$'), (u'dog', 'NN'), (u'!', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'As', 'IN'),
#   (u'soon', 'RB'),
#   (u'as', 'IN'),
#   (u'she', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'able', 'JJ'),
#   (u'to', 'TO'),
#   (u'take', 'VB'),
#   (u'a', 'DT'),
#   (u'breath', 'NN'),
#   (u'she', 'PRP'),
#   (u'pleads', 'VBZ'),
#   (u'with', 'IN'),
#   (u'Phung', 'NNP'),
#   (u'to', 'TO'),
#   (u'save', 'VB'),
#   (u'her', 'PRP'),
#   (u'dog', 'VB'),
#   (u'still', 'RB'),
#   (u'trapped', 'VBN'),
#   (u'inside', 'NN'),
#   (u'the', 'DT'),
#   (u'car', 'NN'),
#   (u'.', '.')],
#  [(u'DAVID', 'NNP'),
#   (u'PHUNG', 'NNP'),
#   (u'LOUISIANA', 'NNP'),
#   (u'RESCUER', 'NNP'),
#   (u':', ':'),
#   (u'I', 'PRP'),
#   (u'will', 'MD'),
#   (u'get', 'VB'),
#   (u'the', 'DT'),
#   (u'dog', 'NN'),
#   (u'.', '.')],
#  [(u'Here', 'RB'), (u'here', 'RB'), (u'.', '.')],
#  [(u'I', 'PRP'),
#   (u'ca', 'MD'),
#   (u"n't", 'RB'),
#   (u'get', 'VB'),
#   (u'the', 'DT'),
#   (u'dog', 'NN'),
#   (u'.', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'FEMALE', 'NNP'),
#   (u':', ':'),
#   (u'(', ':'),
#   (u'Inaudible', 'JJ'),
#   (u')', 'NN'),
#   (u'PHUNG', 'NNP'),
#   (u':', ':'),
#   (u'Then', 'NNP'),
#   (u'she', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'gone', 'VBN'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'So', 'RB'),
#   (u'he', 'PRP'),
#   (u'dives', 'VBZ'),
#   (u'back', 'RB'),
#   (u'down', 'IN'),
#   (u'under', 'IN'),
#   (u'the', 'DT'),
#   (u'water', 'NN'),
#   (u'.', '.')],
#  [(u'PHUNG', 'NNP'),
#   (u':', ':'),
#   (u'I', 'PRP'),
#   (u'got', 'VBD'),
#   (u'your', 'PRP$'),
#   (u'dog', 'NN'),
#   (u'!', '.')],
#  [(u'UNIDENTIFIED', 'VBD'),
#   (u'FEMALE', 'NNP'),
#   (u':', ':'),
#   (u'Oh', 'NNP'),
#   (u'you', 'PRP'),
#   (u'are', 'VBP'),
#   (u'amazing', 'VBG'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'In', 'NNP'),
#   (u'the', 'DT'),
#   (u'end', 'NN'),
#   (u'saving', 'VBG'),
#   (u'them', 'PRP'),
#   (u'both', 'DT'),
#   (u'.', '.')],
#  [(u'Officials', 'NNS'),
#   (u'and', 'CC'),
#   (u'volunteers', 'NNS'),
#   (u'in', 'IN'),
#   (u'Louisiana', 'NNP'),
#   (u'are', 'VBP'),
#   (u'working', 'VBG'),
#   (u'around', 'IN'),
#   (u'the', 'DT'),
#   (u'clock', 'NN'),
#   (u'to', 'TO'),
#   (u'help', 'VB'),
#   (u'those', 'DT'),
#   (u'stranded', 'VBN'),
#   (u'by', 'IN'),
#   (u'the', 'DT'),
#   (u'devastating', 'VBG'),
#   (u'floods', 'NNS'),
#   (u'.', '.')],
#  [(u'Those', 'DT'),
#   (u'able', 'JJ'),
#   (u'to', 'TO'),
#   (u'walk', 'VB'),
#   (u'through', 'RP'),
#   (u'the', 'DT'),
#   (u'rushing', 'NN'),
#   (u'water', 'NN'),
#   (u'are', 'VBP'),
#   (u'given', 'VBN'),
#   (u'a', 'DT'),
#   (u'helping', 'NN'),
#   (u'hand', 'NN'),
#   (u'to', 'TO'),
#   (u'higher', 'JJR'),
#   (u'ground', 'NN'),
#   (u'.', '.')],
#  [(u'Those', 'DT'),
#   (u'unable', 'JJ'),
#   (u'to', 'TO'),
#   (u'make', 'VB'),
#   (u'it', 'PRP'),
#   (u'on', 'IN'),
#   (u'their', 'PRP$'),
#   (u'own', 'JJ'),
#   (u'are', 'VBP'),
#   (u'carried', 'VBN'),
#   (u'to', 'TO'),
#   (u'safety', 'NN'),
#   (u'.', '.')],
#  [(u'GOV', 'NNP'), (u'.', '.')],
#  [(u'JOHN', 'NNP'),
#   (u'BEL', 'NNP'),
#   (u'EDWARDS', 'NNP'),
#   (u'(', 'NNP'),
#   (u'D', 'NNP'),
#   (u')', 'NNP'),
#   (u'LOUISIANA', 'NNP'),
#   (u':', ':'),
#   (u'As', 'IN'),
#   (u'of', 'IN'),
#   (u'right', 'NN'),
#   (u'now', 'RB'),
#   (u'there', 'EX'),
#   (u'have', 'VBP'),
#   (u'been', 'VBN'),
#   (u'more', 'RBR'),
#   (u'than', 'IN'),
#   (u'20000', 'CD'),
#   (u'people', 'NNS'),
#   (u'rescued', 'VBN'),
#   (u'from', 'IN'),
#   (u'their', 'PRP$'),
#   (u'homes', 'NNS'),
#   (u'in', 'IN'),
#   (u'and', 'CC'),
#   (u'around', 'IN'),
#   (u'southern', 'NN'),
#   (u'Louisiana', 'NNP'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Pets', 'NNPS'),
#   (u'were', 'VBD'),
#   (u"n't", 'RB'),
#   (u'left', 'VBN'),
#   (u'behind', 'IN'),
#   (u'in', 'IN'),
#   (u'these', 'DT'),
#   (u'rescues', 'NNS'),
#   (u'.', '.')],
#  [(u'This', 'DT'),
#   (u'military', 'JJ'),
#   (u'convoy', 'NN'),
#   (u'made', 'VBD'),
#   (u'room', 'NN'),
#   (u'for', 'IN'),
#   (u'dogs', 'NNS'),
#   (u'as', 'IN'),
#   (u'well', 'RB'),
#   (u'as', 'IN'),
#   (u'people', 'NNS'),
#   (u'.', '.')],
#  [(u'They', 'PRP'),
#   (u'fled', 'VBD'),
#   (u'the', 'DT'),
#   (u'Baton', 'NNP'),
#   (u'Rouge', 'NNP'),
#   (u'area', 'NN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'flood', 'NN'),
#   (u'waters', 'NNS'),
#   (u'are', 'VBP'),
#   (u'not', 'RB'),
#   (u'expected', 'VBN'),
#   (u'to', 'TO'),
#   (u'recede', 'VB'),
#   (u'for', 'IN'),
#   (u'days', 'NNS'),
#   (u'with', 'IN'),
#   (u'many', 'JJ'),
#   (u'still', 'RB'),
#   (u'trapped', 'VBN'),
#   (u'inside', 'NN'),
#   (u'their', 'PRP$'),
#   (u'homes', 'NNS'),
#   (u'rescue', 'VBP'),
#   (u'operations', 'NNS'),
#   (u'continue', 'VBP'),
#   (u'.', '.')],
#  [(u'Images', 'NNS'),
#   (u'like', 'IN'),
#   (u'these', 'DT'),
#   (u'evoking', 'VBG'),
#   (u'memories', 'NNS'),
#   (u'of', 'IN'),
#   (u'Hurricane', 'NNP'),
#   (u'Katrina', 'NNP'),
#   (u'which', 'WDT'),
#   (u'hit', 'VBD'),
#   (u'this', 'DT'),
#   (u'region', 'NN'),
#   (u'11', 'CD'),
#   (u'years', 'NNS'),
#   (u'ago', 'RB'),
#   (u'this', 'DT'),
#   (u'month', 'NN'),
#   (u'.', '.')],
#  [(u'(', 'NN'),
#   (u'END', 'NN'),
#   (u'VIDEO', 'NNP'),
#   (u'CLIP', 'NNP'),
#   (u')', 'NNP'),
#   (u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Over', 'IN'),
#   (u'the', 'DT'),
#   (u'weekend', 'NN'),
#   (u'more', 'JJR'),
#   (u'than', 'IN'),
#   (u'20', 'CD'),
#   (u'inches', 'NNS'),
#   (u'of', 'IN'),
#   (u'rain', 'NN'),
#   (u'fell', 'VBD'),
#   (u'in', 'IN'),
#   (u'and', 'CC'),
#   (u'around', 'IN'),
#   (u'Baton', 'NNP'),
#   (u'Rouge', 'NNP'),
#   (u'and', 'CC'),
#   (u'more', 'JJR'),
#   (u'is', 'VBZ'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'way', 'NN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'water', 'NN'),
#   (u'is', 'VBZ'),
#   (u'not', 'RB'),
#   (u'done', 'VBN'),
#   (u'rising', 'VBG'),
#   (u'in', 'IN'),
#   (u'Louisiana', 'NNP'),
#   (u'.', '.')],
#  [(u'Our', 'PRP$'),
#   (u'meteorologist', 'NN'),
#   (u'Jennifer', 'NNP'),
#   (u'Gray', 'NNP'),
#   (u'joins', 'VBZ'),
#   (u'us', 'PRP'),
#   (u'from', 'IN'),
#   (u'Baton', 'NNP'),
#   (u'Rouge', 'NNP'),
#   (u'with', 'IN'),
#   (u'more', 'JJR'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'almost', 'RB'),
#   (u'two', 'CD'),
#   (u'feet', 'NNS'),
#   (u'of', 'IN'),
#   (u'rain', 'NN'),
#   (u'in', 'IN'),
#   (u'just', 'RB'),
#   (u'a', 'DT'),
#   (u'few', 'JJ'),
#   (u'days', 'NNS'),
#   (u'.', '.')],
#  [(u'How', 'WRB'),
#   (u'is', 'VBZ'),
#   (u'the', 'DT'),
#   (u'community', 'NN'),
#   (u'coping', 'VBG'),
#   (u'?', '.')],
#  [(u'[', 'NN'),
#   (u'20:55:07', 'CD'),
#   (u']', 'CD'),
#   (u'JENNIFER', 'NNP'),
#   (u'GRAY', 'NNP'),
#   (u'CNN', 'NNP'),
#   (u'METEOROLOGIST', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'this', 'DT'),
#   (u'is', 'VBZ'),
#   (u'a', 'DT'),
#   (u'one', 'CD'),
#   (u'in', 'IN'),
#   (u'1000', 'CD'),
#   (u'year', 'NN'),
#   (u'flood', 'NN'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'this', 'DT'),
#   (u'comes', 'VBZ'),
#   (u'just', 'RB'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'heels', 'NNS'),
#   (u'six', 'CD'),
#   (u'months', 'NNS'),
#   (u'ago', 'RB'),
#   (u'we', 'PRP'),
#   (u'had', 'VBD'),
#   (u'a', 'DT'),
#   (u'historic', 'JJ'),
#   (u'flood', 'NN'),
#   (u'across', 'IN'),
#   (u'south', 'NN'),
#   (u'Louisiana', 'NNP'),
#   (u'and', 'CC'),
#   (u'so', 'RB'),
#   (u'now', 'RB'),
#   (u'we', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'seeing', 'VBG'),
#   (u'another', 'DT'),
#   (u'one', 'CD'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'you', 'PRP'),
#   (u'know', 'VBP'),
#   (u'the', 'DT'),
#   (u'front', 'NN'),
#   (u'cover', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'``', '``'),
#   (u'Time', 'NNP'),
#   (u"''", "''"),
#   (u'newspaper', 'NN'),
#   (u'this', 'DT'),
#   (u'morning', 'NN'),
#   (u'said', 'VBD'),
#   (u'like', 'IN'),
#   (u'Katrina', 'NNP'),
#   (u'all', 'DT'),
#   (u'over', 'IN'),
#   (u'again', 'RB'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'Anderson', 'NNP'),
#   (u'I', 'NNP'),
#   (u'think', 'VBP'),
#   (u'the', 'DT'),
#   (u'images', 'NNS'),
#   (u'of', 'IN'),
#   (u'people', 'NNS'),
#   (u'climbing', 'VBG'),
#   (u'out', 'RP'),
#   (u'of', 'IN'),
#   (u'their', 'PRP$'),
#   (u'roofs', 'NNS'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'to', 'TO'),
#   (u'safety', 'NN'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'on', 'IN'),
#   (u'people', 'NNS'),
#   (u"'s", 'POS'),
#   (u'boats', 'NNS'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'out', 'IN'),
#   (u'of', 'IN'),
#   (u'their', 'PRP$'),
#   (u'neighborhoods', 'NNS'),
#   (u'was', 'VBD'),
#   (u'haunting', 'VBG'),
#   (u'for', 'IN'),
#   (u'people', 'NNS'),
#   (u'across', 'IN'),
#   (u'south', 'JJ'),
#   (u'Louisiana', 'NNP'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u'have', 'VBP'),
#   (u'drone', 'VBN'),
#   (u'footage', 'NN'),
#   (u'now', 'RB'),
#   (u'and', 'CC'),
#   (u'you', 'PRP'),
#   (u'can', 'MD'),
#   (u'see', 'VB'),
#   (u'the', 'DT'),
#   (u'scope', 'NN'),
#   (u'of', 'IN'),
#   (u'what', 'WP'),
#   (u'we', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'water', 'NN'),
#   (u'chest-high', 'JJ'),
#   (u'inside', 'NN'),
#   (u'people', 'NNS'),
#   (u"'s", 'POS'),
#   (u'homes', 'NNS'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u"'s", 'VBZ'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'long', 'JJ'),
#   (u'time', 'NN'),
#   (u'before', 'IN'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'able', 'JJ'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'back', 'RB'),
#   (u'in', 'IN'),
#   (u'Anderson', 'NNP'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'That', 'DT'),
#   (u"'s", 'VBZ'),
#   (u'drone', 'NN'),
#   (u'footage', 'NN'),
#   (u'from', 'IN'),
#   (u'the', 'DT'),
#   (u'area', 'NN'),
#   (u'where', 'WRB'),
#   (u'you', 'PRP'),
#   (u'are', 'VBP'),
#   (u'in', 'IN'),
#   (u'.', '.')],
#  [(u'Jennifer', 'NNP'),
#   (u'I', 'PRP'),
#   (u'mean', 'VBP'),
#   (u'is', 'VBZ'),
#   (u'more', 'RBR'),
#   (u'rain', 'JJ'),
#   (u'expected', 'VBN'),
#   (u'?', '.')],
#  [(u'What', 'WP'),
#   (u"'s", 'VBZ'),
#   (u'the', 'DT'),
#   (u'forecast', 'NN'),
#   (u'?', '.')],
#  [(u'GRAY', 'NNP'),
#   (u':', ':'),
#   (u'Well', 'NNP'),
#   (u'we', 'PRP'),
#   (u'are', 'VBP'),
#   (u'looking', 'VBG'),
#   (u'at', 'IN'),
#   (u'a', 'DT'),
#   (u'little', 'RB'),
#   (u'bit', 'NN'),
#   (u'more', 'JJR'),
#   (u'rain', 'NN'),
#   (u'each', 'DT'),
#   (u'day', 'NN'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'not', 'RB'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'see', 'VB'),
#   (u'some', 'DT'),
#   (u'widespread', 'JJ'),
#   (u'all', 'DT'),
#   (u'day', 'NN'),
#   (u'rain', 'NN'),
#   (u'but', 'CC'),
#   (u'we', 'PRP'),
#   (u'will', 'MD'),
#   (u'see', 'VB'),
#   (u'pop-up', 'JJ'),
#   (u'showers', 'NNS'),
#   (u'that', 'WDT'),
#   (u'it', 'PRP'),
#   (u'should', 'MD'),
#   (u"n't", 'RB'),
#   (u'do', 'VB'),
#   (u'too', 'RB'),
#   (u'much', 'RB'),
#   (u'as', 'IN'),
#   (u'far', 'RB'),
#   (u'as', 'IN'),
#   (u'worsen', 'VBN'),
#   (u'the', 'DT'),
#   (u'flood', 'NN'),
#   (u'but', 'CC'),
#   (u'lot', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'rivers', 'NNS'),
#   (u'have', 'VBP'),
#   (u'already', 'RB'),
#   (u'crested', 'VBN'),
#   (u'.', '.')],
#  [(u'But', 'CC'),
#   (u'keep', 'VB'),
#   (u'in', 'IN'),
#   (u'mind', 'NN'),
#   (u'this', 'DT'),
#   (u'is', 'VBZ'),
#   (u'going', 'VBG'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'very', 'RB'),
#   (u'slow', 'JJ'),
#   (u'climb', 'NN'),
#   (u'downwards', 'NNS'),
#   (u'.', '.')],
#  [(u'We', 'PRP'),
#   (u'are', 'VBP'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'days', 'NNS'),
#   (u'not', 'RB'),
#   (u'hours', 'NNS'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'some', 'DT'),
#   (u'of', 'IN'),
#   (u'these', 'DT'),
#   (u'rivers', 'NNS'),
#   (u'could', 'MD'),
#   (u'sit', 'VB'),
#   (u'at', 'IN'),
#   (u'where', 'WRB'),
#   (u'they', 'PRP'),
#   (u'crested', 'VBD'),
#   (u'for', 'IN'),
#   (u'several', 'JJ'),
#   (u'days', 'NNS'),
#   (u'.', '.')],
#  [(u'So', 'IN'),
#   (u'we', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'talking', 'VBG'),
#   (u'about', 'IN'),
#   (u'these', 'DT'),
#   (u'houses', 'NNS'),
#   (u'behind', 'IN'),
#   (u'me', 'PRP'),
#   (u'with', 'IN'),
#   (u'water', 'NN'),
#   (u'inside', 'NN'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u'could', 'MD'),
#   (u'be', 'VB'),
#   (u'the', 'DT'),
#   (u'end', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'week', 'NN'),
#   (u'before', 'IN'),
#   (u'they', 'PRP'),
#   (u"'re", 'VBP'),
#   (u'able', 'JJ'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'in', 'IN'),
#   (u'their', 'PRP$'),
#   (u'front', 'NN'),
#   (u'door', 'NN'),
#   (u'Anderson', 'NNP'),
#   (u'.', '.')],
#  [(u'COOPER', 'NNP'),
#   (u':', ':'),
#   (u'Just', 'NNP'),
#   (u'terrible', 'JJ'),
#   (u'.', '.')],
#  [(u'Jennifer', 'NNP'),
#   (u'Gray', 'NNP'),
#   (u'I', 'NNP'),
#   (u'appreciate', 'VBP'),
#   (u'you', 'PRP'),
#   (u'being', 'VBG'),
#   (u'there', 'RB'),
#   (u'.', '.')],
#  [(u'Thank', 'NNP'), (u'you', 'PRP'), (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'the', 'DT'),
#   (u'next', 'JJ'),
#   (u'hour', 'NN'),
#   (u'of', 'IN'),
#   (u'``', '``'),
#   (u'360', 'CD'),
#   (u"''", "''"),
#   (u'Donald', 'NNP'),
#   (u'Trump', 'NNP'),
#   (u'proposes', 'VBZ'),
#   (u'what', 'WP'),
#   (u'he', 'PRP'),
#   (u'calls', 'VBZ'),
#   (u'extreme', 'NN'),
#   (u'vetting', 'VBG'),
#   (u'of', 'IN'),
#   (u'immigrants', 'NNS'),
#   (u'and', 'CC'),
#   (u'other', 'JJ'),
#   (u'steps', 'NNS'),
#   (u'as', 'IN'),
#   (u'he', 'PRP'),
#   (u'unveils', 'VBZ'),
#   (u'his', 'PRP$'),
#   (u'plan', 'NN'),
#   (u'to', 'TO'),
#   (u'defeat', 'VB'),
#   (u'ISIS', 'NNP'),
#   (u'.', '.')],
#  [(u'(', 'NN'), (u'COMMERCIAL', 'JJ'), (u'BREAK', 'NNP'), (u')', 'NNP')]]

# %%
"""dist = nltk.FreqDist(words)
print(dist['Clinton'])
print(dist['Trump'])"""
# Out:
# "dist = nltk.FreqDist(words)\nprint(dist['Clinton'])\nprint(dist['Trump'])"

# %%
stopwords = stopwords.words('english')

# %%
grammar = "speaker: {<NNP>+<:>}" #""" NP: {<NNP>+:}"""
cp = nltk.RegexpParser(grammar)

# %%
cp.parse(pos[0])
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# /usr/local/lib/python2.7/site-packages/nltk/tree.pyc in _repr_png_(self)
#     724             _canvas_frame.print_to_file(in_path)
#     725             _canvas_frame.destroy_widget(widget)
# --> 726             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     727                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     728                             .format(out_path, in_path).split())
#
# /usr/local/lib/python2.7/site-packages/nltk/__init__.pyc in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     561                 binary_names=None, url=None, verbose=True):
#     562     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 563                                  binary_names, url, verbose))
#     564
#     565 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# /usr/local/lib/python2.7/site-packages/nltk/__init__.pyc in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     555     """
#     556     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 557                      url, verbose):
#     558         yield file
#     559
#
# /usr/local/lib/python2.7/site-packages/nltk/__init__.pyc in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     526                         (filename, url))
#     527         div = '='*75
# --> 528         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     529
#     530
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [(u'[', 'NN'), (u'20:00:21', 'CD'), (u']', 'CD'), Tree('speaker', [(u'ANDERSON', 'NNP'), (u'COOPER', 'NNP'), (u'CNN', 'NNP'), (u'ANCHOR', 'NNP'), (u':', ':')]), (u'Good', 'NNP'), (u'evening', 'NN'), (u'.', '.')])

# %%
transcript
